# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.metrics import roc_curve, precision_score, recall_score, f1_score, accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
from multiprocessing import Pool

# %% [markdown]
# ### Function Used

# %%
def model_info(x, y, test_date, data_tested):
    cm = confusion_matrix(x,y)
    acc = accuracy_score(x,y)
    rec = recall_score(x,y)
    rec_0 = recall_score(x,y, pos_label=0)
    data = [{"Accuracy":acc,"Specificity":rec_0, "Sensitivity":rec}]
    df = pd.DataFrame(data)
    df['test_date'] = test_date
    df['data_tested'] = data_tested
    if len(x.value_counts()) == 1:
        l30 = x.value_counts()[0]
        df['greter_than_30'] = '0'
        df['less_than_30'] = l30
    else:
        g30 = x.value_counts()[1]
        l30 = x.value_counts()[0]
        df['greter_than_30'] = g30
        df['less_than_30'] = l30
    return (df)

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv("15min_dateset.csv")
df.drop('Unnamed: 0', inplace = True, axis = 1)
print(len(df['EXP'].unique()))
df.head(2)
# Out:
# 32
#                   Date  Type     from     EXP  jul_date  hour_angle  \
# 0  2017-01-07 06:00:00  ANDE  MESONET  1/7/17         7   -1.570795
# 1  2017-01-07 06:15:00  ANDE  MESONET  1/7/17         7   -1.505345
#
#    max_wind_speed  avg_wind_speed        R1        R2  ...  HYBL_one  \
# 0        2.332608        1.295893  2.630564  2.322274  ...  0.629230
# 1        1.555072        0.647947  2.055383  1.813005  ...  0.748575
#
#    HYBL_two  HYBL_three  HYBL_four  HYBL_five  diff_temp  geo_cbl  veg_sfc  \
# 0  0.903721    3.610055   5.011670   6.054984      0.739  -5000.0   40.293
# 1  1.493288    3.643217   5.232982   6.394255      1.050  -5000.0   40.293
#
#    best_4_layer     ws_700
# 0        23.757  16.787335
# 1        23.959  16.195689
#
# [2 rows x 27 columns]

# %% [markdown]
# ### Create Column for classification

# %%
df["max_th"] = np.where(df["max_wind_speed"] > 30, 1, 0 )
table = df["max_th"].value_counts()
total = table[1] + table[0]
print(table)
print('% greater than 30:', round(table[1]/total,3))
print('% less than 30:', round(table[0]/total,3))
# Out:
# 0    69019
# 1     3630
# Name: max_th, dtype: int64
# % greater than 30: 0.05
# % less than 30: 0.95

# %%
df2 = df[['Type', 'from', 'EXP',
       'max_wind_speed', 'R1', 'R2',
       'Pressure_reduced_to_MSL_.Pa..0.MSL',
       'Derived_radar_reflectivity_.dB..1.HYBL',
       'u.component_of_wind_.m.s..85000.ISBL',
       'v.component_of_wind_.m.s..85000.ISBL', 'wind_speed_85000',
       'wind_shear_85000', 'Wind_speed_.gust._.m.s..0.SFC', 'HYBL_one',
       'HYBL_two', 'HYBL_three', 'HYBL_four', 'HYBL_five', 'diff_temp',
       'geo_cbl', 'veg_sfc', 'best_4_layer', 'ws_700', 'max_th']]
le = LabelEncoder()
df2['from'] = le.fit_transform(df2['from'])
df2.head(2)
# Out:
#    Type  from     EXP  max_wind_speed        R1        R2  \
# 0  ANDE     1  1/7/17        2.332608  2.630564  2.322274
# 1  ANDE     1  1/7/17        1.555072  2.055383  1.813005
#
#    Pressure_reduced_to_MSL_.Pa..0.MSL  Derived_radar_reflectivity_.dB..1.HYBL  \
# 0                            102879.7                                     0.0
# 1                            102951.0                                     0.0
#
#    u.component_of_wind_.m.s..85000.ISBL  v.component_of_wind_.m.s..85000.ISBL  \
# 0                                 5.447                                -1.457
# 1                                 5.629                                -1.464
#
#    ...  HYBL_two  HYBL_three  HYBL_four  HYBL_five  diff_temp  geo_cbl  \
# 0  ...  0.903721    3.610055   5.011670   6.054984      0.739  -5000.0
# 1  ...  1.493288    3.643217   5.232982   6.394255      1.050  -5000.0
#
#    veg_sfc  best_4_layer     ws_700  max_th
# 0   40.293        23.757  16.787335       0
# 1   40.293        23.959  16.195689       0
#
# [2 rows x 24 columns]

# %% [markdown]
# ### Grid Search for best parameters

# %%
X = df2.drop(['max_wind_speed', 'Type', 'EXP','max_th'], 1)
Y = df2.max_th.values

pram = {'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5],
        'learning_rate': [.01,0.1,0.3],
        'n_estimators': [100,250,500]}

# %%
clf = GridSearchCV(XGBClassifier(objective='binary:logistic' , random_state=19), pram, cv=3, n_jobs=-1, verbose=3, scoring='roc_auc')
clf.fit(X,Y)
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   39.1s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed: 20.4min
# [Parallel(n_jobs=-1)]: Done 496 tasks      | elapsed: 40.3min
# [Parallel(n_jobs=-1)]: Done 729 out of 729 | elapsed: 64.8min finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0,
#                                      learning_rate=0.1, max_delta_step=0,
#                                      max_depth=3, min_child_weight=1,
#                                      missing=None, n_estimators=100, n_jobs=1,
#                                      nthread=None, objective='binary:logistic',
#                                      random_state=19, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=None, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='warn', n_jobs=-1,
#              param_grid={'colsample_bytree': [0.6, 0.8, 1.0],
#                          'learning_rate': [0.01, 0.1, 0.3],
#                          'max_depth': [3, 4, 5],
#                          'n_estimators': [100, 250, 500],
#                          'subsample': [0.6, 0.8, 1.0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='roc_auc', verbose=3)

# %%
clf.best_score_, clf.best_params_,clf.scorer_
# Out:
# (0.9323359560570017,
#  {'colsample_bytree': 0.6,
#   'learning_rate': 0.01,
#   'max_depth': 5,
#   'n_estimators': 500,
#   'subsample': 0.6},
#  make_scorer(roc_auc_score, needs_threshold=True))

# %% [markdown]
# ### XGB Model Non-resampling

# %%
def rf_model(x):
    test_1 = df2[df2.EXP == x]
    train_1 = df2[df2.EXP != x]
    train_1 = train_1[['Type', 'from', 'R1', 'R2',
       'Pressure_reduced_to_MSL_.Pa..0.MSL',
       'Derived_radar_reflectivity_.dB..1.HYBL',
       'u.component_of_wind_.m.s..85000.ISBL',
       'v.component_of_wind_.m.s..85000.ISBL', 'wind_speed_85000',
       'wind_shear_85000', 'Wind_speed_.gust._.m.s..0.SFC', 'HYBL_one',
       'HYBL_two', 'HYBL_three', 'HYBL_four', 'HYBL_five', 'diff_temp',
       'geo_cbl', 'veg_sfc', 'best_4_layer', 'ws_700','max_th','max_wind_speed']]


    test_1 = test_1[['Type', 'from', 'R1', 'R2',
       'Pressure_reduced_to_MSL_.Pa..0.MSL',
       'Derived_radar_reflectivity_.dB..1.HYBL',
       'u.component_of_wind_.m.s..85000.ISBL',
       'v.component_of_wind_.m.s..85000.ISBL', 'wind_speed_85000',
       'wind_shear_85000', 'Wind_speed_.gust._.m.s..0.SFC', 'HYBL_one',
       'HYBL_two', 'HYBL_three', 'HYBL_four', 'HYBL_five', 'diff_temp',
       'geo_cbl', 'veg_sfc', 'best_4_layer', 'ws_700','max_th','max_wind_speed']]
    
    
    x_train = train_1.drop('max_th', 1)
    x_train.drop(['Type','max_wind_speed'], axis=1, inplace=True)
    y_train = train_1.max_th
    x_test = test_1.drop('max_th', 1)
    x_test_copy = x_test.copy()
    x_test.drop(['Type','max_wind_speed'], axis=1, inplace=True)
    y_test = test_1.max_th
    
    model = XGBClassifier(objective='binary:logistic', max_depth=5, n_estimators=500,colsample_bytree= 0.6 ,
                          learning_rate =  0.01, subsample = 0.6, random_state=19)
    model.fit(x_train, y_train)
    
    pred_train = model.predict(x_train)
    train_info = model_info(y_train, pred_train, x , "train")

    pred_test = model.predict(x_test)
    test_info = model_info(y_test, pred_test, x , "test")

    table = train_info.append(test_info)
    
    print(x)
    print(table)
    print("--" * 40)
    prod = model.predict_proba(x_test)
    prod_data = pd.DataFrame(prod, columns=["less_30","greater_30"])
    df4 = pd.DataFrame(y_test)
    df4 = df4.rename(columns={'max_th': 'actual'})
    df4 = df4.reset_index()
    df4.drop('index', axis=1, inplace=True)
    x_test_copy = x_test_copy.reset_index()
    x_test_copy.drop("index", axis=1, inplace=True)
    df5 = pd.concat([x_test_copy, df4, prod_data], axis=1)
    pred_df = pd.DataFrame(pred_test, columns=["pred"])
    df6 = pd.concat([df5, pred_df], axis=1)
    df6['From'] = np.where(df6['from'] == 1, 'Mesonet', 'ASOS')
    df6.drop('from', inplace=True, axis=1)
    df6['test_date'] = x
    return(table, df6)

# %%
# %%time
table = pd.DataFrame()
data = pd.DataFrame()
for i in df['EXP'].unique():
    t,d = rf_model(i)
    table = table.append(t)
    data = data.append(d)
# Out:
# 1/7/17
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.965582     0.995929     0.404959    1/7/17       train           3630
# 0  1.000000     1.000000     0.000000    1/7/17        test              0
#
#    less_than_30
# 0         67060
# 0          1959
# --------------------------------------------------------------------------------
# 2/9/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.965943     0.995911     0.404529    2/9/17       train            3577
# 0  0.973314     0.991036     0.301887    2/9/17        test              53
#
#    less_than_30
# 0         67011
# 0          2008
# --------------------------------------------------------------------------------
# 2/13/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.970364     0.997101     0.385238   2/13/17       train            3089
# 0  0.759325     0.993644     0.146026   2/13/17        test             541
#
#    less_than_30
# 0         67603
# 0          1416
# --------------------------------------------------------------------------------
# 2/25/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.965856     0.996032     0.403723   2/25/17       train            3599
# 0  0.984562     1.000000     0.000000   2/25/17        test              31
#
#    less_than_30
# 0         67042
# 0          1977
# --------------------------------------------------------------------------------
# 3/2/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.971213     0.997214     0.386538    3/2/17       train            3001
# 0  0.778753     0.998698     0.241653    3/2/17        test             629
#
#    less_than_30
# 0         67483
# 0          1536
# --------------------------------------------------------------------------------
# 3/14/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.966929     0.996064     0.400406   3/14/17       train            3449
# 0  0.939522     0.984119     0.458564   3/14/17        test             181
#
#    less_than_30
# 0         67067
# 0          1952
# --------------------------------------------------------------------------------
# 3/22/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.969554     0.996418     0.406357   3/22/17       train            3209
# 0  0.842884     0.980493     0.273159   3/22/17        test             421
#
#    less_than_30
# 0         67276
# 0          1743
# --------------------------------------------------------------------------------
# 6/19/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.965835     0.995888     0.407087   6/19/17       train            3584
# 0  0.981070     1.000000     0.000000   6/19/17        test              46
#
#    less_than_30
# 0         66635
# 0          2384
# --------------------------------------------------------------------------------
# 7/13/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.965128     0.995949     0.398842   7/13/17       train            3628
# 0  0.999154     1.000000     0.000000   7/13/17        test               2
#
#    less_than_30
# 0         66658
# 0          2361
# --------------------------------------------------------------------------------
# 10/29/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.967486     0.995851     0.429383  10/29/17       train            3519
# 0  0.950232     0.992035     0.099099  10/29/17        test             111
#
#    less_than_30
# 0         66759
# 0          2260
# --------------------------------------------------------------------------------
# 11/19/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.969466     0.995813     0.436650  11/19/17       train            3307
# 0  0.884381     0.990663     0.179567  11/19/17        test             323
#
#    less_than_30
# 0         66877
# 0          2142
# --------------------------------------------------------------------------------
# 12/9/17
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.965273     0.996195     0.398898   12/9/17       train           3630
# 0  1.000000     1.000000     0.000000   12/9/17        test              0
#
#    less_than_30
# 0         66488
# 0          2531
# --------------------------------------------------------------------------------
# 1/4/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.967765     0.996092     0.409212    1/4/18       train            3387
# 0  0.913201     0.999552     0.119342    1/4/18        test             243
#
#    less_than_30
# 0         66785
# 0          2234
# --------------------------------------------------------------------------------
# 3/2/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.967017     0.995986     0.406893    3/2/18       train            3453
# 0  0.926337     0.995118     0.050847    3/2/18        test             177
#
#    less_than_30
# 0         66766
# 0          2253
# --------------------------------------------------------------------------------
# 3/7/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.965161     0.995849     0.402372    3/7/18       train            3626
# 0  0.997625     0.999207     0.000000    3/7/18        test               4
#
#    less_than_30
# 0         66497
# 0          2522
# --------------------------------------------------------------------------------
# 3/21/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.965286     0.996176     0.397796   3/21/18       train           3630
# 0  0.994425     0.994425     0.000000   3/21/18        test              0
#
#    less_than_30
# 0         66687
# 0          2332
# --------------------------------------------------------------------------------
# 5/15/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.965786     0.995853     0.407366   5/15/18       train            3584
# 0  0.981223     0.999593     0.000000   5/15/18        test              46
#
#    less_than_30
# 0         66562
# 0          2457
# --------------------------------------------------------------------------------
# 5/26/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.965179     0.996142      0.39697   5/26/18       train           3630
# 0  1.000000     1.000000      0.00000   5/26/18        test              0
#
#    less_than_30
# 0         66615
# 0          2404
# --------------------------------------------------------------------------------
# 6/13/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.965332     0.996058      0.40259   6/13/18       train            3629
# 0  0.999609     1.000000      0.00000   6/13/18        test               1
#
#    less_than_30
# 0         66465
# 0          2554
# --------------------------------------------------------------------------------
# 7/17/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.965339     0.995981     0.400829   7/17/18       train            3620
# 0  0.995726     1.000000     0.000000   7/17/18        test              10
#
#    less_than_30
# 0         66689
# 0          2330
# --------------------------------------------------------------------------------
# 7/21/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.965162     0.995827     0.400994   7/21/18       train            3621
# 0  0.996264     1.000000     0.000000   7/21/18        test               9
#
#    less_than_30
# 0         66619
# 0          2400
# --------------------------------------------------------------------------------
# 8/17/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.965151     0.996021     0.395529   8/17/18       train            3623
# 0  0.996780     1.000000     0.000000   8/17/18        test               7
#
#    less_than_30
# 0         66852
# 0          2167
# --------------------------------------------------------------------------------
# 9/4/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.965384     0.996307     0.395592    9/4/18       train           3630
# 0  1.000000     1.000000     0.000000    9/4/18        test              0
#
#    less_than_30
# 0         66886
# 0          2133
# --------------------------------------------------------------------------------
# 9/6/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.965490     0.995898     0.405077    9/6/18       train            3624
# 0  0.997315     1.000000     0.000000    9/6/18        test               6
#
#    less_than_30
# 0         66790
# 0          2229
# --------------------------------------------------------------------------------
# 9/10/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.965107     0.995911     0.397793   9/10/18       train            3625
# 0  0.997790     1.000000     0.000000   9/10/18        test               5
#
#    less_than_30
# 0         66762
# 0          2257
# --------------------------------------------------------------------------------
# 9/26/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.965137     0.996007     0.396419   9/26/18       train           3630
# 0  1.000000     1.000000     0.000000   9/26/18        test              0
#
#    less_than_30
# 0         66874
# 0          2145
# --------------------------------------------------------------------------------
# 10/2/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.965554     0.996072     0.402261   10/2/18       train            3627
# 0  0.998554     1.000000     0.000000   10/2/18        test               3
#
#    less_than_30
# 0         66947
# 0          2072
# --------------------------------------------------------------------------------
# 10/12/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.966002     0.995928     0.408368  10/12/18       train            3585
# 0  0.979673     0.998647     0.044444  10/12/18        test              45
#
#    less_than_30
# 0         66801
# 0          2218
# --------------------------------------------------------------------------------
# 10/27/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.967266     0.996001     0.420500  10/27/18       train            3522
# 0  0.951185     1.000000     0.046296  10/27/18        test             108
#
#    less_than_30
# 0         67017
# 0          2002
# --------------------------------------------------------------------------------
# 12/17/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.968029     0.996364     0.416981  12/17/18       train            3451
# 0  0.913189     0.990556     0.089385  12/17/18        test             179
#
#    less_than_30
# 0         67113
# 0          1906
# --------------------------------------------------------------------------------
# 12/22/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.968097     0.996221     0.423155  12/22/18       train            3455
# 0  0.926157     0.993247     0.131429  12/22/18        test             175
#
#    less_than_30
# 0         66946
# 0          2073
# --------------------------------------------------------------------------------
# 2/24/19
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.967446     0.996132     0.395113   2/24/19       train            3356
# 0  0.902397     0.992726     0.222628   2/24/19        test             274
#
#    less_than_30
# 0         66957
# 0          2062
# --------------------------------------------------------------------------------
# CPU times: user 30min, sys: 3.72 s, total: 30min 4s
# Wall time: 29min 28s

# %%
data.tail()
# Out:
#       Type        R1        R2  Pressure_reduced_to_MSL_.Pa..0.MSL  \
# 2331  WANT  0.098920  0.157647                          100027.320
# 2332  WANT  0.098133  0.156265                          100043.773
# 2333  WANT  0.098374  0.154478                          100029.609
# 2334  WANT  0.097222  0.153720                          100029.547
# 2335  WANT  0.094813  0.153293                          100049.734
#
#       Derived_radar_reflectivity_.dB..1.HYBL  \
# 2331                                     0.0
# 2332                                     0.0
# 2333                                     0.0
# 2334                                     0.0
# 2335                                     0.0
#
#       u.component_of_wind_.m.s..85000.ISBL  \
# 2331                                32.948
# 2332                                33.102
# 2333                                33.439
# 2334                                33.765
# 2335                                33.951
#
#       v.component_of_wind_.m.s..85000.ISBL  wind_speed_85000  \
# 2331                                -5.489         33.402093
# 2332                                -5.860         33.616692
# 2333                                -5.925         33.959864
# 2334                                -5.858         34.269394
# 2335                                -5.796         34.442184
#
#       wind_shear_85000  Wind_speed_.gust._.m.s..0.SFC  ...  veg_sfc  \
# 2331         23.859866                         37.742  ...   40.175
# 2332         24.105445                         38.260  ...   40.175
# 2333         24.255558                         39.137  ...   40.175
# 2334         24.277645                         40.062  ...   40.175
# 2335         24.231285                         40.566  ...   40.175
#
#       best_4_layer     ws_700  max_wind_speed  actual   less_30  greater_30  \
# 2331        21.381  17.640080       37.904880       1  0.775173    0.224827
# 2332        21.517  19.861816       46.457776       1  0.777900    0.222100
# 2333        21.800  22.217660       37.710496       1  0.778572    0.221428
# 2334        21.817  22.936901       39.071184       1  0.775179    0.224821
# 2335        21.817  23.463382       36.349808       1  0.772047    0.227953
#
#       pred     From  test_date
# 2331     0  Mesonet    2/24/19
# 2332     0  Mesonet    2/24/19
# 2333     0  Mesonet    2/24/19
# 2334     0  Mesonet    2/24/19
# 2335     0  Mesonet    2/24/19
#
# [5 rows x 27 columns]

# %%
table
# Out:
#     Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0   0.965582     0.995929     0.404959    1/7/17       train           3630
# 0   1.000000     1.000000     0.000000    1/7/17        test              0
# 0   0.965943     0.995911     0.404529    2/9/17       train           3577
# 0   0.973314     0.991036     0.301887    2/9/17        test             53
# 0   0.970364     0.997101     0.385238   2/13/17       train           3089
# ..       ...          ...          ...       ...         ...            ...
# 0   0.913189     0.990556     0.089385  12/17/18        test            179
# 0   0.968097     0.996221     0.423155  12/22/18       train           3455
# 0   0.926157     0.993247     0.131429  12/22/18        test            175
# 0   0.967446     0.996132     0.395113   2/24/19       train           3356
# 0   0.902397     0.992726     0.222628   2/24/19        test            274
#
#     less_than_30
# 0          67060
# 0           1959
# 0          67011
# 0           2008
# 0          67603
# ..           ...
# 0           1906
# 0          66946
# 0           2073
# 0          66957
# 0           2062
#
# [64 rows x 7 columns]

# %%
#table.to_csv('XGB_CLASS_greater_30_no_sample_stats.csv')

# %%
#data.to_csv('XGB_CLASS_greater_30_no_sample_data.csv')

# %% [markdown]
# ### XGB Model resampling

# %%
def rf_model2(x):
    test_1 = df2[df2.EXP == x]
    train_1 = df2[df2.EXP != x]
    train_1 = train_1[['Type', 'from', 'R1', 'R2',
       'Pressure_reduced_to_MSL_.Pa..0.MSL',
       'Derived_radar_reflectivity_.dB..1.HYBL',
       'u.component_of_wind_.m.s..85000.ISBL',
       'v.component_of_wind_.m.s..85000.ISBL', 'wind_speed_85000',
       'wind_shear_85000', 'Wind_speed_.gust._.m.s..0.SFC', 'HYBL_one',
       'HYBL_two', 'HYBL_three', 'HYBL_four', 'HYBL_five', 'diff_temp',
       'geo_cbl', 'veg_sfc', 'best_4_layer', 'ws_700','max_th','max_wind_speed']]


    test_1 = test_1[['Type', 'from', 'R1', 'R2',
       'Pressure_reduced_to_MSL_.Pa..0.MSL',
       'Derived_radar_reflectivity_.dB..1.HYBL',
       'u.component_of_wind_.m.s..85000.ISBL',
       'v.component_of_wind_.m.s..85000.ISBL', 'wind_speed_85000',
       'wind_shear_85000', 'Wind_speed_.gust._.m.s..0.SFC', 'HYBL_one',
       'HYBL_two', 'HYBL_three', 'HYBL_four', 'HYBL_five', 'diff_temp',
       'geo_cbl', 'veg_sfc', 'best_4_layer', 'ws_700','max_th','max_wind_speed']]
    
    df_0 = train_1[train_1['max_th'] == 0]
    df_1 = train_1[train_1['max_th'] == 1]
    df_under = df_0.sample(9000 ,random_state=19)
    df_new = pd.concat([df_under, df_1], axis = 0)
    
    
    x_train = df_new.drop('max_th', 1)
    x_train.drop(['Type','max_wind_speed'], axis=1, inplace=True)
    y_train = df_new.max_th
    x_test = test_1.drop('max_th', 1)
    x_test_copy = x_test.copy()
    x_test.drop(['Type','max_wind_speed'], axis=1, inplace=True)
    y_test = test_1.max_th
    
    model = XGBClassifier(objective='binary:logistic', max_depth=5, n_estimators=500,colsample_bytree= 0.6 ,
                          learning_rate =  0.01, subsample = 0.6, random_state=19)
    model.fit(x_train, y_train)
    
    pred_train = model.predict(x_train)
    train_info = model_info(y_train, pred_train, x , "train")

    pred_test = model.predict(x_test)
    test_info = model_info(y_test, pred_test, x , "test")

    table = train_info.append(test_info)
    
    print(x)
    print(table)
    print("--" * 40)
    prod = model.predict_proba(x_test)
    prod_data = pd.DataFrame(prod, columns=["less_30","greater_30"])
    df4 = pd.DataFrame(y_test)
    df4 = df4.rename(columns={'max_th': 'actual'})
    df4 = df4.reset_index()
    df4.drop('index', axis=1, inplace=True)
    x_test_copy = x_test_copy.reset_index()
    x_test_copy.drop("index", axis=1, inplace=True)
    df5 = pd.concat([x_test_copy, df4, prod_data], axis=1)
    pred_df = pd.DataFrame(pred_test, columns=["pred"])
    df6 = pd.concat([df5, pred_df], axis=1)
    df6['From'] = np.where(df6['from'] == 1, 'Mesonet', 'ASOS')
    df6.drop('from', inplace=True, axis=1)
    df6['test_date'] = x
    return(table, df6)

# %%
# %%time
table2 = pd.DataFrame()
data2 = pd.DataFrame()
for i in df['EXP'].unique():
    t,d = rf_model2(i)
    table2 = table2.append(t)
    data2 = data2.append(d)
# Out:
# 1/7/17
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.919002     0.933556      0.88292    1/7/17       train           3630
# 0  0.995406     0.995406      0.00000    1/7/17        test              0
#
#    less_than_30
# 0          9000
# 0          1959
# --------------------------------------------------------------------------------
# 2/9/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.923034     0.937667     0.886218    2/9/17       train            3577
# 0  0.939350     0.943725     0.773585    2/9/17        test              53
#
#    less_than_30
# 0          9000
# 0          2008
# --------------------------------------------------------------------------------
# 2/13/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.929275     0.948667     0.872774   2/13/17       train            3089
# 0  0.785386     0.808616     0.724584   2/13/17        test             541
#
#    less_than_30
# 0          9000
# 0          1416
# --------------------------------------------------------------------------------
# 2/25/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.927613     0.939778     0.897194   2/25/17       train            3599
# 0  0.942231     0.955488     0.096774   2/25/17        test              31
#
#    less_than_30
# 0          9000
# 0          1977
# --------------------------------------------------------------------------------
# 3/2/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.931589     0.951778     0.871043    3/2/17       train            3001
# 0  0.642494     0.562500     0.837838    3/2/17        test             629
#
#    less_than_30
# 0          9000
# 0          1536
# --------------------------------------------------------------------------------
# 3/14/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.927384     0.943889     0.884314   3/14/17       train            3449
# 0  0.872480     0.867828     0.922652   3/14/17        test             181
#
#    less_than_30
# 0          9000
# 0          1952
# --------------------------------------------------------------------------------
# 3/22/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.927922     0.944222     0.882206   3/22/17       train            3209
# 0  0.578096     0.518072     0.826603   3/22/17        test             421
#
#    less_than_30
# 0          9000
# 0          1743
# --------------------------------------------------------------------------------
# 6/19/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.926097     0.940222     0.890625   6/19/17       train            3584
# 0  0.978601     0.993708     0.195652   6/19/17        test              46
#
#    less_than_30
# 0          9000
# 0          2384
# --------------------------------------------------------------------------------
# 7/13/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.923741     0.938111     0.888093   7/13/17       train            3628
# 0  0.999154     1.000000     0.000000   7/13/17        test               2
#
#    less_than_30
# 0          9000
# 0          2361
# --------------------------------------------------------------------------------
# 10/29/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.927630     0.942222      0.89031  10/29/17       train            3519
# 0  0.823703     0.837168      0.54955  10/29/17        test             111
#
#    less_than_30
# 0          9000
# 0          2260
# --------------------------------------------------------------------------------
# 11/19/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.931096     0.947222     0.887209  11/19/17       train            3307
# 0  0.644625     0.609244     0.879257  11/19/17        test             323
#
#    less_than_30
# 0          9000
# 0          2142
# --------------------------------------------------------------------------------
# 12/9/17
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.925099     0.939778     0.888705   12/9/17       train           3630
# 0  1.000000     1.000000     0.000000   12/9/17        test              0
#
#    less_than_30
# 0          9000
# 0          2531
# --------------------------------------------------------------------------------
# 1/4/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.925648     0.944778     0.874815    1/4/18       train            3387
# 0  0.942269     0.995971     0.448560    1/4/18        test             243
#
#    less_than_30
# 0          9000
# 0          2234
# --------------------------------------------------------------------------------
# 3/2/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.924837     0.939556     0.886476    3/2/18       train            3453
# 0  0.882305     0.895695     0.711864    3/2/18        test             177
#
#    less_than_30
# 0          9000
# 0          2253
# --------------------------------------------------------------------------------
# 3/7/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.923729     0.937667     0.889134    3/7/18       train            3626
# 0  0.994062     0.994845     0.500000    3/7/18        test               4
#
#    less_than_30
# 0          9000
# 0          2522
# --------------------------------------------------------------------------------
# 3/21/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.923674     0.938667     0.886501   3/21/18       train           3630
# 0  0.946398     0.946398     0.000000   3/21/18        test              0
#
#    less_than_30
# 0          9000
# 0          2332
# --------------------------------------------------------------------------------
# 5/15/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.925699     0.941111     0.886998   5/15/18       train            3584
# 0  0.977627     0.994302     0.086957   5/15/18        test              46
#
#    less_than_30
# 0          9000
# 0          2457
# --------------------------------------------------------------------------------
# 5/26/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.925178     0.939889     0.888705   5/26/18       train           3630
# 0  1.000000     1.000000     0.000000   5/26/18        test              0
#
#    less_than_30
# 0          9000
# 0          2404
# --------------------------------------------------------------------------------
# 6/13/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.925806     0.939667      0.89143   6/13/18       train            3629
# 0  0.999609     1.000000      0.00000   6/13/18        test               1
#
#    less_than_30
# 0          9000
# 0          2554
# --------------------------------------------------------------------------------
# 7/17/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.925040        0.939     0.890331   7/17/18       train            3620
# 0  0.995726        1.000     0.000000   7/17/18        test              10
#
#    less_than_30
# 0          9000
# 0          2330
# --------------------------------------------------------------------------------
# 7/21/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.920846     0.935556     0.884286   7/21/18       train            3621
# 0  0.990452     0.992500     0.444444   7/21/18        test               9
#
#    less_than_30
# 0          9000
# 0          2400
# --------------------------------------------------------------------------------
# 8/17/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.924344     0.937667      0.89125   8/17/18       train            3623
# 0  0.996780     1.000000      0.00000   8/17/18        test               7
#
#    less_than_30
# 0          9000
# 0          2167
# --------------------------------------------------------------------------------
# 9/4/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.924545     0.939444     0.887603    9/4/18       train           3630
# 0  1.000000     1.000000     0.000000    9/4/18        test              0
#
#    less_than_30
# 0          9000
# 0          2133
# --------------------------------------------------------------------------------
# 9/6/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.924430        0.938     0.890728    9/6/18       train            3624
# 0  0.997315        1.000     0.000000    9/6/18        test               6
#
#    less_than_30
# 0          9000
# 0          2229
# --------------------------------------------------------------------------------
# 9/10/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.923485     0.939222     0.884414   9/10/18       train            3625
# 0  0.997790     1.000000     0.000000   9/10/18        test               5
#
#    less_than_30
# 0          9000
# 0          2257
# --------------------------------------------------------------------------------
# 9/26/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.923674     0.939222     0.885124   9/26/18       train           3630
# 0  1.000000     1.000000     0.000000   9/26/18        test              0
#
#    less_than_30
# 0          9000
# 0          2145
# --------------------------------------------------------------------------------
# 10/2/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.919933     0.934556      0.88365   10/2/18       train            3627
# 0  0.998554     1.000000      0.00000   10/2/18        test               3
#
#    less_than_30
# 0          9000
# 0          2072
# --------------------------------------------------------------------------------
# 10/12/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.927135     0.940556     0.893445  10/12/18       train            3585
# 0  0.943438     0.957169     0.266667  10/12/18        test              45
#
#    less_than_30
# 0          9000
# 0          2218
# --------------------------------------------------------------------------------
# 10/27/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.928526     0.941222     0.896082  10/27/18       train            3522
# 0  0.913270     0.944056     0.342593  10/27/18        test             108
#
#    less_than_30
# 0          9000
# 0          2002
# --------------------------------------------------------------------------------
# 12/17/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.926994     0.942000     0.887859  12/17/18       train            3451
# 0  0.786091     0.806925     0.564246  12/17/18        test             179
#
#    less_than_30
# 0          9000
# 0          1906
# --------------------------------------------------------------------------------
# 12/22/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0   0.92766     0.943000     0.887699  12/22/18       train            3455
# 0   0.83274     0.849493     0.634286  12/22/18        test             175
#
#    less_than_30
# 0          9000
# 0          2073
# --------------------------------------------------------------------------------
# 2/24/19
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.926433     0.944222     0.878725   2/24/19       train            3356
# 0  0.876284     0.880698     0.843066   2/24/19        test             274
#
#    less_than_30
# 0          9000
# 0          2062
# --------------------------------------------------------------------------------
# CPU times: user 5min 31s, sys: 1.28 s, total: 5min 32s
# Wall time: 5min 33s

# %%
table2
# Out:
#     Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0   0.919002     0.933556     0.882920    1/7/17       train           3630
# 0   0.995406     0.995406     0.000000    1/7/17        test              0
# 0   0.923034     0.937667     0.886218    2/9/17       train           3577
# 0   0.939350     0.943725     0.773585    2/9/17        test             53
# 0   0.929275     0.948667     0.872774   2/13/17       train           3089
# ..       ...          ...          ...       ...         ...            ...
# 0   0.786091     0.806925     0.564246  12/17/18        test            179
# 0   0.927660     0.943000     0.887699  12/22/18       train           3455
# 0   0.832740     0.849493     0.634286  12/22/18        test            175
# 0   0.926433     0.944222     0.878725   2/24/19       train           3356
# 0   0.876284     0.880698     0.843066   2/24/19        test            274
#
#     less_than_30
# 0           9000
# 0           1959
# 0           9000
# 0           2008
# 0           9000
# ..           ...
# 0           1906
# 0           9000
# 0           2073
# 0           9000
# 0           2062
#
# [64 rows x 7 columns]

# %%
data.tail()
# Out:
#       Type        R1        R2  Pressure_reduced_to_MSL_.Pa..0.MSL  \
# 2331  WANT  0.098920  0.157647                          100027.320
# 2332  WANT  0.098133  0.156265                          100043.773
# 2333  WANT  0.098374  0.154478                          100029.609
# 2334  WANT  0.097222  0.153720                          100029.547
# 2335  WANT  0.094813  0.153293                          100049.734
#
#       Derived_radar_reflectivity_.dB..1.HYBL  \
# 2331                                     0.0
# 2332                                     0.0
# 2333                                     0.0
# 2334                                     0.0
# 2335                                     0.0
#
#       u.component_of_wind_.m.s..85000.ISBL  \
# 2331                                32.948
# 2332                                33.102
# 2333                                33.439
# 2334                                33.765
# 2335                                33.951
#
#       v.component_of_wind_.m.s..85000.ISBL  wind_speed_85000  \
# 2331                                -5.489         33.402093
# 2332                                -5.860         33.616692
# 2333                                -5.925         33.959864
# 2334                                -5.858         34.269394
# 2335                                -5.796         34.442184
#
#       wind_shear_85000  Wind_speed_.gust._.m.s..0.SFC  ...  veg_sfc  \
# 2331         23.859866                         37.742  ...   40.175
# 2332         24.105445                         38.260  ...   40.175
# 2333         24.255558                         39.137  ...   40.175
# 2334         24.277645                         40.062  ...   40.175
# 2335         24.231285                         40.566  ...   40.175
#
#       best_4_layer     ws_700  max_wind_speed  actual   less_30  greater_30  \
# 2331        21.381  17.640080       37.904880       1  0.775173    0.224827
# 2332        21.517  19.861816       46.457776       1  0.777900    0.222100
# 2333        21.800  22.217660       37.710496       1  0.778572    0.221428
# 2334        21.817  22.936901       39.071184       1  0.775179    0.224821
# 2335        21.817  23.463382       36.349808       1  0.772047    0.227953
#
#       pred     From  test_date
# 2331     0  Mesonet    2/24/19
# 2332     0  Mesonet    2/24/19
# 2333     0  Mesonet    2/24/19
# 2334     0  Mesonet    2/24/19
# 2335     0  Mesonet    2/24/19
#
# [5 rows x 27 columns]

# %%
#table2.to_csv('XGB_CLASS_greater_30_sample9000_stats.csv')

# %%
#data2.to_csv('XGB_CLASS_greater_30_sample9000_data.csv')
