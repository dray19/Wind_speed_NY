# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, precision_score, recall_score, f1_score, accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
from multiprocessing import Pool

# %% [markdown]
# ### Function used

# %%
def model_info(x, y, test_date, data_tested):
    cm = confusion_matrix(x,y)
    acc = accuracy_score(x,y)
    rec = recall_score(x,y)
    rec_0 = recall_score(x,y, pos_label=0)
    data = [{"Accuracy":acc,"Specificity":rec_0, "Sensitivity":rec}]
    df = pd.DataFrame(data)
    df['test_date'] = test_date
    df['data_tested'] = data_tested
    if len(x.value_counts()) == 1:
        l30 = x.value_counts()[0]
        df['greter_than_30'] = '0'
        df['less_than_30'] = l30
    else:
        g30 = x.value_counts()[1]
        l30 = x.value_counts()[0]
        df['greter_than_30'] = g30
        df['less_than_30'] = l30
    return (df)

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv("15min_dateset.csv")
df.drop('Unnamed: 0', inplace = True, axis = 1)
print(len(df['EXP'].unique()))
df.head(2)
# Out:
# 32
#                   Date  Type     from     EXP  jul_date  hour_angle  \
# 0  2017-01-07 06:00:00  ANDE  MESONET  1/7/17         7   -1.570795
# 1  2017-01-07 06:15:00  ANDE  MESONET  1/7/17         7   -1.505345
#
#    max_wind_speed  avg_wind_speed        R1        R2  ...  HYBL_one  \
# 0        2.332608        1.295893  2.630564  2.322274  ...  0.629230
# 1        1.555072        0.647947  2.055383  1.813005  ...  0.748575
#
#    HYBL_two  HYBL_three  HYBL_four  HYBL_five  diff_temp  geo_cbl  veg_sfc  \
# 0  0.903721    3.610055   5.011670   6.054984      0.739  -5000.0   40.293
# 1  1.493288    3.643217   5.232982   6.394255      1.050  -5000.0   40.293
#
#    best_4_layer     ws_700
# 0        23.757  16.787335
# 1        23.959  16.195689
#
# [2 rows x 27 columns]

# %% [markdown]
# ### Create a Column for Classification

# %%
df["max_th"] = np.where(df["max_wind_speed"] > 30, 1, 0 )
table = df["max_th"].value_counts()
total = table[1] + table[0]
print(table)
print('% greater than 30:', round(table[1]/total,3))
print('% less than 30:', round(table[0]/total,3))
# Out:
# 0    69019
# 1     3630
# Name: max_th, dtype: int64
# % greater than 30: 0.05
# % less than 30: 0.95

# %%
le = LabelEncoder()
df['from'] = le.fit_transform(df['from'])
df.head(2)
# Out:
#                   Date  Type  from     EXP  jul_date  hour_angle  \
# 0  2017-01-07 06:00:00  ANDE     1  1/7/17         7   -1.570795
# 1  2017-01-07 06:15:00  ANDE     1  1/7/17         7   -1.505345
#
#    max_wind_speed  avg_wind_speed        R1        R2  ...  HYBL_two  \
# 0        2.332608        1.295893  2.630564  2.322274  ...  0.903721
# 1        1.555072        0.647947  2.055383  1.813005  ...  1.493288
#
#    HYBL_three  HYBL_four  HYBL_five  diff_temp  geo_cbl  veg_sfc  \
# 0    3.610055   5.011670   6.054984      0.739  -5000.0   40.293
# 1    3.643217   5.232982   6.394255      1.050  -5000.0   40.293
#
#    best_4_layer     ws_700  max_th
# 0        23.757  16.787335       0
# 1        23.959  16.195689       0
#
# [2 rows x 28 columns]

# %% [markdown]
# ### Grid search best parameters

# %%
#X = df.drop(['max_wind_speed', 'Type', 'EXP','max_th','jul_date','hour_angle'.'avg_wind_speed'], 1)
#Y = df.max_th.values

# %%
#pram = {'max_depth' : [3,5,7,9],'n_estimators':[250 ,400,500], 'bootstrap' :[True, False],'min_samples_split' : [2, 5, 7]}

# %%
#clf = GridSearchCV(RandomForestClassifier(random_state=19, max_features = 'sqrt'), pram, cv=3,scoring='accuracy', n_jobs=-1, verbose=3)
#clf.fit(X,Y)
# Out:
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 216 out of 216 | elapsed: 26.9min finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='sqrt',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators='warn', n_jobs=None,
#                                               oob_score=False, random_state=19,
#                                               verbose=0, warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'bootstrap': [True, False], 'max_depth': [3, 5, 7, 9],
#                          'min_samples_split': [2, 5, 7],
#                          'n_estimators': [250, 400, 500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=3)

# %%
#clf.best_score_, clf.best_params_,clf.scorer_
# Out:
# (0.904293245605583,
#  {'bootstrap': False,
#   'max_depth': 3,
#   'min_samples_split': 2,
#   'n_estimators': 250},
#  make_scorer(accuracy_score))

# %% [markdown]
# ### Random Forest Model Non-resampling

# %%
def rf_model(x):
    test_1 = df[df.EXP == x]
    train_1 = df[df.EXP != x]
    
    train_1 = train_1.drop(['EXP','jul_date','hour_angle','avg_wind_speed'], axis = 1)
    test_1 = test_1.drop(['EXP','jul_date','hour_angle','avg_wind_speed'], axis = 1)
    
    x_train = train_1.drop('max_th', 1)
    x_train.drop(['Date','Type','max_wind_speed'], axis=1, inplace=True)
    y_train = train_1.max_th
    x_test = test_1.drop('max_th', 1)
    x_test_copy = x_test.copy()
    x_test.drop(['Date','Type','max_wind_speed'], axis=1, inplace=True)
    y_test = test_1.max_th
    
    model = RandomForestClassifier(n_estimators=250, bootstrap= False, max_depth = 3, max_features= 'sqrt', min_samples_split = 3,
                               random_state=19)
    model.fit(x_train, y_train)
    
    pred_train = model.predict(x_train)
    train_info = model_info(y_train, pred_train, x , "train")

    pred_test = model.predict(x_test)
    test_info = model_info(y_test, pred_test, x , "test")

    table = train_info.append(test_info)
    
    print(x)
    print(table)
    print("--" * 40)
    prod = model.predict_proba(x_test)
    prod_data = pd.DataFrame(prod, columns=["less_30","greater_30"])
    df4 = pd.DataFrame(y_test)
    df4 = df4.rename(columns={'max_th': 'actual'})
    df4 = df4.reset_index()
    df4.drop('index', axis=1, inplace=True)
    x_test_copy = x_test_copy.reset_index()
    x_test_copy.drop("index", axis=1, inplace=True)
    df5 = pd.concat([x_test_copy, df4, prod_data], axis=1)
    pred_df = pd.DataFrame(pred_test, columns=["pred"])
    df6 = pd.concat([df5, pred_df], axis=1)
    df6['From'] = np.where(df6['from'] == 1, 'Mesonet', 'ASOS')
    df6.drop('from', inplace=True, axis=1)
    df6['test_date'] = x
    return(table, df6)

# %%
# %%time
table = pd.DataFrame()
data = pd.DataFrame()
for i in df['EXP'].unique():
    t,d = rf_model(i)
    table = table.append(t)
    data = data.append(d)
# Out:
# 1/7/17
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.948649          1.0          0.0    1/7/17       train           3630
# 0  1.000000          1.0          0.0    1/7/17        test              0
#
#    less_than_30
# 0         67060
# 0          1959
# --------------------------------------------------------------------------------
# 2/9/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.949326          1.0          0.0    2/9/17       train            3577
# 0  0.974284          1.0          0.0    2/9/17        test              53
#
#    less_than_30
# 0         67011
# 0          2008
# --------------------------------------------------------------------------------
# 2/13/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.956303          1.0          0.0   2/13/17       train            3089
# 0  0.723556          1.0          0.0   2/13/17        test             541
#
#    less_than_30
# 0         67603
# 0          1416
# --------------------------------------------------------------------------------
# 2/25/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.949052          1.0          0.0   2/25/17       train            3599
# 0  0.984562          1.0          0.0   2/25/17        test              31
#
#    less_than_30
# 0         67042
# 0          1977
# --------------------------------------------------------------------------------
# 3/2/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.957423          1.0          0.0    3/2/17       train            3001
# 0  0.709469          1.0          0.0    3/2/17        test             629
#
#    less_than_30
# 0         67483
# 0          1536
# --------------------------------------------------------------------------------
# 3/14/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.951089          1.0          0.0   3/14/17       train            3449
# 0  0.915143          1.0          0.0   3/14/17        test             181
#
#    less_than_30
# 0         67067
# 0          1952
# --------------------------------------------------------------------------------
# 3/22/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.954856          1.0     0.008414   3/22/17       train            3209
# 0  0.805453          1.0     0.000000   3/22/17        test             421
#
#    less_than_30
# 0         67276
# 0          1743
# --------------------------------------------------------------------------------
# 6/19/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.949116          1.0     0.003069   6/19/17       train            3584
# 0  0.981070          1.0     0.000000   6/19/17        test              46
#
#    less_than_30
# 0         66635
# 0          2384
# --------------------------------------------------------------------------------
# 7/13/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.948382          1.0          0.0   7/13/17       train            3628
# 0  0.999154          1.0          0.0   7/13/17        test               2
#
#    less_than_30
# 0         66658
# 0          2361
# --------------------------------------------------------------------------------
# 10/29/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.949927          1.0          0.0  10/29/17       train            3519
# 0  0.953184          1.0          0.0  10/29/17        test             111
#
#    less_than_30
# 0         66759
# 0          2260
# --------------------------------------------------------------------------------
# 11/19/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.953579     0.999985     0.015119  11/19/17       train            3307
# 0  0.868966     1.000000     0.000000  11/19/17        test             323
#
#    less_than_30
# 0         66877
# 0          2142
# --------------------------------------------------------------------------------
# 12/9/17
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0   0.94823          1.0          0.0   12/9/17       train           3630
# 0   1.00000          1.0          0.0   12/9/17        test              0
#
#    less_than_30
# 0         66488
# 0          2531
# --------------------------------------------------------------------------------
# 1/4/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.951733          1.0          0.0    1/4/18       train            3387
# 0  0.901897          1.0          0.0    1/4/18        test             243
#
#    less_than_30
# 0         66785
# 0          2234
# --------------------------------------------------------------------------------
# 3/2/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.950825          1.0          0.0    3/2/18       train            3453
# 0  0.927160          1.0          0.0    3/2/18        test             177
#
#    less_than_30
# 0         66766
# 0          2253
# --------------------------------------------------------------------------------
# 3/7/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.948291          1.0          0.0    3/7/18       train            3626
# 0  0.998416          1.0          0.0    3/7/18        test               4
#
#    less_than_30
# 0         66497
# 0          2522
# --------------------------------------------------------------------------------
# 3/21/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.948377          1.0          0.0   3/21/18       train           3630
# 0  1.000000          1.0          0.0   3/21/18        test              0
#
#    less_than_30
# 0         66687
# 0          2332
# --------------------------------------------------------------------------------
# 5/15/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.948921          1.0     0.000279   5/15/18       train            3584
# 0  0.981622          1.0     0.000000   5/15/18        test              46
#
#    less_than_30
# 0         66562
# 0          2457
# --------------------------------------------------------------------------------
# 5/26/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.948324          1.0          0.0   5/26/18       train           3630
# 0  1.000000          1.0          0.0   5/26/18        test              0
#
#    less_than_30
# 0         66615
# 0          2404
# --------------------------------------------------------------------------------
# 6/13/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.948227          1.0          0.0   6/13/18       train            3629
# 0  0.999609          1.0          0.0   6/13/18        test               1
#
#    less_than_30
# 0         66465
# 0          2554
# --------------------------------------------------------------------------------
# 7/17/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.948513          1.0          0.0   7/17/18       train            3620
# 0  0.995726          1.0          0.0   7/17/18        test              10
#
#    less_than_30
# 0         66689
# 0          2330
# --------------------------------------------------------------------------------
# 7/21/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.948448          1.0          0.0   7/21/18       train            3621
# 0  0.996264          1.0          0.0   7/21/18        test               9
#
#    less_than_30
# 0         66619
# 0          2400
# --------------------------------------------------------------------------------
# 8/17/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.948592          1.0          0.0   8/17/18       train            3623
# 0  0.996780          1.0          0.0   8/17/18        test               7
#
#    less_than_30
# 0         66852
# 0          2167
# --------------------------------------------------------------------------------
# 9/4/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.948522          1.0          0.0    9/4/18       train           3630
# 0  1.000000          1.0          0.0    9/4/18        test              0
#
#    less_than_30
# 0         66886
# 0          2133
# --------------------------------------------------------------------------------
# 9/6/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.948533          1.0          0.0    9/6/18       train            3624
# 0  0.997315          1.0          0.0    9/6/18        test               6
#
#    less_than_30
# 0         66790
# 0          2229
# --------------------------------------------------------------------------------
# 9/10/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.948499          1.0          0.0   9/10/18       train            3625
# 0  0.997790          1.0          0.0   9/10/18        test               5
#
#    less_than_30
# 0         66762
# 0          2257
# --------------------------------------------------------------------------------
# 9/26/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.948514          1.0          0.0   9/26/18       train           3630
# 0  1.000000          1.0          0.0   9/26/18        test              0
#
#    less_than_30
# 0         66874
# 0          2145
# --------------------------------------------------------------------------------
# 10/2/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.948607          1.0          0.0   10/2/18       train            3627
# 0  0.998554          1.0          0.0   10/2/18        test               3
#
#    less_than_30
# 0         66947
# 0          2072
# --------------------------------------------------------------------------------
# 10/12/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.949507          1.0     0.008647  10/12/18       train            3585
# 0  0.980115          1.0     0.000000  10/12/18        test              45
#
#    less_than_30
# 0         66801
# 0          2218
# --------------------------------------------------------------------------------
# 10/27/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.950070          1.0          0.0  10/27/18       train            3522
# 0  0.948815          1.0          0.0  10/27/18        test             108
#
#    less_than_30
# 0         67017
# 0          2002
# --------------------------------------------------------------------------------
# 12/17/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.951590          1.0     0.010142  12/17/18       train            3451
# 0  0.914149          1.0     0.000000  12/17/18        test             179
#
#    less_than_30
# 0         67113
# 0          1906
# --------------------------------------------------------------------------------
# 12/22/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.950995          1.0     0.001447  12/22/18       train            3455
# 0  0.922153          1.0     0.000000  12/22/18        test             175
#
#    less_than_30
# 0         66946
# 0          2073
# --------------------------------------------------------------------------------
# 2/24/19
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.952271          1.0          0.0   2/24/19       train            3356
# 0  0.882705          1.0          0.0   2/24/19        test             274
#
#    less_than_30
# 0         66957
# 0          2062
# --------------------------------------------------------------------------------
# CPU times: user 13min 28s, sys: 4.62 s, total: 13min 32s
# Wall time: 12min 51s

# %%
table.head()
# Out:
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.948649          1.0          0.0    1/7/17       train           3630
# 0  1.000000          1.0          0.0    1/7/17        test              0
# 0  0.949326          1.0          0.0    2/9/17       train           3577
# 0  0.974284          1.0          0.0    2/9/17        test             53
# 0  0.956303          1.0          0.0   2/13/17       train           3089
#
#    less_than_30
# 0         67060
# 0          1959
# 0         67011
# 0          2008
# 0         67603

# %%
data.tail()
# Out:
#                      Date  Type  max_wind_speed        R1        R2  \
# 2331  2019-02-25 05:00:00  WANT       37.904880  0.098920  0.157647
# 2332  2019-02-25 05:15:00  WANT       46.457776  0.098133  0.156265
# 2333  2019-02-25 05:30:00  WANT       37.710496  0.098374  0.154478
# 2334  2019-02-25 05:45:00  WANT       39.071184  0.097222  0.153720
# 2335  2019-02-25 06:00:00  WANT       36.349808  0.094813  0.153293
#
#       Pressure_reduced_to_MSL_.Pa..0.MSL  \
# 2331                          100027.320
# 2332                          100043.773
# 2333                          100029.609
# 2334                          100029.547
# 2335                          100049.734
#
#       Derived_radar_reflectivity_.dB..1.HYBL  \
# 2331                                     0.0
# 2332                                     0.0
# 2333                                     0.0
# 2334                                     0.0
# 2335                                     0.0
#
#       u.component_of_wind_.m.s..85000.ISBL  \
# 2331                                32.948
# 2332                                33.102
# 2333                                33.439
# 2334                                33.765
# 2335                                33.951
#
#       v.component_of_wind_.m.s..85000.ISBL  wind_speed_85000  ...  geo_cbl  \
# 2331                                -5.489         33.402093  ...  -5000.0
# 2332                                -5.860         33.616692  ...  -5000.0
# 2333                                -5.925         33.959864  ...  -5000.0
# 2334                                -5.858         34.269394  ...  -5000.0
# 2335                                -5.796         34.442184  ...  -5000.0
#
#       veg_sfc  best_4_layer     ws_700  actual   less_30  greater_30  pred  \
# 2331   40.175        21.381  17.640080       1  0.841885    0.158115     0
# 2332   40.175        21.517  19.861816       1  0.841885    0.158115     0
# 2333   40.175        21.800  22.217660       1  0.841295    0.158705     0
# 2334   40.175        21.817  22.936901       1  0.838933    0.161067     0
# 2335   40.175        21.817  23.463382       1  0.838933    0.161067     0
#
#          From  test_date
# 2331  Mesonet    2/24/19
# 2332  Mesonet    2/24/19
# 2333  Mesonet    2/24/19
# 2334  Mesonet    2/24/19
# 2335  Mesonet    2/24/19
#
# [5 rows x 28 columns]

# %%
#table.to_csv('RF_CLASS_greater_30_no_sample_stats.csv')

# %%
#data.to_csv('RF_CLASS_greater_30_no_sample_data.csv')

# %% [markdown]
# ### Random Forest Model sampleling

# %%
def rf_model2(x):
    test_1 = df[df.EXP == x]
    train_1 = df[df.EXP != x]
    train_1 = train_1.drop(['EXP','jul_date','hour_angle','avg_wind_speed'], axis = 1)
    test_1 = test_1.drop(['EXP','jul_date','hour_angle','avg_wind_speed'], axis = 1)
    
    df_0 = train_1[train_1['max_th'] == 0]
    df_1 = train_1[train_1['max_th'] == 1]
    df_under = df_0.sample(9000 ,random_state=19)
    df_new = pd.concat([df_under, df_1], axis = 0)
    
    
    x_train = df_new.drop('max_th', 1)
    x_train.drop(['Date','Type','max_wind_speed'], axis=1, inplace=True)
    y_train = df_new.max_th
    x_test = test_1.drop('max_th', 1)
    x_test_copy = x_test.copy()
    x_test.drop(['Date','Type','max_wind_speed'], axis=1, inplace=True)
    y_test = test_1.max_th
    
    model = RandomForestClassifier(n_estimators=250, bootstrap= False, max_depth = 3, max_features= 'sqrt', min_samples_split = 3,
                               random_state=19)
    model.fit(x_train, y_train)
    
    pred_train = model.predict(x_train)
    train_info = model_info(y_train, pred_train, x , "train")

    pred_test = model.predict(x_test)
    test_info = model_info(y_test, pred_test, x , "test")

    table = train_info.append(test_info)
    
    print(x)
    print(table)
    print("--" * 40)
    prod = model.predict_proba(x_test)
    prod_data = pd.DataFrame(prod, columns=["less_30","greater_30"])
    df4 = pd.DataFrame(y_test)
    df4 = df4.rename(columns={'max_th': 'actual'})
    df4 = df4.reset_index()
    df4.drop('index', axis=1, inplace=True)
    x_test_copy = x_test_copy.reset_index()
    x_test_copy.drop("index", axis=1, inplace=True)
    df5 = pd.concat([x_test_copy, df4, prod_data], axis=1)
    pred_df = pd.DataFrame(pred_test, columns=["pred"])
    df6 = pd.concat([df5, pred_df], axis=1)
    df6['From'] = np.where(df6['from'] == 1, 'Mesonet', 'ASOS')
    df6.drop('from', inplace=True, axis=1)
    df6['test_date'] = x
    return(table, df6)

# %%
# %%time
table2 = pd.DataFrame()
data2 = pd.DataFrame()
for i in df['EXP'].unique():
    t,d = rf_model2(i)
    table2 = table2.append(t)
    data2 = data2.append(d)
# Out:
# 1/7/17
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.868250     0.898667     0.792837    1/7/17       train           3630
# 0  0.997958     0.997958     0.000000    1/7/17        test              0
#
#    less_than_30
# 0          9000
# 0          1959
# --------------------------------------------------------------------------------
# 2/9/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.872307     0.903556     0.793682    2/9/17       train            3577
# 0  0.928190     0.936753     0.603774    2/9/17        test              53
#
#    less_than_30
# 0          9000
# 0          2008
# --------------------------------------------------------------------------------
# 2/13/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.878650     0.919333     0.760117   2/13/17       train            3089
# 0  0.654573     0.584040     0.839187   2/13/17        test             541
#
#    less_than_30
# 0          9000
# 0          1416
# --------------------------------------------------------------------------------
# 2/25/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.878482     0.899778     0.825229   2/25/17       train            3599
# 0  0.922311     0.935255     0.096774   2/25/17        test              31
#
#    less_than_30
# 0          9000
# 0          1977
# --------------------------------------------------------------------------------
# 3/2/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.881927     0.919778     0.768411    3/2/17       train            3001
# 0  0.551501     0.450521     0.798092    3/2/17        test             629
#
#    less_than_30
# 0          9000
# 0          1536
# --------------------------------------------------------------------------------
# 3/14/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.871958     0.905778     0.783705   3/14/17       train            3449
# 0  0.842944     0.837090     0.906077   3/14/17        test             181
#
#    less_than_30
# 0          9000
# 0          1952
# --------------------------------------------------------------------------------
# 3/22/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.881727      0.91400     0.791212   3/22/17       train            3209
# 0  0.531423      0.47619     0.760095   3/22/17        test             421
#
#    less_than_30
# 0          9000
# 0          1743
# --------------------------------------------------------------------------------
# 6/19/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.875000     0.901556     0.808315   6/19/17       train            3584
# 0  0.977778     0.992869     0.195652   6/19/17        test              46
#
#    less_than_30
# 0          9000
# 0          2384
# --------------------------------------------------------------------------------
# 7/13/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.870843     0.899889     0.798787   7/13/17       train            3628
# 0  0.999154     1.000000     0.000000   7/13/17        test               2
#
#    less_than_30
# 0          9000
# 0          2361
# --------------------------------------------------------------------------------
# 10/29/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.875789     0.900000     0.813868  10/29/17       train            3519
# 0  0.741881     0.751327     0.549550  10/29/17        test             111
#
#    less_than_30
# 0          9000
# 0          2260
# --------------------------------------------------------------------------------
# 11/19/17
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.883806     0.915111     0.798609  11/19/17       train            3307
# 0  0.607708     0.577031     0.811146  11/19/17        test             323
#
#    less_than_30
# 0          9000
# 0          2142
# --------------------------------------------------------------------------------
# 12/9/17
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0   0.87015     0.897889     0.801377   12/9/17       train           3630
# 0   1.00000     1.000000     0.000000   12/9/17        test              0
#
#    less_than_30
# 0          9000
# 0          2531
# --------------------------------------------------------------------------------
# 1/4/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.876160     0.920111     0.759374    1/4/18       train            3387
# 0  0.920468     0.998657     0.201646    1/4/18        test             243
#
#    less_than_30
# 0          9000
# 0          2234
# --------------------------------------------------------------------------------
# 3/2/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.873765     0.906667     0.788010    3/2/18       train            3453
# 0  0.889300     0.917443     0.531073    3/2/18        test             177
#
#    less_than_30
# 0          9000
# 0          2253
# --------------------------------------------------------------------------------
# 3/7/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.870822     0.895667     0.809156    3/7/18       train            3626
# 0  0.993270     0.994449     0.250000    3/7/18        test               4
#
#    less_than_30
# 0          9000
# 0          2522
# --------------------------------------------------------------------------------
# 3/21/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.868725     0.887778     0.821488   3/21/18       train           3630
# 0  0.753859     0.753859     0.000000   3/21/18        test              0
#
#    less_than_30
# 0          9000
# 0          2332
# --------------------------------------------------------------------------------
# 5/15/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.873570     0.899667     0.808036   5/15/18       train            3584
# 0  0.981622     0.998372     0.086957   5/15/18        test              46
#
#    less_than_30
# 0          9000
# 0          2457
# --------------------------------------------------------------------------------
# 5/26/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0   0.87213     0.899444     0.804408   5/26/18       train           3630
# 0   1.00000     1.000000     0.000000   5/26/18        test              0
#
#    less_than_30
# 0          9000
# 0          2404
# --------------------------------------------------------------------------------
# 6/13/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.873466     0.900333     0.806834   6/13/18       train            3629
# 0  0.996477     0.996868     0.000000   6/13/18        test               1
#
#    less_than_30
# 0          9000
# 0          2554
# --------------------------------------------------------------------------------
# 7/17/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.871949     0.897111     0.809392   7/17/18       train            3620
# 0  0.995726     1.000000     0.000000   7/17/18        test              10
#
#    less_than_30
# 0          9000
# 0          2330
# --------------------------------------------------------------------------------
# 7/21/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.867839     0.895333     0.799503   7/21/18       train            3621
# 0  0.994188     0.996667     0.333333   7/21/18        test               9
#
#    less_than_30
# 0          9000
# 0          2400
# --------------------------------------------------------------------------------
# 8/17/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.872851     0.902111     0.800166   8/17/18       train            3623
# 0  0.996780     1.000000     0.000000   8/17/18        test               7
#
#    less_than_30
# 0          9000
# 0          2167
# --------------------------------------------------------------------------------
# 9/4/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.874188     0.905333      0.79697    9/4/18       train           3630
# 0  1.000000     1.000000      0.00000    9/4/18        test              0
#
#    less_than_30
# 0          9000
# 0          2133
# --------------------------------------------------------------------------------
# 9/6/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.872861        0.901      0.80298    9/6/18       train            3624
# 0  0.997315        1.000      0.00000    9/6/18        test               6
#
#    less_than_30
# 0          9000
# 0          2229
# --------------------------------------------------------------------------------
# 9/10/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.869545     0.898444     0.797793   9/10/18       train            3625
# 0  0.997790     1.000000     0.000000   9/10/18        test               5
#
#    less_than_30
# 0          9000
# 0          2257
# --------------------------------------------------------------------------------
# 9/26/18
#    Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0  0.873001     0.899222     0.807989   9/26/18       train           3630
# 0  1.000000     1.000000     0.000000   9/26/18        test              0
#
#    less_than_30
# 0          9000
# 0          2145
# --------------------------------------------------------------------------------
# 10/2/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.870753     0.896222     0.807554   10/2/18       train            3627
# 0  0.998554     1.000000     0.000000   10/2/18        test               3
#
#    less_than_30
# 0          9000
# 0          2072
# --------------------------------------------------------------------------------
# 10/12/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.876917     0.904889     0.806695  10/12/18       train            3585
# 0  0.909412     0.920649     0.355556  10/12/18        test              45
#
#    less_than_30
# 0          9000
# 0          2218
# --------------------------------------------------------------------------------
# 10/27/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.873023     0.900778     0.802101  10/27/18       train            3522
# 0  0.884360     0.911089     0.388889  10/27/18        test             108
#
#    less_than_30
# 0          9000
# 0          2002
# --------------------------------------------------------------------------------
# 12/17/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.876476     0.903000     0.807302  12/17/18       train            3451
# 0  0.762590     0.796957     0.396648  12/17/18        test             179
#
#    less_than_30
# 0          9000
# 0          1906
# --------------------------------------------------------------------------------
# 12/22/18
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.875632     0.903444     0.803184  12/22/18       train            3455
# 0  0.775356     0.796430     0.525714  12/22/18        test             175
#
#    less_than_30
# 0          9000
# 0          2073
# --------------------------------------------------------------------------------
# 2/24/19
#    Accuracy  Specificity  Sensitivity test_date data_tested  greter_than_30  \
# 0  0.873826     0.914778     0.764005   2/24/19       train            3356
# 0  0.853596     0.891853     0.565693   2/24/19        test             274
#
#    less_than_30
# 0          9000
# 0          2062
# --------------------------------------------------------------------------------
# CPU times: user 2min 32s, sys: 1.4 s, total: 2min 34s
# Wall time: 2min 20s

# %%
table2
# Out:
#     Accuracy  Specificity  Sensitivity test_date data_tested greter_than_30  \
# 0   0.868250     0.898667     0.792837    1/7/17       train           3630
# 0   0.997958     0.997958     0.000000    1/7/17        test              0
# 0   0.872307     0.903556     0.793682    2/9/17       train           3577
# 0   0.928190     0.936753     0.603774    2/9/17        test             53
# 0   0.878650     0.919333     0.760117   2/13/17       train           3089
# ..       ...          ...          ...       ...         ...            ...
# 0   0.762590     0.796957     0.396648  12/17/18        test            179
# 0   0.875632     0.903444     0.803184  12/22/18       train           3455
# 0   0.775356     0.796430     0.525714  12/22/18        test            175
# 0   0.873826     0.914778     0.764005   2/24/19       train           3356
# 0   0.853596     0.891853     0.565693   2/24/19        test            274
#
#     less_than_30
# 0           9000
# 0           1959
# 0           9000
# 0           2008
# 0           9000
# ..           ...
# 0           1906
# 0           9000
# 0           2073
# 0           9000
# 0           2062
#
# [64 rows x 7 columns]

# %%
#table2.to_csv('RF_CLASS_greater_30_sample10000_stats.csv')

# %%
#data2.to_csv('RF_CLASS_greater_30_sample10000_data.csv')
