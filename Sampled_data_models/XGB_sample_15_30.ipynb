# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor, DMatrix
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from collections import Counter

# %% [markdown]
# ### Laod Data

# %%
df = pd.read_csv("15min_dateset.csv")
df.drop('Unnamed: 0', inplace = True, axis = 1)
print(len(df['EXP'].unique()))
df.head()
# Out:
# 32
#                   Date  Type     from     EXP  jul_date  hour_angle  \
# 0  2017-01-07 06:00:00  ANDE  MESONET  1/7/17         7   -1.570795
# 1  2017-01-07 06:15:00  ANDE  MESONET  1/7/17         7   -1.505345
# 2  2017-01-07 06:30:00  ANDE  MESONET  1/7/17         7   -1.439895
# 3  2017-01-07 06:45:00  ANDE  MESONET  1/7/17         7   -1.374446
# 4  2017-01-07 07:00:00  ANDE  MESONET  1/7/17         7   -1.308996
#
#    max_wind_speed  avg_wind_speed        R1        R2  ...  HYBL_one  \
# 0        2.332608        1.295893  2.630564  2.322274  ...  0.629230
# 1        1.555072        0.647947  2.055383  1.813005  ...  0.748575
# 2        2.332608        1.360688  1.792587  1.671478  ...  1.154196
# 3        1.555072        0.453563  1.442889  1.352497  ...  2.183654
# 4        2.526992        1.360688  2.283417  1.677404  ...  2.407290
#
#    HYBL_two  HYBL_three  HYBL_four  HYBL_five  diff_temp  geo_cbl  veg_sfc  \
# 0  0.903721    3.610055   5.011670   6.054984      0.739  -5000.0   40.293
# 1  1.493288    3.643217   5.232982   6.394255      1.050  -5000.0   40.293
# 2  1.645343    3.346854   5.054551   6.395084      1.211  -5000.0   40.293
# 3  2.266223    3.550607   5.363623   6.869857      0.943  -5000.0   40.293
# 4  2.633109    3.692489   5.309871   6.783159      0.751  -5000.0   40.293
#
#    best_4_layer     ws_700
# 0        23.757  16.787335
# 1        23.959  16.195689
# 2        24.118  15.636587
# 3        24.220  16.767452
# 4        24.149  17.249375
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Functions Used

# %%
#### Clasification results
def model_info1(x, y, test_date, data_tested):
    cm = confusion_matrix(x,y)
    acc = accuracy_score(x,y)
    cm = confusion_matrix(x,y)
    if len(cm) > 1:
        hit = cm[1][1]
        false_alarms = cm[0][1]
        misses = cm[1][0]
        no_events = cm[0][0]
        csi = hit / (false_alarms + misses + hit)
        hit_rate = hit / (hit + misses)
        false_alarm_rate = false_alarms / (hit + false_alarms)
    else:
        hit = 0
        false_alarms = 0
        misses = 0
        no_events = cm[0][0]
        csi = 0
        hit_rate =0
        false_alarm_rate = 0
    data = [{"Accuracy":acc,"Hits":hit, "False Alarms":false_alarms, 'Misses':misses,'No Events': no_events, 'CSI':csi, 'Hit Rate':hit_rate, 'False Alarm Rate':false_alarm_rate}]
    df = pd.DataFrame(data)
    df['test_date'] = test_date
    df['data_tested'] = data_tested
    if len(Counter(x)) == 1:
        l30 = Counter(x)[0]
        df['greter_than_30_knots'] = '0'
        df['less_than_30_knots'] = l30
    else:
        g30 = Counter(x)[1]
        l30 = Counter(x)[0]
        df['greter_than_30_knots'] = g30
        df['less_than_30_knots'] = l30
    return (df)



### Regression results
def model_info2(x, y,test_date,data_tested):
    mae = mean_absolute_error(x,y)
    mse = mean_squared_error(x,y)
    r2 = r2_score(x,y)
    residual_0 = x - y
    res_0 = np.array(residual_0)
    res_mean = round(res_0.mean(),4)
    data = [{"MAE":mae ,"MSE":mse, 'Residual Mean':res_mean}]
    df = pd.DataFrame(data)
    df['test_date'] = test_date
    df['data_tested'] = data_tested
    return (df)

# %%
le = LabelEncoder()
df['from'] = le.fit_transform(df['from'])
df.tail(2)
# Out:
#                       Date  Type  from      EXP  jul_date  hour_angle  \
# 72647  2018-07-22 05:45:00  WBOU     1  7/21/18       203   -1.636245
# 72648  2018-07-22 06:00:00  WBOU     1  7/21/18       203   -1.570795
#
#        max_wind_speed  avg_wind_speed        R1        R2  ...  HYBL_one  \
# 72647       17.105792        8.552896  0.279731  0.693772  ...  9.634310
# 72648       17.105792       10.043173  0.231301  0.605321  ...  8.939975
#
#         HYBL_two  HYBL_three  HYBL_four  HYBL_five  diff_temp  geo_cbl  \
# 72647  16.364893   18.456569  21.401767  24.263238      3.607  554.661
# 72648  16.514877   18.701148  22.068564  24.935163      3.349  555.042
#
#        veg_sfc  best_4_layer    ws_700
# 72647   81.379         0.706  8.964475
# 72648   81.379         0.171  7.752404
#
# [2 rows x 27 columns]

# %%
df["max_th"] = np.where(df["max_wind_speed"] > 30, 2, np.where(df["max_wind_speed"] < 15, 0, 1))
df['max_th'].value_counts()
# Out:
# 0    44574
# 1    24445
# 2     3630
# Name: max_th, dtype: int64

# %% [markdown]
# ### XGB basic model no grid search

# %%
def xgb_model_basic(x): 
    test_1 = df[df.EXP == x]
    train_1 = df[df.EXP != x]

    train_1 = train_1.drop(['EXP', 'jul_date' ,'hour_angle', 'avg_wind_speed'], axis = 1)
    test_1 = test_1.drop(['EXP', 'jul_date' ,'hour_angle', 'avg_wind_speed'], axis = 1)

    df_0 = train_1[train_1['max_th'] == 0]
    df_1 = train_1[train_1['max_th'] == 1]
    df_2 = train_1[train_1['max_th'] == 2]

    df0_sample = df_0.sample(9000 ,random_state=19)
    df1_sample = df_1.sample(9000 ,random_state=19)
    df2_sample = df_2.sample(3000 ,random_state=19)

    df_new = pd.concat([df0_sample, df1_sample, df2_sample], axis = 0)

    x_train = df_new.drop('max_wind_speed', 1)
    x_train.drop(['Date','Type','max_th'], axis=1, inplace=True)
    y_train = df_new.max_wind_speed
    x_test = test_1.drop('max_wind_speed', 1)
    x_test_copy = x_test.copy()
    x_test.drop(['Date','Type','max_th'], axis=1, inplace=True)
    y_test = test_1.max_wind_speed


    model = XGBRegressor(booster='gbtree', objective='reg:squarederror',random_state = 19)
    model.fit(x_train, y_train)

    pred_train = model.predict(x_train)
    train_info = model_info2(y_train, pred_train, x , "train")

    y_train30 = np.where(y_train > 30, 1, 0 )
    pred_train30 = np.where(pred_train > 30, 1, 0 )
    train_info2 = model_info1(y_train30, pred_train30, x,'train')

    pred_test = model.predict(x_test)
    test_info = model_info2(y_test, pred_test, x , "test")

    y_test30 = np.where(y_test > 30, 1, 0 )
    pred_test30 = np.where(pred_test > 30, 1, 0 )
    test_info2 = model_info1(y_test30, pred_test30, x,'test')

    table = train_info.append(test_info)
    table2 = train_info2.append(test_info2)
    print(x)
    print(table)
    print("==" *10)
    print(table2)
    print('--' * 40)

    df_class = pd.DataFrame(pred_test30, columns=['Class_results'])
    df_class['Class_results'] = np.where(df_class['Class_results'] == 1, 'Greater than 30 knots', 'Less than 30 knots')
    df_class = df_class.reset_index()
    df_class.drop('index', axis=1, inplace=True)
    df4 = pd.DataFrame(y_test)
    df4 = df4.rename(columns={'max_wind_speed': 'actual'})
    df4 = df4.reset_index()
    df4.drop('index', axis=1, inplace=True)
    x_test_copy = x_test_copy.reset_index()
    x_test_copy.drop("index", axis=1, inplace=True)
    df5 = pd.concat([x_test_copy, df4, df_class], axis=1)
    pred_df = pd.DataFrame(pred_test, columns=["pred"])
    df6 = pd.concat([df5, pred_df], axis=1)
    df6['From'] = np.where(df6['from'] == 1, 'Mesonet', 'ASOS')
    df6.drop(['from', 'max_th'], inplace=True, axis=1)
    df6['test_date'] = x
    return(table, table2, df6)

# %%
table = pd.DataFrame()
table_class = pd.DataFrame()
data = pd.DataFrame()
for i in df['EXP'].unique():
    t,tc,d = xgb_model_basic(i)
    table = table.append(t)
    table_class = table_class.append(tc)
    data = data.append(d)
# Out:
# 1/7/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.837926  25.355370         0.0006    1/7/17       train
# 0  2.671488  11.408716         0.7114    1/7/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.911762  1438           291    1562      17709  0.436949  0.479333
# 0  1.000000     0             0       0       1959  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.168305    1/7/17       train                 3000
# 0          0.000000    1/7/17        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                1959
# --------------------------------------------------------------------------------
# 2/9/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.833782  25.200074         0.0007    2/9/17       train
# 0  3.841905  23.043714        -1.7483    2/9/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.911524  1444           302    1556      17698  0.437311  0.481333
# 0  0.968947    18            29      35       1979  0.219512  0.339623
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.172967    2/9/17       train                  3000
# 0          0.617021    2/9/17        test                    53
#
#    less_than_30_knots
# 0               18000
# 0                2008
# --------------------------------------------------------------------------------
# 2/13/17
#         MAE       MSE  Residual Mean test_date data_tested
# 0  3.803090  24.79434         0.0007   2/13/17       train
# 0  5.510579  47.90574         1.6116   2/13/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.911524  1417           275    1583      17725  0.432672  0.472333
# 0  0.787430   158            33     383       1383  0.275261  0.292052
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.162530   2/13/17       train                  3000
# 0          0.172775   2/13/17        test                   541
#
#    less_than_30_knots
# 0               18000
# 0                1416
# --------------------------------------------------------------------------------
# 2/25/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.820303  24.873273         0.0006   2/25/17       train
# 0  4.536429  32.268627        -1.1813   2/25/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0   0.91019  1416           302    1584      17698  0.428831     0.472
# 0   0.98257     0             4      31       1973  0.000000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.175786   2/25/17       train                  3000
# 0          1.000000   2/25/17        test                    31
#
#    less_than_30_knots
# 0               18000
# 0                1977
# --------------------------------------------------------------------------------
# 3/2/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.836402  25.468138         0.0006    3/2/17       train
# 0  4.659851  34.211659         1.2587    3/2/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.912429  1436           275    1564      17725  0.438473  0.478667
# 0  0.790762   229            53     400       1483  0.335777  0.364070
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.160725    3/2/17       train                  3000
# 0          0.187943    3/2/17        test                   629
#
#    less_than_30_knots
# 0               18000
# 0                1536
# --------------------------------------------------------------------------------
# 3/14/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.796221  24.821650         0.0007   3/14/17       train
# 0  3.711668  23.408129        -1.3191   3/14/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.912286  1457           299    1543      17701  0.441649  0.485667
# 0  0.918894   127           119      54       1833  0.423333  0.701657
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.170273   3/14/17       train                  3000
# 0          0.483740   3/14/17        test                   181
#
#    less_than_30_knots
# 0               18000
# 0                1952
# --------------------------------------------------------------------------------
# 3/22/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.812042  25.074489         0.0005   3/22/17       train
# 0  5.539398  45.752869        -2.6382   3/22/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.913952  1479           286    1521      17714  0.450091  0.493000
# 0  0.774030   258           326     163       1417  0.345382  0.612827
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.162040   3/22/17       train                  3000
# 0          0.558219   3/22/17        test                   421
#
#    less_than_30_knots
# 0               18000
# 0                1743
# --------------------------------------------------------------------------------
# 6/19/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.822965  24.859853         0.0007   6/19/17       train
# 0  3.677698  24.446202        -0.2969   6/19/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.911714  1441           295    1559      17705  0.437329  0.480333
# 0  0.980247     1             3      45       2381  0.020408  0.021739
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.169931   6/19/17       train                  3000
# 0          0.750000   6/19/17        test                    46
#
#    less_than_30_knots
# 0               18000
# 0                2384
# --------------------------------------------------------------------------------
# 7/13/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.811149  24.981120         0.0007   7/13/17       train
# 0  3.399815  18.084509        -1.3990   7/13/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.911571  1448           305    1552      17695  0.438124  0.482667
# 0  0.999154     0             0       2       2361  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.173987   7/13/17       train                  3000
# 0               NaN   7/13/17        test                     2
#
#    less_than_30_knots
# 0               18000
# 0                2361
# --------------------------------------------------------------------------------
# 10/29/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.767769  24.250690         0.0006  10/29/17       train
# 0  6.965487  75.055267        -3.5314  10/29/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.916619  1559           310    1441      17690  0.470997  0.519667
# 0  0.945171    23            42      88       2218  0.150327  0.207207
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.165864  10/29/17       train                  3000
# 0          0.646154  10/29/17        test                   111
#
#    less_than_30_knots
# 0               18000
# 0                2260
# --------------------------------------------------------------------------------
# 11/19/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.793668  24.796213         0.0007  11/19/17       train
# 0  6.008648  53.046954        -3.3703  11/19/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.915476  1525           300    1475      17700  0.462121  0.508333
# 0  0.871805    66            59     257       2083  0.172775  0.204334
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.164384  11/19/17       train                  3000
# 0          0.472000  11/19/17        test                   323
#
#    less_than_30_knots
# 0               18000
# 0                2142
# --------------------------------------------------------------------------------
# 12/9/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.836094  25.262697         0.0008   12/9/17       train
# 0  2.332064   7.812781        -1.2583   12/9/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.910714  1471           346    1529      17654  0.439629  0.490333
# 0  1.000000     0             0       0       2531  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.190424   12/9/17       train                 3000
# 0          0.000000   12/9/17        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2531
# --------------------------------------------------------------------------------
# 1/4/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.799329  24.919283         0.0007    1/4/18       train
# 0  4.147786  28.536782         1.1610    1/4/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.913857  1471           280    1529      17720  0.448476  0.490333
# 0  0.916431    37             1     206       2233  0.151639  0.152263
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.159909    1/4/18       train                  3000
# 0          0.026316    1/4/18        test                   243
#
#    less_than_30_knots
# 0               18000
# 0                2234
# --------------------------------------------------------------------------------
# 3/2/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.764452  24.317116         0.0006    3/2/18       train
# 0  5.258521  44.062296        -2.6051    3/2/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.913810  1510           320    1490      17680  0.454819  0.503333
# 0  0.916872    37            62     140       2191  0.154812  0.209040
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.174863    3/2/18       train                  3000
# 0          0.626263    3/2/18        test                   177
#
#    less_than_30_knots
# 0               18000
# 0                2253
# --------------------------------------------------------------------------------
# 3/7/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.819203  25.194299         0.0007    3/7/18       train
# 0  3.324247  17.041241        -0.6568    3/7/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.910429  1430           311    1570      17689  0.431894  0.476667
# 0  0.997229     0             3       4       2519  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.178633    3/7/18       train                  3000
# 0          1.000000    3/7/18        test                     4
#
#    less_than_30_knots
# 0               18000
# 0                2522
# --------------------------------------------------------------------------------
# 3/21/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.820118  24.916963         0.0007   3/21/18       train
# 0  6.411933  57.248536        -5.8480   3/21/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.912238  1459           302    1541      17698  0.441853  0.486333
# 0  0.968268     0            74       0       2258  0.000000       NaN
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.171493   3/21/18       train                 3000
# 0          1.000000   3/21/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2332
# --------------------------------------------------------------------------------
# 5/15/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.795099  24.422887         0.0006   5/15/18       train
# 0  4.430304  36.342133        -2.2210   5/15/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.911095  1444           311    1556      17689  0.436122  0.481333
# 0  0.981223     0             1      46       2456  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.177208   5/15/18       train                  3000
# 0          1.000000   5/15/18        test                    46
#
#    less_than_30_knots
# 0               18000
# 0                2457
# --------------------------------------------------------------------------------
# 5/26/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.823752  25.098885         0.0008   5/26/18       train
# 0  3.878053  23.791142        -2.7740   5/26/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.912429  1467           306    1533      17694  0.443739     0.489
# 0  1.000000     0             0       0       2404  0.000000     0.000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.172589   5/26/18       train                 3000
# 0          0.000000   5/26/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2404
# --------------------------------------------------------------------------------
# 6/13/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.799471  24.881508         0.0007   6/13/18       train
# 0  3.838796  24.365293        -2.0360   6/13/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.911048  1455           323    1545      17677  0.437857     0.485
# 0  0.999609     0             0       1       2554  0.000000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.181665   6/13/18       train                  3000
# 0               NaN   6/13/18        test                     1
#
#    less_than_30_knots
# 0               18000
# 0                2554
# --------------------------------------------------------------------------------
# 7/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.830947  25.068402         0.0006   7/17/18       train
# 0  3.141823  19.228031        -0.4198   7/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.911429  1463           323    1537      17677  0.440265  0.487667
# 0  0.995726     0             0      10       2330  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.180851   7/17/18       train                  3000
# 0               NaN   7/17/18        test                    10
#
#    less_than_30_knots
# 0               18000
# 0                2330
# --------------------------------------------------------------------------------
# 7/21/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.818147  25.023298         0.0006   7/21/18       train
# 0  3.781113  23.060791         0.5530   7/21/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.913952  1474           281    1526      17719  0.449253  0.491333
# 0  0.994604     2             6       7       2394  0.133333  0.222222
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.160114   7/21/18       train                  3000
# 0          0.750000   7/21/18        test                     9
#
#    less_than_30_knots
# 0               18000
# 0                2400
# --------------------------------------------------------------------------------
# 8/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.829764  25.087480         0.0007   8/17/18       train
# 0  3.492477  22.189151        -0.2576   8/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.912476  1455           293    1545      17707  0.441846     0.485
# 0  0.996780     0             0       7       2167  0.000000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0           0.16762   8/17/18       train                  3000
# 0               NaN   8/17/18        test                     7
#
#    less_than_30_knots
# 0               18000
# 0                2167
# --------------------------------------------------------------------------------
# 9/4/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.836855  25.160043         0.0008    9/4/18       train
# 0  2.234856   7.470884        -0.9723    9/4/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0   0.91281  1481           312    1519      17688  0.447162  0.493667
# 0   1.00000     0             0       0       2133  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0           0.17401    9/4/18       train                 3000
# 0           0.00000    9/4/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2133
# --------------------------------------------------------------------------------
# 9/6/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.815609  24.843172         0.0007    9/6/18       train
# 0  2.923043  17.180520         0.6967    9/6/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.911714  1448           302    1552      17698  0.438522  0.482667
# 0  0.997315     0             0       6       2229  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.172571    9/6/18       train                  3000
# 0               NaN    9/6/18        test                     6
#
#    less_than_30_knots
# 0               18000
# 0                2229
# --------------------------------------------------------------------------------
# 9/10/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.820368  24.979088         0.0006   9/10/18       train
# 0  3.273048  18.021679         0.7050   9/10/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.912762  1454           286    1546      17714  0.442483  0.484667
# 0  0.997790     0             0       5       2257  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.164368   9/10/18       train                  3000
# 0               NaN   9/10/18        test                     5
#
#    less_than_30_knots
# 0               18000
# 0                2257
# --------------------------------------------------------------------------------
# 9/26/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.821990  25.123424         0.0007   9/26/18       train
# 0  3.445276  19.238903         0.2637   9/26/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.911429  1453           313    1547      17687  0.438575  0.484333
# 0  1.000000     0             0       0       2145  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.177237   9/26/18       train                 3000
# 0          0.000000   9/26/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2145
# --------------------------------------------------------------------------------
# 10/2/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.811719  24.901863         0.0006   10/2/18       train
# 0  4.153027  27.609099        -1.8377   10/2/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.912381  1456           296    1544      17704  0.441748  0.485333
# 0  0.998554     0             0       3       2072  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0           0.16895   10/2/18       train                  3000
# 0               NaN   10/2/18        test                     3
#
#    less_than_30_knots
# 0               18000
# 0                2072
# --------------------------------------------------------------------------------
# 10/12/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.815009  24.989788         0.0008  10/12/18       train
# 0  4.122165  26.206507        -1.4484  10/12/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.914810  1497           286    1503      17714  0.455569     0.499
# 0  0.976138     9            18      36       2200  0.142857     0.200
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.160404  10/12/18       train                  3000
# 0          0.666667  10/12/18        test                    45
#
#    less_than_30_knots
# 0               18000
# 0                2218
# --------------------------------------------------------------------------------
# 10/27/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.792976  24.675816         0.0004  10/27/18       train
# 0  4.039625  26.605257        -1.0154  10/27/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.912429  1484           323    1516      17677  0.446584  0.494667
# 0  0.954028    14             3      94       1999  0.126126  0.129630
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.178749  10/27/18       train                  3000
# 0          0.176471  10/27/18        test                   108
#
#    less_than_30_knots
# 0               18000
# 0                2002
# --------------------------------------------------------------------------------
# 12/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.827024  24.940525         0.0005  12/17/18       train
# 0  4.477930  32.497019        -0.4962  12/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.914238  1518           319    1482      17681  0.457367  0.506000
# 0  0.914149    20            20     159       1886  0.100503  0.111732
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.173653  12/17/18       train                  3000
# 0          0.500000  12/17/18        test                   179
#
#    less_than_30_knots
# 0               18000
# 0                1906
# --------------------------------------------------------------------------------
# 12/22/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.834998  25.353242         0.0007  12/22/18       train
# 0  4.232008  28.330733        -0.4697  12/22/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.915048  1520           304    1480      17696  0.460048  0.506667
# 0  0.924822    47            41     128       2032  0.217593  0.268571
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.166667  12/22/18       train                  3000
# 0          0.465909  12/22/18        test                   175
#
#    less_than_30_knots
# 0               18000
# 0                2073
# --------------------------------------------------------------------------------
# 2/24/19
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.778554  24.404144         0.0007   2/24/19       train
# 0  5.368712  44.955474        -2.3204   2/24/19        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.912619  1460           295    1540      17705  0.443096  0.486667
# 0  0.897688    79            44     195       2018  0.248428  0.288321
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.168091   2/24/19       train                  3000
# 0          0.357724   2/24/19        test                   274
#
#    less_than_30_knots
# 0               18000
# 0                2062
# --------------------------------------------------------------------------------

# %%
#table.to_csv('XGB_basic_regression_results.csv')
table[table['data_tested'] == 'test']
# Out:
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.671488  11.408716         0.7114    1/7/17        test
# 0  3.841905  23.043714        -1.7483    2/9/17        test
# 0  5.510579  47.905740         1.6116   2/13/17        test
# 0  4.536429  32.268627        -1.1813   2/25/17        test
# 0  4.659851  34.211659         1.2587    3/2/17        test
# 0  3.711668  23.408129        -1.3191   3/14/17        test
# 0  5.539398  45.752869        -2.6382   3/22/17        test
# 0  3.677698  24.446202        -0.2969   6/19/17        test
# 0  3.399815  18.084509        -1.3990   7/13/17        test
# 0  6.965487  75.055267        -3.5314  10/29/17        test
# 0  6.008648  53.046954        -3.3703  11/19/17        test
# 0  2.332064   7.812781        -1.2583   12/9/17        test
# 0  4.147786  28.536782         1.1610    1/4/18        test
# 0  5.258521  44.062296        -2.6051    3/2/18        test
# 0  3.324247  17.041241        -0.6568    3/7/18        test
# 0  6.411933  57.248536        -5.8480   3/21/18        test
# 0  4.430304  36.342133        -2.2210   5/15/18        test
# 0  3.878053  23.791142        -2.7740   5/26/18        test
# 0  3.838796  24.365293        -2.0360   6/13/18        test
# 0  3.141823  19.228031        -0.4198   7/17/18        test
# 0  3.781113  23.060791         0.5530   7/21/18        test
# 0  3.492477  22.189151        -0.2576   8/17/18        test
# 0  2.234856   7.470884        -0.9723    9/4/18        test
# 0  2.923043  17.180520         0.6967    9/6/18        test
# 0  3.273048  18.021679         0.7050   9/10/18        test
# 0  3.445276  19.238903         0.2637   9/26/18        test
# 0  4.153027  27.609099        -1.8377   10/2/18        test
# 0  4.122165  26.206507        -1.4484  10/12/18        test
# 0  4.039625  26.605257        -1.0154  10/27/18        test
# 0  4.477930  32.497019        -0.4962  12/17/18        test
# 0  4.232008  28.330733        -0.4697  12/22/18        test
# 0  5.368712  44.955474        -2.3204   2/24/19        test

# %%
#table_class.to_csv('XGB_basic_classfication_results.csv')
table_class[table_class['data_tested'] == 'test']
# Out:
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  1.000000     0             0       0       1959  0.000000  0.000000
# 0  0.968947    18            29      35       1979  0.219512  0.339623
# 0  0.787430   158            33     383       1383  0.275261  0.292052
# 0  0.982570     0             4      31       1973  0.000000  0.000000
# 0  0.790762   229            53     400       1483  0.335777  0.364070
# 0  0.918894   127           119      54       1833  0.423333  0.701657
# 0  0.774030   258           326     163       1417  0.345382  0.612827
# 0  0.980247     1             3      45       2381  0.020408  0.021739
# 0  0.999154     0             0       2       2361  0.000000  0.000000
# 0  0.945171    23            42      88       2218  0.150327  0.207207
# 0  0.871805    66            59     257       2083  0.172775  0.204334
# 0  1.000000     0             0       0       2531  0.000000  0.000000
# 0  0.916431    37             1     206       2233  0.151639  0.152263
# 0  0.916872    37            62     140       2191  0.154812  0.209040
# 0  0.997229     0             3       4       2519  0.000000  0.000000
# 0  0.968268     0            74       0       2258  0.000000       NaN
# 0  0.981223     0             1      46       2456  0.000000  0.000000
# 0  1.000000     0             0       0       2404  0.000000  0.000000
# 0  0.999609     0             0       1       2554  0.000000  0.000000
# 0  0.995726     0             0      10       2330  0.000000  0.000000
# 0  0.994604     2             6       7       2394  0.133333  0.222222
# 0  0.996780     0             0       7       2167  0.000000  0.000000
# 0  1.000000     0             0       0       2133  0.000000  0.000000
# 0  0.997315     0             0       6       2229  0.000000  0.000000
# 0  0.997790     0             0       5       2257  0.000000  0.000000
# 0  1.000000     0             0       0       2145  0.000000  0.000000
# 0  0.998554     0             0       3       2072  0.000000  0.000000
# 0  0.976138     9            18      36       2200  0.142857  0.200000
# 0  0.954028    14             3      94       1999  0.126126  0.129630
# 0  0.914149    20            20     159       1886  0.100503  0.111732
# 0  0.924822    47            41     128       2032  0.217593  0.268571
# 0  0.897688    79            44     195       2018  0.248428  0.288321
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.000000    1/7/17        test                    0
# 0          0.617021    2/9/17        test                   53
# 0          0.172775   2/13/17        test                  541
# 0          1.000000   2/25/17        test                   31
# 0          0.187943    3/2/17        test                  629
# 0          0.483740   3/14/17        test                  181
# 0          0.558219   3/22/17        test                  421
# 0          0.750000   6/19/17        test                   46
# 0               NaN   7/13/17        test                    2
# 0          0.646154  10/29/17        test                  111
# 0          0.472000  11/19/17        test                  323
# 0          0.000000   12/9/17        test                    0
# 0          0.026316    1/4/18        test                  243
# 0          0.626263    3/2/18        test                  177
# 0          1.000000    3/7/18        test                    4
# 0          1.000000   3/21/18        test                    0
# 0          1.000000   5/15/18        test                   46
# 0          0.000000   5/26/18        test                    0
# 0               NaN   6/13/18        test                    1
# 0               NaN   7/17/18        test                   10
# 0          0.750000   7/21/18        test                    9
# 0               NaN   8/17/18        test                    7
# 0          0.000000    9/4/18        test                    0
# 0               NaN    9/6/18        test                    6
# 0               NaN   9/10/18        test                    5
# 0          0.000000   9/26/18        test                    0
# 0               NaN   10/2/18        test                    3
# 0          0.666667  10/12/18        test                   45
# 0          0.176471  10/27/18        test                  108
# 0          0.500000  12/17/18        test                  179
# 0          0.465909  12/22/18        test                  175
# 0          0.357724   2/24/19        test                  274
#
#    less_than_30_knots
# 0                1959
# 0                2008
# 0                1416
# 0                1977
# 0                1536
# 0                1952
# 0                1743
# 0                2384
# 0                2361
# 0                2260
# 0                2142
# 0                2531
# 0                2234
# 0                2253
# 0                2522
# 0                2332
# 0                2457
# 0                2404
# 0                2554
# 0                2330
# 0                2400
# 0                2167
# 0                2133
# 0                2229
# 0                2257
# 0                2145
# 0                2072
# 0                2218
# 0                2002
# 0                1906
# 0                2073
# 0                2062

# %%
#data.to_csv('XGB_basic_data_results.csv')
data.head(2)
# Out:
#                   Date  Type        R1        R2  \
# 0  2017-01-07 06:00:00  ANDE  2.630564  2.322274
# 1  2017-01-07 06:15:00  ANDE  2.055383  1.813005
#
#    Pressure_reduced_to_MSL_.Pa..0.MSL  Derived_radar_reflectivity_.dB..1.HYBL  \
# 0                            102879.7                                     0.0
# 1                            102951.0                                     0.0
#
#    u.component_of_wind_.m.s..85000.ISBL  v.component_of_wind_.m.s..85000.ISBL  \
# 0                                 5.447                                -1.457
# 1                                 5.629                                -1.464
#
#    wind_speed_85000  wind_shear_85000  ...  diff_temp  geo_cbl  veg_sfc  \
# 0          5.638498          5.269992  ...      0.739  -5000.0   40.293
# 1          5.816265          5.773324  ...      1.050  -5000.0   40.293
#
#    best_4_layer     ws_700    actual       Class_results      pred     From  \
# 0        23.757  16.787335  2.332608  Less than 30 knots  5.746608  Mesonet
# 1        23.959  16.195689  1.555072  Less than 30 knots  5.746608  Mesonet
#
#    test_date
# 0     1/7/17
# 1     1/7/17
#
# [2 rows x 26 columns]

# %% [markdown]
# ### Grid Search Model

# %%
# df_0 = df2[df2['max_th'] == 0]
# df_1 = df2[df2['max_th'] == 1]
# df_2 = df2[df2['max_th'] == 2]

# df0_sample = df_0.sample(9000 ,random_state=19)
# df1_sample = df_1.sample(9000 ,random_state=19)
# df2_sample = df_2.sample(3000 ,random_state=19)

# df_gs = pd.concat([df0_sample, df1_sample, df2_sample], axis = 0)
# df_gs['max_th'].value_counts()
# Out:
# 1    9000
# 0    9000
# 2    3000
# Name: max_th, dtype: int64

# %%
# X = df_gs.drop(['Date','max_wind_speed', 'Type', 'EXP', 'max_th'], 1)
# Y = df_gs.max_wind_speed.values
# X
# Out:
#        from          R1          R2  Pressure_reduced_to_MSL_.Pa..0.MSL  \
# 10628     1    3.261219    6.132343                          102305.945
# 9344      1    0.152229    0.247941                          100969.600
# 56227     1    0.318725    0.382697                          100941.227
# 70523     1    7.627781    3.370534                          100430.800
# 48479     1  168.072532  118.652089                          101041.789
# ...     ...         ...         ...                                 ...
# 68215     1    1.037844    1.485693                           99718.380
# 48516     1    0.256680    0.386990                           99734.828
# 5065      1    0.662720    0.743379                           98702.180
# 41001     0    0.012512    0.019735                          100375.700
# 69485     1   -0.021828   -0.074405                          100008.836
#
#        Derived_radar_reflectivity_.dB..1.HYBL  \
# 10628                                   0.000
# 9344                                   33.099
# 56227                                   0.000
# 70523                                  27.962
# 48479                                   0.000
# ...                                       ...
# 68215                                  27.139
# 48516                                  17.453
# 5065                                   33.386
# 41001                                   0.000
# 69485                                   0.000
#
#        u.component_of_wind_.m.s..85000.ISBL  \
# 10628                                 7.229
# 9344                                -18.893
# 56227                                15.297
# 70523                                -8.825
# 48479                                 6.342
# ...                                     ...
# 68215                               -13.345
# 48516                                -4.688
# 5065                                -30.792
# 41001                                25.212
# 69485                                14.596
#
#        v.component_of_wind_.m.s..85000.ISBL  wind_speed_85000  \
# 10628                                -2.143          7.539953
# 9344                                 -8.557         20.740485
# 56227                                 4.152         15.850467
# 70523                               -11.532         14.521283
# 48479                                -0.381          6.353434
# ...                                     ...               ...
# 68215                               -17.285         21.837130
# 48516                                10.497         11.496276
# 5065                                -20.424         36.949791
# 41001                                 0.160         25.212508
# 69485                               -11.863         18.808880
#
#        wind_shear_85000  Wind_speed_.gust._.m.s..0.SFC  HYBL_one   HYBL_two  \
# 10628         11.683057                         13.157  4.774199   5.474310
# 9344          12.970719                         35.733  8.706624  13.847472
# 56227         11.993877                         18.805  5.420390   7.235121
# 70523         13.937777                         23.745  1.787987   4.414027
# 48479          3.322680                          6.390  3.299620   3.346181
# ...                 ...                            ...       ...        ...
# 68215         15.755341                         35.936  8.856065  17.014168
# 48516         18.281077                         35.772  9.059464  15.681797
# 5065          31.360209                         47.098  9.966333  21.252886
# 41001         16.084006                         31.691  9.129168  19.528904
# 69485         12.835594                         26.831  6.623413  11.400766
#
#        HYBL_three  HYBL_four  HYBL_five  diff_temp   geo_cbl  veg_sfc  \
# 10628    7.426896   8.629481   7.586525      0.079  9613.756   87.831
# 9344    17.020268  19.371065  21.503364     -1.993  2451.432   36.072
# 56227    8.691705  10.875789  13.237866     -3.119 -5000.000   86.181
# 70523   10.467418  13.408971  14.921248      0.387   496.275   38.977
# 48479    4.309025   6.146063   7.883806      0.485  5767.350   44.053
# ...           ...        ...        ...        ...       ...      ...
# 68215   18.759977  20.652048  22.376745     -3.191   474.611   43.724
# 48516   18.568731  20.858800  22.640065      3.231   266.416   41.801
# 5065    23.848851  26.730762  29.941884     -0.986   559.418   41.206
# 41001   22.060336  23.619324  24.663153     -5.191 -5000.000   32.040
# 69485   13.080156  14.508165  15.961644     -5.882 -5000.000   44.291
#
#        best_4_layer     ws_700
# 10628        -0.913   2.643295
# 9344          9.649  13.108330
# 56227        -0.045   2.921928
# 70523        17.013  14.884441
# 48479        18.313  16.078714
# ...             ...        ...
# 68215        18.400  20.115060
# 48516        -0.042  11.009412
# 5065          8.700   2.228930
# 41001        19.561  13.250822
# 69485        13.334   4.681805
#
# [21000 rows x 20 columns]

# %%
# from sklearn.model_selection import GridSearchCV
# pram = {'subsample': [0.6, 0.8, 1.0],
#         'colsample_bytree': [0.6, 0.8, 1.0],
#         'max_depth': [3, 4, 5],
#         'learning_rate': [.01,0.1,0.3],
#         'n_estimators': [100,250,500],
#        'gamma': [0,0.3,0.7,1]}
# clf = GridSearchCV(XGBRegressor(booster='gbtree',objective= 'reg:squarederror' , random_state=19), pram, cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_absolute_error')
# clf.fit(X,Y)
# Out:
# Fitting 3 folds for each of 972 candidates, totalling 2916 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=-1)]: Done 997 tasks      | elapsed: 22.1min
# [Parallel(n_jobs=-1)]: Done 1442 tasks      | elapsed: 33.5min
# [Parallel(n_jobs=-1)]: Done 1969 tasks      | elapsed: 47.4min
# [Parallel(n_jobs=-1)]: Done 2576 tasks      | elapsed: 65.7min
# [Parallel(n_jobs=-1)]: Done 2916 out of 2916 | elapsed: 76.5min finished
# GridSearchCV(cv=3, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:squarederror',
#                                     random_state=19, reg_alpha...
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'colsample_bytree': [0.6, 0.8, 1.0],
#                          'gamma': [0, 0.3, 0.7, 1],
#                          'learning_rate': [0.01, 0.1, 0.3],
#                          'max_depth': [3, 4, 5],
#                          'n_estimators': [100, 250, 500],
#                          'subsample': [0.6, 0.8, 1.0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_mean_absolute_error', verbose=2)

# %%
# clf.best_score_, clf.best_params_
# Out:
# (-4.4978801590795445,
#  {'colsample_bytree': 1.0,
#   'gamma': 0.3,
#   'learning_rate': 0.1,
#   'max_depth': 5,
#   'n_estimators': 500,
#   'subsample': 0.6})

# %%
def xgb_model(x): 
    test_1 = df[df.EXP == x]
    train_1 = df[df.EXP != x]

    train_1 = train_1.drop(['EXP', 'jul_date' ,'hour_angle', 'avg_wind_speed'], axis = 1)
    test_1 = test_1.drop(['EXP', 'jul_date' ,'hour_angle', 'avg_wind_speed'], axis = 1)

    df_0 = train_1[train_1['max_th'] == 0]
    df_1 = train_1[train_1['max_th'] == 1]
    df_2 = train_1[train_1['max_th'] == 2]

    df0_sample = df_0.sample(9000 ,random_state=19)
    df1_sample = df_1.sample(9000 ,random_state=19)
    df2_sample = df_2.sample(3000 ,random_state=19)

    df_new = pd.concat([df0_sample, df1_sample, df2_sample], axis = 0)

    x_train = df_new.drop('max_wind_speed', 1)
    x_train.drop(['Date','Type','max_th'], axis=1, inplace=True)
    y_train = df_new.max_wind_speed
    x_test = test_1.drop('max_wind_speed', 1)
    x_test_copy = x_test.copy()
    x_test.drop(['Date','Type','max_th'], axis=1, inplace=True)
    y_test = test_1.max_wind_speed

    model = XGBRegressor(booster='gbtree', objective='reg:squarederror', n_estimators = 500 ,
                         colsample_bytree = 1.0,  gamma = 0.3, max_depth = 5, 
                         subsample = 0.6, random_state = 19)
    model.fit(x_train, y_train)

    pred_train = model.predict(x_train)
    train_info = model_info2(y_train, pred_train, x , "train")

    y_train30 = np.where(y_train > 30, 1, 0 )
    pred_train30 = np.where(pred_train > 30, 1, 0 )
    train_info2 = model_info1(y_train30, pred_train30, x,'train')

    pred_test = model.predict(x_test)
    test_info = model_info2(y_test, pred_test, x , "test")

    y_test30 = np.where(y_test > 30, 1, 0 )
    pred_test30 = np.where(pred_test > 30, 1, 0 )
    test_info2 = model_info1(y_test30, pred_test30, x,'test')

    table = train_info.append(test_info)
    table2 = train_info2.append(test_info2)
    print(x)
    print(table)
    print("==" *10)
    print(table2)
    print('--' * 40)

    df_class = pd.DataFrame(pred_test30, columns=['Class_results'])
    df_class['Class_results'] = np.where(df_class['Class_results'] == 1, 'Greater than 30 knots', 'Less than 30 knots')
    df_class = df_class.reset_index()
    df_class.drop('index', axis=1, inplace=True)
    df4 = pd.DataFrame(y_test)
    df4 = df4.rename(columns={'max_wind_speed': 'actual'})
    df4 = df4.reset_index()
    df4.drop('index', axis=1, inplace=True)
    x_test_copy = x_test_copy.reset_index()
    x_test_copy.drop("index", axis=1, inplace=True)
    df5 = pd.concat([x_test_copy, df4, df_class], axis=1)
    pred_df = pd.DataFrame(pred_test, columns=["pred"])
    df6 = pd.concat([df5, pred_df], axis=1)
    df6['From'] = np.where(df6['from'] == 1, 'Mesonet', 'ASOS')
    df6.drop(['from', 'max_th'], inplace=True, axis=1)
    df6['test_date'] = x
    return(table, table2, df6)

# %%
table2 = pd.DataFrame()
table_class2 = pd.DataFrame()
data2 = pd.DataFrame()
for i in df['EXP'].unique():
    t,tc,d = xgb_model(i)
    table2 = table2.append(t)
    table_class2 = table_class2.append(tc)
    data2 = data2.append(d)
# Out:
# 1/7/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.243412   8.503966         0.0009    1/7/17       train
# 0  2.790713  12.718934         0.4276    1/7/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.953381  2239           218     761      17782  0.695774  0.746333
# 0  0.999490     0             1       0       1958  0.000000       NaN
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.088726    1/7/17       train                 3000
# 0          1.000000    1/7/17        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                1959
# --------------------------------------------------------------------------------
# 2/9/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.239793   8.466018         0.0036    2/9/17       train
# 0  3.905667  24.057773        -1.8967    2/9/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.954048  2242           207     758      17793  0.699096  0.747333
# 0  0.967492    30            44      23       1964  0.309278  0.566038
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.084524    2/9/17       train                  3000
# 0          0.594595    2/9/17        test                    53
#
#    less_than_30_knots
# 0               18000
# 0                2008
# --------------------------------------------------------------------------------
# 2/13/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.224158   8.361699         0.0017   2/13/17       train
# 0  6.230148  63.353309         4.0128   2/13/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.952571  2230           226     770      17774  0.691259  0.743333
# 0  0.769034   105            16     436       1400  0.188510  0.194085
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.092020   2/13/17       train                  3000
# 0          0.132231   2/13/17        test                   541
#
#    less_than_30_knots
# 0               18000
# 0                1416
# --------------------------------------------------------------------------------
# 2/25/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.220908   8.393981        -0.0040   2/25/17       train
# 0  4.434021  31.529900        -1.0737   2/25/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0   0.95419  2270           232     730      17768  0.702351  0.756667
# 0   0.98257     0             4      31       1973  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.092726   2/25/17       train                  3000
# 0          1.000000   2/25/17        test                    31
#
#    less_than_30_knots
# 0               18000
# 0                1977
# --------------------------------------------------------------------------------
# 3/2/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.228717   8.443731        -0.0004    3/2/17       train
# 0  4.901993  38.299254         2.5105    3/2/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events      CSI  Hit Rate  \
# 0  0.954952  2256           202     744      17798  0.70456  0.752000
# 0  0.782910   192            33     437       1503  0.29003  0.305246
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.082181    3/2/17       train                  3000
# 0          0.146667    3/2/17        test                   629
#
#    less_than_30_knots
# 0               18000
# 0                1536
# --------------------------------------------------------------------------------
# 3/14/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.222991   8.300357         0.0015   3/14/17       train
# 0  4.025611  28.229662        -1.3765   3/14/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.951524  2208           226     792      17774  0.684439  0.736000
# 0  0.905767   121           141      60       1811  0.375776  0.668508
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.092851   3/14/17       train                  3000
# 0          0.538168   3/14/17        test                   181
#
#    less_than_30_knots
# 0               18000
# 0                1952
# --------------------------------------------------------------------------------
# 3/22/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.242204   8.551056        -0.0031   3/22/17       train
# 0  5.041289  39.653989        -1.6675   3/22/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.953619  2245           219     755      17781  0.697422  0.748333
# 0  0.803604   229           233     192       1510  0.350153  0.543943
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.088880   3/22/17       train                  3000
# 0          0.504329   3/22/17        test                   421
#
#    less_than_30_knots
# 0               18000
# 0                1743
# --------------------------------------------------------------------------------
# 6/19/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.215563   8.331984        -0.0011   6/19/17       train
# 0  3.863309  27.318058        -0.5419   6/19/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.953952  2256           223     744      17777  0.699969  0.752000
# 0  0.978189     5            12      41       2372  0.086207  0.108696
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.089956   6/19/17       train                  3000
# 0          0.705882   6/19/17        test                    46
#
#    less_than_30_knots
# 0               18000
# 0                2384
# --------------------------------------------------------------------------------
# 7/13/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.226082   8.378058        -0.0013   7/13/17       train
# 0  3.335722  17.409224        -1.0595   7/13/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.952429  2244           243     756      17757  0.691952     0.748
# 0  0.999154     0             0       2       2361  0.000000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.097708   7/13/17       train                  3000
# 0               NaN   7/13/17        test                     2
#
#    less_than_30_knots
# 0               18000
# 0                2361
# --------------------------------------------------------------------------------
# 10/29/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.204716   8.219802        -0.0009  10/29/17       train
# 0  6.657792  68.754617        -3.0417  10/29/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.953905  2260           228     740      17772  0.700124  0.753333
# 0  0.943906    24            46      87       2214  0.152866  0.216216
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.091640  10/29/17       train                  3000
# 0          0.657143  10/29/17        test                   111
#
#    less_than_30_knots
# 0               18000
# 0                2260
# --------------------------------------------------------------------------------
# 11/19/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.224366   8.368104        -0.0014  11/19/17       train
# 0  5.264091  42.735517        -1.8470  11/19/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.956524  2304           217     696      17783  0.716195  0.768000
# 0  0.882353    88            55     235       2087  0.232804  0.272446
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.086077  11/19/17       train                  3000
# 0          0.384615  11/19/17        test                   323
#
#    less_than_30_knots
# 0               18000
# 0                2142
# --------------------------------------------------------------------------------
# 12/9/17
#         MAE       MSE  Residual Mean test_date data_tested
# 0  2.254458  8.583737        -0.0004   12/9/17       train
# 0  2.289846  8.130250        -0.7872   12/9/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events      CSI  Hit Rate  \
# 0  0.952667  2238           232     762      17768  0.69245     0.746
# 0  1.000000     0             0       0       2531  0.00000     0.000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.093927   12/9/17       train                 3000
# 0          0.000000   12/9/17        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2531
# --------------------------------------------------------------------------------
# 1/4/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.237022   8.500076        -0.0017    1/4/18       train
# 0  3.856672  25.918970         1.2393    1/4/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.952905  2233           222     767      17778  0.693048  0.744333
# 0  0.917239    43             5     200       2229  0.173387  0.176955
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.090428    1/4/18       train                  3000
# 0          0.104167    1/4/18        test                   243
#
#    less_than_30_knots
# 0               18000
# 0                2234
# --------------------------------------------------------------------------------
# 3/2/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.235760   8.485808         0.0016    3/2/18       train
# 0  4.955614  40.157339        -1.8593    3/2/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.952571  2243           239     757      17761  0.692498  0.747667
# 0  0.918930    29            49     148       2204  0.128319  0.163842
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.096293    3/2/18       train                  3000
# 0          0.628205    3/2/18        test                   177
#
#    less_than_30_knots
# 0               18000
# 0                2253
# --------------------------------------------------------------------------------
# 3/7/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.257808   8.721400        -0.0076    3/7/18       train
# 0  3.351339  17.423982        -1.2249    3/7/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.951905  2227           237     773      17763  0.687983  0.742333
# 0  0.997625     2             4       2       2518  0.250000  0.500000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.096185    3/7/18       train                  3000
# 0          0.666667    3/7/18        test                     4
#
#    less_than_30_knots
# 0               18000
# 0                2522
# --------------------------------------------------------------------------------
# 3/21/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.254515   8.611075         0.0037   3/21/18       train
# 0  4.957748  37.512053        -3.8790   3/21/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.952333  2221           222     779      17778  0.689323  0.740333
# 0  0.981132     0            44       0       2288  0.000000       NaN
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.090872   3/21/18       train                 3000
# 0          1.000000   3/21/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2332
# --------------------------------------------------------------------------------
# 5/15/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.207153   8.213276         0.0009   5/15/18       train
# 0  4.164681  34.008474        -1.0613   5/15/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.952714  2236           229     764      17771  0.692474  0.745333
# 0  0.981622     0             0      46       2457  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.092901   5/15/18       train                  3000
# 0               NaN   5/15/18        test                    46
#
#    less_than_30_knots
# 0               18000
# 0                2457
# --------------------------------------------------------------------------------
# 5/26/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.248913   8.557720         0.0018   5/26/18       train
# 0  3.568689  20.086136        -2.2741   5/26/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0   0.95381  2227           197     773      17803  0.696591  0.742333
# 0   1.00000     0             0       0       2404  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.081271   5/26/18       train                 3000
# 0          0.000000   5/26/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2404
# --------------------------------------------------------------------------------
# 6/13/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.243214   8.546332        -0.0003   6/13/18       train
# 0  4.133131  30.423932        -2.0535   6/13/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.953095  2248           233     752      17767  0.695329  0.749333
# 0  0.999217     0             1       1       2553  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.093914   6/13/18       train                  3000
# 0          1.000000   6/13/18        test                     1
#
#    less_than_30_knots
# 0               18000
# 0                2554
# --------------------------------------------------------------------------------
# 7/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.251903   8.572032         0.0080   7/17/18       train
# 0  2.927199  17.160548         0.1066   7/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events      CSI  Hit Rate  \
# 0  0.952619  2226           221     774      17779  0.69109     0.742
# 0  0.995726     0             0      10       2330  0.00000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.090315   7/17/18       train                  3000
# 0               NaN   7/17/18        test                    10
#
#    less_than_30_knots
# 0               18000
# 0                2330
# --------------------------------------------------------------------------------
# 7/21/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.245628   8.510769        -0.0016   7/21/18       train
# 0  4.387897  32.888528         0.2710   7/21/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0   0.95419  2260           222     740      17778  0.701428  0.753333
# 0   0.97966     2            42       7       2358  0.039216  0.222222
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.089444   7/21/18       train                  3000
# 0          0.954545   7/21/18        test                     9
#
#    less_than_30_knots
# 0               18000
# 0                2400
# --------------------------------------------------------------------------------
# 8/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.216488   8.278007         0.0071   8/17/18       train
# 0  3.991402  26.364672        -0.9177   8/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.954238  2259           220     741      17780  0.701553     0.753
# 0  0.996780     0             0       7       2167  0.000000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.088745   8/17/18       train                  3000
# 0               NaN   8/17/18        test                     7
#
#    less_than_30_knots
# 0               18000
# 0                2167
# --------------------------------------------------------------------------------
# 9/4/18
#         MAE       MSE  Residual Mean test_date data_tested
# 0  2.253980  8.610888          0.000    9/4/18       train
# 0  1.984375  6.238177         -0.017    9/4/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.952238  2229           232     771      17768  0.689666     0.743
# 0  1.000000     0             0       0       2133  0.000000     0.000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.094271    9/4/18       train                 3000
# 0          0.000000    9/4/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2133
# --------------------------------------------------------------------------------
# 9/6/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.223098   8.350257         0.0007    9/6/18       train
# 0  2.903912  16.401755         0.6879    9/6/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events      CSI  Hit Rate  \
# 0  0.953905  2266           234     734      17766  0.70068  0.755333
# 0  0.997315     0             0       6       2229  0.00000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0            0.0936    9/6/18       train                  3000
# 0               NaN    9/6/18        test                     6
#
#    less_than_30_knots
# 0               18000
# 0                2229
# --------------------------------------------------------------------------------
# 9/10/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.221287   8.362594        -0.0012   9/10/18       train
# 0  3.556000  21.107573         0.6782   9/10/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.954810  2250           199     750      17801  0.703345      0.75
# 0  0.997347     0             1       5       2256  0.000000      0.00
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.081258   9/10/18       train                  3000
# 0          1.000000   9/10/18        test                     5
#
#    less_than_30_knots
# 0               18000
# 0                2257
# --------------------------------------------------------------------------------
# 9/26/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.232003   8.464484         0.0050   9/26/18       train
# 0  3.607515  20.947283         1.0105   9/26/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.951905  2213           223     787      17777  0.686627  0.737667
# 0  1.000000     0             0       0       2145  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.091544   9/26/18       train                 3000
# 0          0.000000   9/26/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2145
# --------------------------------------------------------------------------------
# 10/2/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.242093   8.516772        -0.0014   10/2/18       train
# 0  4.594275  32.496035        -2.4172   10/2/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.952143  2213           218     787      17782  0.687694  0.737667
# 0  0.998554     0             0       3       2072  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.089675   10/2/18       train                  3000
# 0               NaN   10/2/18        test                     3
#
#    less_than_30_knots
# 0               18000
# 0                2072
# --------------------------------------------------------------------------------
# 10/12/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.243071   8.542763        -0.0011  10/12/18       train
# 0  4.258513  28.563291        -0.8321  10/12/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.954333  2254           213     746      17787  0.701525  0.751333
# 0  0.966858     6            36      39       2182  0.074074  0.133333
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.086340  10/12/18       train                  3000
# 0          0.857143  10/12/18        test                    45
#
#    less_than_30_knots
# 0               18000
# 0                2218
# --------------------------------------------------------------------------------
# 10/27/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.237453   8.436545        -0.0035  10/27/18       train
# 0  4.287539  29.314104        -0.6689  10/27/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.955095  2281           224     719      17776  0.707506  0.760333
# 0  0.945972    14            20      94       1982  0.109375  0.129630
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.089421  10/27/18       train                  3000
# 0          0.588235  10/27/18        test                   108
#
#    less_than_30_knots
# 0               18000
# 0                2002
# --------------------------------------------------------------------------------
# 12/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.247808   8.576454        -0.0015  12/17/18       train
# 0  4.367638  31.505710        -0.5580  12/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.953810  2238           208     762      17792  0.697631  0.746000
# 0  0.911271    30            36     149       1870  0.139535  0.167598
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.085037  12/17/18       train                  3000
# 0          0.545455  12/17/18        test                   179
#
#    less_than_30_knots
# 0               18000
# 0                1906
# --------------------------------------------------------------------------------
# 12/22/18
#         MAE       MSE  Residual Mean test_date data_tested
# 0  2.284547   8.78628         0.0059  12/22/18       train
# 0  4.363299  30.46059        -1.0909  12/22/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.955048  2249           193     751      17807  0.704353  0.749667
# 0  0.923043    51            49     124       2024  0.227679  0.291429
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.079034  12/22/18       train                  3000
# 0          0.490000  12/22/18        test                   175
#
#    less_than_30_knots
# 0               18000
# 0                2073
# --------------------------------------------------------------------------------
# 2/24/19
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.219061   8.285747         0.0042   2/24/19       train
# 0  6.363654  63.126309        -2.0863   2/24/19        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.953238  2228           210     772      17790  0.694081  0.742667
# 0  0.875856    22            38     252       2024  0.070513  0.080292
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.086136   2/24/19       train                  3000
# 0          0.633333   2/24/19        test                   274
#
#    less_than_30_knots
# 0               18000
# 0                2062
# --------------------------------------------------------------------------------

# %%
#table2.to_csv('XGB_search_regression_results.csv')
table2[table2['data_tested'] == 'test']
# Out:
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.790713  12.718934         0.4276    1/7/17        test
# 0  3.905667  24.057773        -1.8967    2/9/17        test
# 0  6.230148  63.353309         4.0128   2/13/17        test
# 0  4.434021  31.529900        -1.0737   2/25/17        test
# 0  4.901993  38.299254         2.5105    3/2/17        test
# 0  4.025611  28.229662        -1.3765   3/14/17        test
# 0  5.041289  39.653989        -1.6675   3/22/17        test
# 0  3.863309  27.318058        -0.5419   6/19/17        test
# 0  3.335722  17.409224        -1.0595   7/13/17        test
# 0  6.657792  68.754617        -3.0417  10/29/17        test
# 0  5.264091  42.735517        -1.8470  11/19/17        test
# 0  2.289846   8.130250        -0.7872   12/9/17        test
# 0  3.856672  25.918970         1.2393    1/4/18        test
# 0  4.955614  40.157339        -1.8593    3/2/18        test
# 0  3.351339  17.423982        -1.2249    3/7/18        test
# 0  4.957748  37.512053        -3.8790   3/21/18        test
# 0  4.164681  34.008474        -1.0613   5/15/18        test
# 0  3.568689  20.086136        -2.2741   5/26/18        test
# 0  4.133131  30.423932        -2.0535   6/13/18        test
# 0  2.927199  17.160548         0.1066   7/17/18        test
# 0  4.387897  32.888528         0.2710   7/21/18        test
# 0  3.991402  26.364672        -0.9177   8/17/18        test
# 0  1.984375   6.238177        -0.0170    9/4/18        test
# 0  2.903912  16.401755         0.6879    9/6/18        test
# 0  3.556000  21.107573         0.6782   9/10/18        test
# 0  3.607515  20.947283         1.0105   9/26/18        test
# 0  4.594275  32.496035        -2.4172   10/2/18        test
# 0  4.258513  28.563291        -0.8321  10/12/18        test
# 0  4.287539  29.314104        -0.6689  10/27/18        test
# 0  4.367638  31.505710        -0.5580  12/17/18        test
# 0  4.363299  30.460590        -1.0909  12/22/18        test
# 0  6.363654  63.126309        -2.0863   2/24/19        test

# %%
#table_class2.to_csv('XGB_search_classification_results.csv')
table_class2[table_class2['data_tested'] == 'test']
# Out:
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.999490     0             1       0       1958  0.000000       NaN
# 0  0.967492    30            44      23       1964  0.309278  0.566038
# 0  0.769034   105            16     436       1400  0.188510  0.194085
# 0  0.982570     0             4      31       1973  0.000000  0.000000
# 0  0.782910   192            33     437       1503  0.290030  0.305246
# 0  0.905767   121           141      60       1811  0.375776  0.668508
# 0  0.803604   229           233     192       1510  0.350153  0.543943
# 0  0.978189     5            12      41       2372  0.086207  0.108696
# 0  0.999154     0             0       2       2361  0.000000  0.000000
# 0  0.943906    24            46      87       2214  0.152866  0.216216
# 0  0.882353    88            55     235       2087  0.232804  0.272446
# 0  1.000000     0             0       0       2531  0.000000  0.000000
# 0  0.917239    43             5     200       2229  0.173387  0.176955
# 0  0.918930    29            49     148       2204  0.128319  0.163842
# 0  0.997625     2             4       2       2518  0.250000  0.500000
# 0  0.981132     0            44       0       2288  0.000000       NaN
# 0  0.981622     0             0      46       2457  0.000000  0.000000
# 0  1.000000     0             0       0       2404  0.000000  0.000000
# 0  0.999217     0             1       1       2553  0.000000  0.000000
# 0  0.995726     0             0      10       2330  0.000000  0.000000
# 0  0.979660     2            42       7       2358  0.039216  0.222222
# 0  0.996780     0             0       7       2167  0.000000  0.000000
# 0  1.000000     0             0       0       2133  0.000000  0.000000
# 0  0.997315     0             0       6       2229  0.000000  0.000000
# 0  0.997347     0             1       5       2256  0.000000  0.000000
# 0  1.000000     0             0       0       2145  0.000000  0.000000
# 0  0.998554     0             0       3       2072  0.000000  0.000000
# 0  0.966858     6            36      39       2182  0.074074  0.133333
# 0  0.945972    14            20      94       1982  0.109375  0.129630
# 0  0.911271    30            36     149       1870  0.139535  0.167598
# 0  0.923043    51            49     124       2024  0.227679  0.291429
# 0  0.875856    22            38     252       2024  0.070513  0.080292
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          1.000000    1/7/17        test                    0
# 0          0.594595    2/9/17        test                   53
# 0          0.132231   2/13/17        test                  541
# 0          1.000000   2/25/17        test                   31
# 0          0.146667    3/2/17        test                  629
# 0          0.538168   3/14/17        test                  181
# 0          0.504329   3/22/17        test                  421
# 0          0.705882   6/19/17        test                   46
# 0               NaN   7/13/17        test                    2
# 0          0.657143  10/29/17        test                  111
# 0          0.384615  11/19/17        test                  323
# 0          0.000000   12/9/17        test                    0
# 0          0.104167    1/4/18        test                  243
# 0          0.628205    3/2/18        test                  177
# 0          0.666667    3/7/18        test                    4
# 0          1.000000   3/21/18        test                    0
# 0               NaN   5/15/18        test                   46
# 0          0.000000   5/26/18        test                    0
# 0          1.000000   6/13/18        test                    1
# 0               NaN   7/17/18        test                   10
# 0          0.954545   7/21/18        test                    9
# 0               NaN   8/17/18        test                    7
# 0          0.000000    9/4/18        test                    0
# 0               NaN    9/6/18        test                    6
# 0          1.000000   9/10/18        test                    5
# 0          0.000000   9/26/18        test                    0
# 0               NaN   10/2/18        test                    3
# 0          0.857143  10/12/18        test                   45
# 0          0.588235  10/27/18        test                  108
# 0          0.545455  12/17/18        test                  179
# 0          0.490000  12/22/18        test                  175
# 0          0.633333   2/24/19        test                  274
#
#    less_than_30_knots
# 0                1959
# 0                2008
# 0                1416
# 0                1977
# 0                1536
# 0                1952
# 0                1743
# 0                2384
# 0                2361
# 0                2260
# 0                2142
# 0                2531
# 0                2234
# 0                2253
# 0                2522
# 0                2332
# 0                2457
# 0                2404
# 0                2554
# 0                2330
# 0                2400
# 0                2167
# 0                2133
# 0                2229
# 0                2257
# 0                2145
# 0                2072
# 0                2218
# 0                2002
# 0                1906
# 0                2073
# 0                2062

# %%
#data2.to_csv('XGB_search_data.csv')
data2.head()
# Out:
#                   Date  Type        R1        R2  \
# 0  2017-01-07 06:00:00  ANDE  2.630564  2.322274
# 1  2017-01-07 06:15:00  ANDE  2.055383  1.813005
# 2  2017-01-07 06:30:00  ANDE  1.792587  1.671478
# 3  2017-01-07 06:45:00  ANDE  1.442889  1.352497
# 4  2017-01-07 07:00:00  ANDE  2.283417  1.677404
#
#    Pressure_reduced_to_MSL_.Pa..0.MSL  Derived_radar_reflectivity_.dB..1.HYBL  \
# 0                            102879.7                                     0.0
# 1                            102951.0                                     0.0
# 2                            102890.6                                     0.0
# 3                            102931.0                                     0.0
# 4                            102882.5                                     0.0
#
#    u.component_of_wind_.m.s..85000.ISBL  v.component_of_wind_.m.s..85000.ISBL  \
# 0                                 5.447                                -1.457
# 1                                 5.629                                -1.464
# 2                                 5.653                                -1.560
# 3                                 5.692                                -2.445
# 4                                 5.226                                -3.060
#
#    wind_speed_85000  wind_shear_85000  ...  diff_temp  geo_cbl  veg_sfc  \
# 0          5.638498          5.269992  ...      0.739  -5000.0   40.293
# 1          5.816265          5.773324  ...      1.050  -5000.0   40.293
# 2          5.864300          6.232140  ...      1.211  -5000.0   40.293
# 3          6.194908          6.806583  ...      0.943  -5000.0   40.293
# 4          6.055962          5.554556  ...      0.751  -5000.0   40.293
#
#    best_4_layer     ws_700    actual       Class_results      pred     From  \
# 0        23.757  16.787335  2.332608  Less than 30 knots  2.168547  Mesonet
# 1        23.959  16.195689  1.555072  Less than 30 knots  2.439883  Mesonet
# 2        24.118  15.636587  2.332608  Less than 30 knots  2.843160  Mesonet
# 3        24.220  16.767452  1.555072  Less than 30 knots  3.277068  Mesonet
# 4        24.149  17.249375  2.526992  Less than 30 knots  3.706889  Mesonet
#
#    test_date
# 0     1/7/17
# 1     1/7/17
# 2     1/7/17
# 3     1/7/17
# 4     1/7/17
#
# [5 rows x 26 columns]
