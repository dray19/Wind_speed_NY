# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from collections import Counter

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv("15min_dateset.csv")
df.drop('Unnamed: 0', inplace = True, axis = 1)
df.head(2)
# Out:
#                   Date  Type     from     EXP  jul_date  hour_angle  \
# 0  2017-01-07 06:00:00  ANDE  MESONET  1/7/17         7   -1.570795
# 1  2017-01-07 06:15:00  ANDE  MESONET  1/7/17         7   -1.505345
#
#    max_wind_speed  avg_wind_speed        R1        R2  ...  HYBL_one  \
# 0        2.332608        1.295893  2.630564  2.322274  ...  0.629230
# 1        1.555072        0.647947  2.055383  1.813005  ...  0.748575
#
#    HYBL_two  HYBL_three  HYBL_four  HYBL_five  diff_temp  geo_cbl  veg_sfc  \
# 0  0.903721    3.610055   5.011670   6.054984      0.739  -5000.0   40.293
# 1  1.493288    3.643217   5.232982   6.394255      1.050  -5000.0   40.293
#
#    best_4_layer     ws_700
# 0        23.757  16.787335
# 1        23.959  16.195689
#
# [2 rows x 27 columns]

# %%
#### Clasification results
def model_info1(x, y, test_date, data_tested):
    cm = confusion_matrix(x,y)
    acc = accuracy_score(x,y)
    cm = confusion_matrix(x,y)
    if len(cm) > 1:
        hit = cm[1][1]
        false_alarms = cm[0][1]
        misses = cm[1][0]
        no_events = cm[0][0]
        csi = hit / (false_alarms + misses + hit)
        hit_rate = hit / (hit + misses)
        false_alarm_rate = false_alarms / (hit + false_alarms)
    else:
        hit = 0
        false_alarms = 0
        misses = 0
        no_events = cm[0][0]
        csi = 0
        hit_rate =0
        false_alarm_rate = 0
    data = [{"Accuracy":acc,"Hits":hit, "False Alarms":false_alarms, 'Misses':misses,'No Events': no_events, 'CSI':csi, 'Hit Rate':hit_rate, 'False Alarm Rate':false_alarm_rate}]
    df = pd.DataFrame(data)
    df['test_date'] = test_date
    df['data_tested'] = data_tested
    if len(Counter(x)) == 1:
        l30 = Counter(x)[0]
        df['greter_than_30_knots'] = '0'
        df['less_than_30_knots'] = l30
    else:
        g30 = Counter(x)[1]
        l30 = Counter(x)[0]
        df['greter_than_30_knots'] = g30
        df['less_than_30_knots'] = l30
    return (df)



### Regression results
def model_info2(x, y,test_date,data_tested):
    mae = mean_absolute_error(x,y)
    mse = mean_squared_error(x,y)
    residual_0 = x - y
    res_0 = np.array(residual_0)
    res_mean = round(res_0.mean(),4)
    data = [{"MAE":mae ,"MSE":mse, 'Residual Mean':res_mean}]
    df = pd.DataFrame(data)
    df['test_date'] = test_date
    df['data_tested'] = data_tested
    return (df)

# %%
le = LabelEncoder()
df['from'] = le.fit_transform(df['from'])
df.tail(2)
# Out:
#                       Date  Type  from      EXP  jul_date  hour_angle  \
# 72647  2018-07-22 05:45:00  WBOU     1  7/21/18       203   -1.636245
# 72648  2018-07-22 06:00:00  WBOU     1  7/21/18       203   -1.570795
#
#        max_wind_speed  avg_wind_speed        R1        R2  ...  HYBL_one  \
# 72647       17.105792        8.552896  0.279731  0.693772  ...  9.634310
# 72648       17.105792       10.043173  0.231301  0.605321  ...  8.939975
#
#         HYBL_two  HYBL_three  HYBL_four  HYBL_five  diff_temp  geo_cbl  \
# 72647  16.364893   18.456569  21.401767  24.263238      3.607  554.661
# 72648  16.514877   18.701148  22.068564  24.935163      3.349  555.042
#
#        veg_sfc  best_4_layer    ws_700
# 72647   81.379         0.706  8.964475
# 72648   81.379         0.171  7.752404
#
# [2 rows x 27 columns]

# %%
df["max_th"] = np.where(df["max_wind_speed"] > 30, 2, np.where(df["max_wind_speed"] < 15, 0, 1))
df['max_th'].value_counts()
# Out:
# 0    44574
# 1    24445
# 2     3630
# Name: max_th, dtype: int64

# %%
def lin_model(x): 
    test_1 = df[df.EXP == x]
    train_1 = df[df.EXP != x]

    train_1 = train_1.drop(['EXP','avg_wind_speed','jul_date','hour_angle'], axis = 1)

    test_1 = test_1.drop(['EXP','avg_wind_speed','jul_date','hour_angle'], axis = 1)

    df_0 = train_1[train_1['max_th'] == 0]
    df_1 = train_1[train_1['max_th'] == 1]
    df_2 = train_1[train_1['max_th'] == 2]

    df0_sample = df_0.sample(9000 ,random_state=19)
    df1_sample = df_1.sample(9000 ,random_state=19)
    df2_sample = df_2.sample(3000 ,random_state=19)

    df_new = pd.concat([df0_sample, df1_sample, df2_sample], axis = 0)

    x_train = df_new.drop('max_wind_speed', 1)
    x_train.drop(['Date','Type','max_th'], axis=1, inplace=True)
    y_train = df_new.max_wind_speed
    x_test = test_1.drop('max_wind_speed', 1)
    x_test_copy = x_test.copy()
    x_test.drop(['Date','Type','max_th'], axis=1, inplace=True)
    y_test = test_1.max_wind_speed
    scale = MinMaxScaler()
    x_train = scale.fit_transform(x_train)
    x_test = scale.transform(x_test)


    model = LinearRegression()
    model.fit(x_train, y_train)

    pred_train = model.predict(x_train)
    train_info = model_info2(y_train, pred_train, x , "train")

    y_train30 = np.where(y_train > 30, 1, 0 )
    pred_train30 = np.where(pred_train > 30, 1, 0 )
    train_info2 = model_info1(y_train30, pred_train30, x,'train')

    pred_test = model.predict(x_test)
    test_info = model_info2(y_test, pred_test, x , "test")

    y_test30 = np.where(y_test > 30, 1, 0 )
    pred_test30 = np.where(pred_test > 30, 1, 0 )
    test_info2 = model_info1(y_test30, pred_test30, x,'test')

    table = train_info.append(test_info)
    table2 = train_info2.append(test_info2)
    print(x)
    print(table)
    print("==" *10)
    print(table2)
    print('--' * 40)

    df_class = pd.DataFrame(pred_test30, columns=['Class_results'])
    df_class['Class_results'] = np.where(df_class['Class_results'] == 1, 'Greater than 30 knots', 'Less than 30 knots')
    df_class = df_class.reset_index()
    df_class.drop('index', axis=1, inplace=True)
    df4 = pd.DataFrame(y_test)
    df4 = df4.rename(columns={'max_wind_speed': 'actual'})
    df4 = df4.reset_index()
    df4.drop('index', axis=1, inplace=True)
    x_test_copy = x_test_copy.reset_index()
    x_test_copy.drop("index", axis=1, inplace=True)
    df5 = pd.concat([x_test_copy, df4, df_class], axis=1)
    pred_df = pd.DataFrame(pred_test, columns=["pred"])
    df6 = pd.concat([df5, pred_df], axis=1)
    df6['From'] = np.where(df6['from'] == 1, 'Mesonet', 'ASOS')
    df6.drop(['from', 'max_th'], inplace=True, axis=1)
    df6['test_date'] = x
    return(table, table2, df6)

# %%
table = pd.DataFrame()
table_class = pd.DataFrame()
data = pd.DataFrame()
for i in df['EXP'].unique():
    t,tc,d = lin_model(i)
    table = table.append(t)
    table_class = table_class.append(tc)
    data = data.append(d)
# Out:
# 1/7/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.664122  36.310676        -0.0000    1/7/17       train
# 0  3.430424  18.494801        -2.6956    1/7/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0   0.88619  1010           400    1990      17600  0.297059  0.336667
# 0   1.00000     0             0       0       1959  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.283688    1/7/17       train                 3000
# 0          0.000000    1/7/17        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                1959
# --------------------------------------------------------------------------------
# 2/9/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.660134  36.200782         0.0000    2/9/17       train
# 0  4.249987  26.654195        -2.7796    2/9/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.884714   989           410    2011      17590  0.290029  0.329667
# 0  0.969918     7            16      46       1992  0.101449  0.132075
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.293066    2/9/17       train                  3000
# 0          0.695652    2/9/17        test                    53
#
#    less_than_30_knots
# 0               18000
# 0                2008
# --------------------------------------------------------------------------------
# 2/13/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.656341  36.087157        -0.0000   2/13/17       train
# 0  6.209148  58.353943        -2.3398   2/13/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.883905   921           359    2079      17641  0.274189  0.307000
# 0  0.737864   372           344     169       1072  0.420339  0.687616
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.280469   2/13/17       train                  3000
# 0          0.480447   2/13/17        test                   541
#
#    less_than_30_knots
# 0               18000
# 0                1416
# --------------------------------------------------------------------------------
# 2/25/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.642509  35.800486         0.0000   2/25/17       train
# 0  4.851158  35.897286        -1.6248   2/25/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.884238   982           413    2018      17587  0.287723  0.327333
# 0  0.984562     0             0      31       1977  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.296057   2/25/17       train                  3000
# 0               NaN   2/25/17        test                    31
#
#    less_than_30_knots
# 0               18000
# 0                1977
# --------------------------------------------------------------------------------
# 3/2/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.669326  36.685049        -0.0000    3/2/17       train
# 0  5.012900  37.753851        -0.4688    3/2/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.884238   977           408    2023      17592  0.286678  0.325667
# 0  0.738106   271           209     358       1327  0.323389  0.430843
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.294585    3/2/17       train                  3000
# 0          0.435417    3/2/17        test                   629
#
#    less_than_30_knots
# 0               18000
# 0                1536
# --------------------------------------------------------------------------------
# 3/14/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.667897  36.274557        -0.0000   3/14/17       train
# 0  4.073754  26.177805        -2.5628   3/14/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.883857   949           388    2051      17612  0.280106  0.316333
# 0  0.920769   131           119      50       1833  0.436667  0.723757
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.290202   3/14/17       train                  3000
# 0          0.476000   3/14/17        test                   181
#
#    less_than_30_knots
# 0               18000
# 0                1952
# --------------------------------------------------------------------------------
# 3/22/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.640887  36.354053        -0.0000   3/22/17       train
# 0  5.110554  38.877479        -1.7719   3/22/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.887476  1054           417    1946      17583  0.308458  0.351333
# 0  0.785582   175           218     246       1525  0.273865  0.415677
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.283481   3/22/17       train                  3000
# 0          0.554707   3/22/17        test                   421
#
#    less_than_30_knots
# 0               18000
# 0                1743
# --------------------------------------------------------------------------------
# 6/19/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.646624  35.849969        -0.0000   6/19/17       train
# 0  3.902094  26.698822        -0.0716   6/19/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.883905  1009           447    1991      17553  0.292718  0.336333
# 0  0.980658     1             2      45       2382  0.020833  0.021739
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.307005   6/19/17       train                  3000
# 0          0.666667   6/19/17        test                    46
#
#    less_than_30_knots
# 0               18000
# 0                2384
# --------------------------------------------------------------------------------
# 7/13/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.645141  36.069887        -0.0000   7/13/17       train
# 0  4.028881  27.209907        -2.1993   7/13/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.885857   998           395    2002      17605  0.293962  0.332667
# 0  0.999154     0             0       2       2361  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.283561   7/13/17       train                  3000
# 0               NaN   7/13/17        test                     2
#
#    less_than_30_knots
# 0               18000
# 0                2361
# --------------------------------------------------------------------------------
# 10/29/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.571639  34.717704        -0.0000  10/29/17       train
# 0  7.790647  98.087994        -5.0988  10/29/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.887429  1043           407    1957      17593  0.306134  0.347667
# 0  0.885702    45           205      66       2055  0.142405  0.405405
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0           0.28069  10/29/17       train                  3000
# 0           0.82000  10/29/17        test                   111
#
#    less_than_30_knots
# 0               18000
# 0                2260
# --------------------------------------------------------------------------------
# 11/19/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.596067  35.640682        -0.0000  11/19/17       train
# 0  6.348446  58.278883        -2.9102  11/19/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.889238  1118           444    1882      17556  0.324623  0.372667
# 0  0.841785    17            84     306       2058  0.041769  0.052632
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.284251  11/19/17       train                  3000
# 0          0.831683  11/19/17        test                   323
#
#    less_than_30_knots
# 0               18000
# 0                2142
# --------------------------------------------------------------------------------
# 12/9/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.645368  36.019371        -0.0000   12/9/17       train
# 0  3.320654  15.494701        -2.8769   12/9/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.885429   998           404    2002      17596  0.293184  0.332667
# 0  1.000000     0             0       0       2531  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0           0.28816   12/9/17       train                 3000
# 0           0.00000   12/9/17        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2531
# --------------------------------------------------------------------------------
# 1/4/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.593283  35.454738         0.0000    1/4/18       train
# 0  4.534424  35.177002         1.6379    1/4/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.885333  1012           420    1988      17580  0.295906  0.337333
# 0  0.909972    21             1     222       2233  0.086066  0.086420
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.293296    1/4/18       train                  3000
# 0          0.045455    1/4/18        test                   243
#
#    less_than_30_knots
# 0               18000
# 0                2234
# --------------------------------------------------------------------------------
# 3/2/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.587542  35.206506         0.0000    3/2/18       train
# 0  5.683469  49.293049        -3.8234    3/2/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.885857   995           392    2005      17608  0.293337  0.331667
# 0  0.895473   136           213      41       2040  0.348718  0.768362
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.282624    3/2/18       train                  3000
# 0          0.610315    3/2/18        test                   177
#
#    less_than_30_knots
# 0               18000
# 0                2253
# --------------------------------------------------------------------------------
# 3/7/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.682082  36.375382        -0.0000    3/7/18       train
# 0  3.584212  18.802700        -1.8728    3/7/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.884286   985           415    2015      17585  0.288433  0.328333
# 0  0.998416     0             0       4       2522  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.296429    3/7/18       train                  3000
# 0               NaN    3/7/18        test                     4
#
#    less_than_30_knots
# 0               18000
# 0                2522
# --------------------------------------------------------------------------------
# 3/21/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.624945  35.768736         0.0000   3/21/18       train
# 0  5.732861  45.964642        -5.2637   3/21/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.885095  1038           451    1962      17549  0.300782     0.346
# 0  1.000000     0             0       0       2332  0.000000     0.000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.302888   3/21/18       train                 3000
# 0          0.000000   3/21/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2332
# --------------------------------------------------------------------------------
# 5/15/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.635110  35.259610         0.0000   5/15/18       train
# 0  4.736046  41.001267        -2.2895   5/15/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.884000  1015           451    1985      17549  0.294118  0.338333
# 0  0.980823     1             3      45       2454  0.020408  0.021739
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0           0.30764   5/15/18       train                  3000
# 0           0.75000   5/15/18        test                    46
#
#    less_than_30_knots
# 0               18000
# 0                2457
# --------------------------------------------------------------------------------
# 5/26/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.667399  36.225626         0.0000   5/26/18       train
# 0  3.254778  16.641072        -1.7278   5/26/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0     0.887  1010           383    1990      17617  0.298552  0.336667
# 0     1.000     0             0       0       2404  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.274946   5/26/18       train                 3000
# 0          0.000000   5/26/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2404
# --------------------------------------------------------------------------------
# 6/13/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.606480  35.755051         0.0000   6/13/18       train
# 0  4.162424  27.429191        -2.4383   6/13/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.883619  1006           450    1994      17550  0.291594  0.335333
# 0  0.999609     0             0       1       2554  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.309066   6/13/18       train                  3000
# 0               NaN   6/13/18        test                     1
#
#    less_than_30_knots
# 0               18000
# 0                2554
# --------------------------------------------------------------------------------
# 7/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.625221  35.740983        -0.0000   7/17/18       train
# 0  4.243594  29.638387         0.9686   7/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.884857  1025           443    1975      17557  0.297705  0.341667
# 0  0.995726     0             0      10       2330  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.301771   7/17/18       train                  3000
# 0               NaN   7/17/18        test                    10
#
#    less_than_30_knots
# 0               18000
# 0                2330
# --------------------------------------------------------------------------------
# 7/21/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.684118  36.721874         0.0000   7/21/18       train
# 0  3.908949  24.209961         1.5943   7/21/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.882429   950           419    2050      17581  0.277859  0.316667
# 0  0.995849     0             1       9       2399  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.306063   7/21/18       train                  3000
# 0          1.000000   7/21/18        test                     9
#
#    less_than_30_knots
# 0               18000
# 0                2400
# --------------------------------------------------------------------------------
# 8/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.656891  36.167636         0.0000   8/17/18       train
# 0  3.921134  28.145541         1.1514   8/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.885952  1014           409    1986      17591  0.297448     0.338
# 0  0.996780     0             0       7       2167  0.000000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.287421   8/17/18       train                  3000
# 0               NaN   8/17/18        test                     7
#
#    less_than_30_knots
# 0               18000
# 0                2167
# --------------------------------------------------------------------------------
# 9/4/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.660936  36.172434         0.0000    9/4/18       train
# 0  2.832485  13.636868        -1.3481    9/4/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.885714  1004           404    1996      17596  0.294947  0.334667
# 0  1.000000     0             0       0       2133  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.286932    9/4/18       train                 3000
# 0          0.000000    9/4/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2133
# --------------------------------------------------------------------------------
# 9/6/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.640794  35.752321         0.0000    9/6/18       train
# 0  3.244553  19.351461         0.1042    9/6/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.885571  1013           416    1987      17584  0.296546  0.337667
# 0  0.997315     0             0       6       2229  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.291113    9/6/18       train                  3000
# 0               NaN    9/6/18        test                     6
#
#    less_than_30_knots
# 0               18000
# 0                2229
# --------------------------------------------------------------------------------
# 9/10/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.633110  35.802176         0.0000   9/10/18       train
# 0  4.208631  28.430111         2.4701   9/10/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.887476  1015           378    1985      17622  0.300474  0.338333
# 0  0.997790     0             0       5       2257  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.271357   9/10/18       train                  3000
# 0               NaN   9/10/18        test                     5
#
#    less_than_30_knots
# 0               18000
# 0                2257
# --------------------------------------------------------------------------------
# 9/26/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.599566  35.510224        -0.0000   9/26/18       train
# 0  3.668957  21.995092        -0.6435   9/26/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0   0.88581  1015           413    1985      17587  0.297392  0.338333
# 0   1.00000     0             0       0       2145  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.289216   9/26/18       train                 3000
# 0          0.000000   9/26/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2145
# --------------------------------------------------------------------------------
# 10/2/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.601821  35.389852        -0.0000   10/2/18       train
# 0  4.152909  28.488054        -0.9399   10/2/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.886000  1007           401    1993      17599  0.296089  0.335667
# 0  0.998554     0             0       3       2072  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.284801   10/2/18       train                  3000
# 0               NaN   10/2/18        test                     3
#
#    less_than_30_knots
# 0               18000
# 0                2072
# --------------------------------------------------------------------------------
# 10/12/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.627329  36.055501          0.000  10/12/18       train
# 0  4.086899  26.764541          0.349  10/12/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.886048   996           389    2004      17611  0.293892     0.332
# 0  0.980115     0             0      45       2218  0.000000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.280866  10/12/18       train                  3000
# 0               NaN  10/12/18        test                    45
#
#    less_than_30_knots
# 0               18000
# 0                2218
# --------------------------------------------------------------------------------
# 10/27/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.617284  35.667669         0.0000  10/27/18       train
# 0  4.498230  33.864728         1.1719  10/27/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.886333  1028           415    1972      17585  0.301025  0.342667
# 0  0.950711     5             1     103       2001  0.045872  0.046296
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.287595  10/27/18       train                  3000
# 0          0.166667  10/27/18        test                   108
#
#    less_than_30_knots
# 0               18000
# 0                2002
# --------------------------------------------------------------------------------
# 12/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.627172  35.609049        -0.0000  12/17/18       train
# 0  4.939638  37.923859        -1.2077  12/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.885762  1033           432    1967      17568  0.300991  0.344333
# 0  0.913189     7             9     172       1897  0.037234  0.039106
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.294881  12/17/18       train                  3000
# 0          0.562500  12/17/18        test                   179
#
#    less_than_30_knots
# 0               18000
# 0                1906
# --------------------------------------------------------------------------------
# 12/22/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.643695  36.335275        -0.0000  12/22/18       train
# 0  4.600722  32.706178        -0.1622  12/22/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.886524  1040           423    1960      17577  0.303827  0.346667
# 0  0.915480     0            15     175       2058  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.289132  12/22/18       train                  3000
# 0          1.000000  12/22/18        test                   175
#
#    less_than_30_knots
# 0               18000
# 0                2073
# --------------------------------------------------------------------------------
# 2/24/19
#        MAE        MSE  Residual Mean test_date data_tested
# 0  4.61236  35.477501        -0.0000   2/24/19       train
# 0  5.23893  42.559655        -1.9718   2/24/19        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.886619  1015           396    1985      17604  0.298881  0.338333
# 0  0.906678    81            25     193       2037  0.270903  0.295620
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.280652   2/24/19       train                  3000
# 0          0.235849   2/24/19        test                   274
#
#    less_than_30_knots
# 0               18000
# 0                2062
# --------------------------------------------------------------------------------

# %%
#table.to_csv('Lin_sample_regression_results.csv')
table.head()
# Out:
#         MAE        MSE  Residual Mean test_date data_tested
# 0  4.664122  36.310676        -0.0000    1/7/17       train
# 0  3.430424  18.494801        -2.6956    1/7/17        test
# 0  4.660134  36.200782         0.0000    2/9/17       train
# 0  4.249987  26.654195        -2.7796    2/9/17        test
# 0  4.656341  36.087157        -0.0000   2/13/17       train

# %%
#table_class.to_csv('lin_sample_classfication_results.csv')
table_class.head()
# Out:
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.886190  1010           400    1990      17600  0.297059  0.336667
# 0  1.000000     0             0       0       1959  0.000000  0.000000
# 0  0.884714   989           410    2011      17590  0.290029  0.329667
# 0  0.969918     7            16      46       1992  0.101449  0.132075
# 0  0.883905   921           359    2079      17641  0.274189  0.307000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.283688    1/7/17       train                 3000
# 0          0.000000    1/7/17        test                    0
# 0          0.293066    2/9/17       train                 3000
# 0          0.695652    2/9/17        test                   53
# 0          0.280469   2/13/17       train                 3000
#
#    less_than_30_knots
# 0               18000
# 0                1959
# 0               18000
# 0                2008
# 0               18000

# %%
#data.to_csv('lin_smaple_data.csv')
data.head()
# Out:
#                   Date  Type        R1        R2  \
# 0  2017-01-07 06:00:00  ANDE  2.630564  2.322274
# 1  2017-01-07 06:15:00  ANDE  2.055383  1.813005
# 2  2017-01-07 06:30:00  ANDE  1.792587  1.671478
# 3  2017-01-07 06:45:00  ANDE  1.442889  1.352497
# 4  2017-01-07 07:00:00  ANDE  2.283417  1.677404
#
#    Pressure_reduced_to_MSL_.Pa..0.MSL  Derived_radar_reflectivity_.dB..1.HYBL  \
# 0                            102879.7                                     0.0
# 1                            102951.0                                     0.0
# 2                            102890.6                                     0.0
# 3                            102931.0                                     0.0
# 4                            102882.5                                     0.0
#
#    u.component_of_wind_.m.s..85000.ISBL  v.component_of_wind_.m.s..85000.ISBL  \
# 0                                 5.447                                -1.457
# 1                                 5.629                                -1.464
# 2                                 5.653                                -1.560
# 3                                 5.692                                -2.445
# 4                                 5.226                                -3.060
#
#    wind_speed_85000  wind_shear_85000  ...  diff_temp  geo_cbl  veg_sfc  \
# 0          5.638498          5.269992  ...      0.739  -5000.0   40.293
# 1          5.816265          5.773324  ...      1.050  -5000.0   40.293
# 2          5.864300          6.232140  ...      1.211  -5000.0   40.293
# 3          6.194908          6.806583  ...      0.943  -5000.0   40.293
# 4          6.055962          5.554556  ...      0.751  -5000.0   40.293
#
#    best_4_layer     ws_700    actual       Class_results      pred     From  \
# 0        23.757  16.787335  2.332608  Less than 30 knots  6.200024  Mesonet
# 1        23.959  16.195689  1.555072  Less than 30 knots  6.948922  Mesonet
# 2        24.118  15.636587  2.332608  Less than 30 knots  7.381036  Mesonet
# 3        24.220  16.767452  1.555072  Less than 30 knots  8.615823  Mesonet
# 4        24.149  17.249375  2.526992  Less than 30 knots  8.870546  Mesonet
#
#    test_date
# 0     1/7/17
# 1     1/7/17
# 2     1/7/17
# 3     1/7/17
# 4     1/7/17
#
# [5 rows x 26 columns]
