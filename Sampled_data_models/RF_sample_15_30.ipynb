# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from collections import Counter

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv("15min_dateset.csv")
df.drop('Unnamed: 0', inplace = True, axis = 1)
print(len(df['EXP'].unique()))
df.head()
# Out:
# 32
#                   Date  Type     from     EXP  jul_date  hour_angle  \
# 0  2017-01-07 06:00:00  ANDE  MESONET  1/7/17         7   -1.570795
# 1  2017-01-07 06:15:00  ANDE  MESONET  1/7/17         7   -1.505345
# 2  2017-01-07 06:30:00  ANDE  MESONET  1/7/17         7   -1.439895
# 3  2017-01-07 06:45:00  ANDE  MESONET  1/7/17         7   -1.374446
# 4  2017-01-07 07:00:00  ANDE  MESONET  1/7/17         7   -1.308996
#
#    max_wind_speed  avg_wind_speed        R1        R2  ...  HYBL_one  \
# 0        2.332608        1.295893  2.630564  2.322274  ...  0.629230
# 1        1.555072        0.647947  2.055383  1.813005  ...  0.748575
# 2        2.332608        1.360688  1.792587  1.671478  ...  1.154196
# 3        1.555072        0.453563  1.442889  1.352497  ...  2.183654
# 4        2.526992        1.360688  2.283417  1.677404  ...  2.407290
#
#    HYBL_two  HYBL_three  HYBL_four  HYBL_five  diff_temp  geo_cbl  veg_sfc  \
# 0  0.903721    3.610055   5.011670   6.054984      0.739  -5000.0   40.293
# 1  1.493288    3.643217   5.232982   6.394255      1.050  -5000.0   40.293
# 2  1.645343    3.346854   5.054551   6.395084      1.211  -5000.0   40.293
# 3  2.266223    3.550607   5.363623   6.869857      0.943  -5000.0   40.293
# 4  2.633109    3.692489   5.309871   6.783159      0.751  -5000.0   40.293
#
#    best_4_layer     ws_700
# 0        23.757  16.787335
# 1        23.959  16.195689
# 2        24.118  15.636587
# 3        24.220  16.767452
# 4        24.149  17.249375
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Function used

# %%
#### Clasification results
def model_info1(x, y, test_date, data_tested):
    cm = confusion_matrix(x,y)
    acc = accuracy_score(x,y)
    cm = confusion_matrix(x,y)
    if len(cm) > 1:
        hit = cm[1][1]
        false_alarms = cm[0][1]
        misses = cm[1][0]
        no_events = cm[0][0]
        csi = hit / (false_alarms + misses + hit)
        hit_rate = hit / (hit + misses)
        false_alarm_rate = false_alarms / (hit + false_alarms)
    else:
        hit = 0
        false_alarms = 0
        misses = 0
        no_events = cm[0][0]
        csi = 0
        hit_rate =0
        false_alarm_rate = 0
    data = [{"Accuracy":acc,"Hits":hit, "False Alarms":false_alarms, 'Misses':misses,'No Events': no_events, 'CSI':csi, 'Hit Rate':hit_rate, 'False Alarm Rate':false_alarm_rate}]
    df = pd.DataFrame(data)
    df['test_date'] = test_date
    df['data_tested'] = data_tested
    if len(Counter(x)) == 1:
        l30 = Counter(x)[0]
        df['greter_than_30_knots'] = '0'
        df['less_than_30_knots'] = l30
    else:
        g30 = Counter(x)[1]
        l30 = Counter(x)[0]
        df['greter_than_30_knots'] = g30
        df['less_than_30_knots'] = l30
    return (df)



### Regression results
def model_info2(x, y,test_date,data_tested):
    mae = mean_absolute_error(x,y)
    mse = mean_squared_error(x,y)
    r2 = r2_score(x,y)
    residual_0 = x - y
    res_0 = np.array(residual_0)
    res_mean = round(res_0.mean(),4)
    data = [{"MAE":mae ,"MSE":mse, 'Residual Mean':res_mean}]
    df = pd.DataFrame(data)
    df['test_date'] = test_date
    df['data_tested'] = data_tested
    return (df)

# %%
le = LabelEncoder()
df['from'] = le.fit_transform(df['from'])
df.tail(2)
# Out:
#                       Date  Type  from      EXP  jul_date  hour_angle  \
# 72647  2018-07-22 05:45:00  WBOU     1  7/21/18       203   -1.636245
# 72648  2018-07-22 06:00:00  WBOU     1  7/21/18       203   -1.570795
#
#        max_wind_speed  avg_wind_speed        R1        R2  ...  HYBL_one  \
# 72647       17.105792        8.552896  0.279731  0.693772  ...  9.634310
# 72648       17.105792       10.043173  0.231301  0.605321  ...  8.939975
#
#         HYBL_two  HYBL_three  HYBL_four  HYBL_five  diff_temp  geo_cbl  \
# 72647  16.364893   18.456569  21.401767  24.263238      3.607  554.661
# 72648  16.514877   18.701148  22.068564  24.935163      3.349  555.042
#
#        veg_sfc  best_4_layer    ws_700
# 72647   81.379         0.706  8.964475
# 72648   81.379         0.171  7.752404
#
# [2 rows x 27 columns]

# %%
df["max_th"] = np.where(df["max_wind_speed"] > 30, 2, np.where(df["max_wind_speed"] < 15, 0, 1))
df['max_th'].value_counts()
# Out:
# 0    44574
# 1    24445
# 2     3630
# Name: max_th, dtype: int64

# %% [markdown]
# ### basic model no grid search

# %%
def rf_model_basic(x): 
    test_1 = df[df.EXP == x]
    train_1 = df[df.EXP != x]

    train_1 = train_1.drop(['EXP','jul_date','hour_angle','avg_wind_speed'], axis = 1)

    test_1 = test_1.drop(['EXP','jul_date','hour_angle','avg_wind_speed'], axis = 1)

    df_0 = train_1[train_1['max_th'] == 0]
    df_1 = train_1[train_1['max_th'] == 1]
    df_2 = train_1[train_1['max_th'] == 2]

    df0_sample = df_0.sample(9000 ,random_state=19)
    df1_sample = df_1.sample(9000 ,random_state=19)
    df2_sample = df_2.sample(3000 ,random_state=19)

    df_new = pd.concat([df0_sample, df1_sample, df2_sample], axis = 0)

    x_train = df_new.drop('max_wind_speed', 1)
    x_train.drop(['Date','Type','max_th'], axis=1, inplace=True)
    y_train = df_new.max_wind_speed
    x_test = test_1.drop('max_wind_speed', 1)
    x_test_copy = x_test.copy()
    x_test.drop(['Date','Type','max_th'], axis=1, inplace=True)
    y_test = test_1.max_wind_speed


    model = RandomForestRegressor(random_state = 19)
    model.fit(x_train, y_train)

    pred_train = model.predict(x_train)
    train_info = model_info2(y_train, pred_train, x , "train")

    y_train30 = np.where(y_train > 30, 1, 0 )
    pred_train30 = np.where(pred_train > 30, 1, 0 )
    train_info2 = model_info1(y_train30, pred_train30, x,'train')

    pred_test = model.predict(x_test)
    test_info = model_info2(y_test, pred_test, x , "test")

    y_test30 = np.where(y_test > 30, 1, 0 )
    pred_test30 = np.where(pred_test > 30, 1, 0 )
    test_info2 = model_info1(y_test30, pred_test30, x,'test')

    table = train_info.append(test_info)
    table2 = train_info2.append(test_info2)
    print(x)
    print(table)
    print("==" *10)
    print(table2)
    print('--' * 40)

    df_class = pd.DataFrame(pred_test30, columns=['Class_results'])
    df_class['Class_results'] = np.where(df_class['Class_results'] == 1, 'Greater than 30 knots', 'Less than 30 knots')
    df_class = df_class.reset_index()
    df_class.drop('index', axis=1, inplace=True)
    df4 = pd.DataFrame(y_test)
    df4 = df4.rename(columns={'max_wind_speed': 'actual'})
    df4 = df4.reset_index()
    df4.drop('index', axis=1, inplace=True)
    x_test_copy = x_test_copy.reset_index()
    x_test_copy.drop("index", axis=1, inplace=True)
    df5 = pd.concat([x_test_copy, df4, df_class], axis=1)
    pred_df = pd.DataFrame(pred_test, columns=["pred"])
    df6 = pd.concat([df5, pred_df], axis=1)
    df6['From'] = np.where(df6['from'] == 1, 'Mesonet', 'ASOS')
    df6.drop(['from', 'max_th'], inplace=True, axis=1)
    df6['test_date'] = x
    return(table, table2, df6)

# %%
table = pd.DataFrame()
table_class = pd.DataFrame()
data = pd.DataFrame()
for i in df['EXP'].unique():
    t,tc,d = rf_model_basic(i)
    table = table.append(t)
    table_class = table_class.append(tc)
    data = data.append(d)
# Out:
# 1/7/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.171080   2.594524        -0.0305    1/7/17       train
# 0  2.628188  10.909912         0.1850    1/7/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.972905  2545           114     455      17886  0.817277  0.848333
# 0  1.000000     0             0       0       1959  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.042873    1/7/17       train                 3000
# 0          0.000000    1/7/17        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                1959
# --------------------------------------------------------------------------------
# 2/9/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.173478   2.611868        -0.0343    2/9/17       train
# 0  3.814669  22.877609        -1.9157    2/9/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.973952  2556           103     444      17897  0.823719  0.852000
# 0  0.973799    35            36      18       1972  0.393258  0.660377
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.038736    2/9/17       train                  3000
# 0          0.507042    2/9/17        test                    53
#
#    less_than_30_knots
# 0               18000
# 0                2008
# --------------------------------------------------------------------------------
# 2/13/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.156712   2.555996        -0.0255   2/13/17       train
# 0  5.606519  50.979304         1.9197   2/13/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974619  2569           102     431      17898  0.828175  0.856333
# 0  0.784875   152            32     389       1384  0.265271  0.280961
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.038188   2/13/17       train                  3000
# 0          0.173913   2/13/17        test                   541
#
#    less_than_30_knots
# 0               18000
# 0                1416
# --------------------------------------------------------------------------------
# 2/25/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.155912   2.523512        -0.0308   2/25/17       train
# 0  4.624652  34.385473        -1.2595   2/25/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.973905  2572           120     428      17880  0.824359  0.857333
# 0  0.982570     0             4      31       1973  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.044577   2/25/17       train                  3000
# 0          1.000000   2/25/17        test                    31
#
#    less_than_30_knots
# 0               18000
# 0                1977
# --------------------------------------------------------------------------------
# 3/2/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.152703   2.534017        -0.0375    3/2/17       train
# 0  4.715084  35.216118         1.5366    3/2/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.975476  2581            96     419      17904  0.833656  0.860333
# 0  0.797229   251            61     378       1475  0.363768  0.399046
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.035861    3/2/17       train                  3000
# 0          0.195513    3/2/17        test                   629
#
#    less_than_30_knots
# 0               18000
# 0                1536
# --------------------------------------------------------------------------------
# 3/14/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.153947   2.519092        -0.0406   3/14/17       train
# 0  3.624915  22.777126        -0.8829   3/14/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974333  2569           108     431      17892  0.826577  0.856333
# 0  0.930614    82            49      99       1903  0.356522  0.453039
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.040344   3/14/17       train                  3000
# 0          0.374046   3/14/17        test                   181
#
#    less_than_30_knots
# 0               18000
# 0                1952
# --------------------------------------------------------------------------------
# 3/22/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.164179   2.596568        -0.0376   3/22/17       train
# 0  4.817011  36.179686        -0.8901   3/22/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974524  2579           114     421      17886  0.828195  0.859667
# 0  0.840573   150            74     271       1669  0.303030  0.356295
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.042332   3/22/17       train                  3000
# 0          0.330357   3/22/17        test                   421
#
#    less_than_30_knots
# 0               18000
# 0                1743
# --------------------------------------------------------------------------------
# 6/19/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.157937   2.512834        -0.0261   6/19/17       train
# 0  3.981140  27.480078        -0.2523   6/19/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974619  2575           108     425      17892  0.828507  0.858333
# 0  0.979835     1             4      45       2380  0.020000  0.021739
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.040253   6/19/17       train                  3000
# 0          0.800000   6/19/17        test                    46
#
#    less_than_30_knots
# 0               18000
# 0                2384
# --------------------------------------------------------------------------------
# 7/13/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.170928   2.590569        -0.0248   7/13/17       train
# 0  3.514820  18.979531        -1.5210   7/13/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events      CSI  Hit Rate  \
# 0  0.973000  2539           106     461      17894  0.81745  0.846333
# 0  0.999154     0             0       2       2361  0.00000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.040076   7/13/17       train                  3000
# 0               NaN   7/13/17        test                     2
#
#    less_than_30_knots
# 0               18000
# 0                2361
# --------------------------------------------------------------------------------
# 10/29/17
#         MAE       MSE  Residual Mean test_date data_tested
# 0  1.143454   2.46160        -0.0356  10/29/17       train
# 0  6.764024  70.11462        -3.5388  10/29/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.976048  2608           111     392      17889  0.838316  0.869333
# 0  0.936736    10            49     101       2211  0.062500  0.090090
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.040824  10/29/17       train                  3000
# 0          0.830508  10/29/17        test                   111
#
#    less_than_30_knots
# 0               18000
# 0                2260
# --------------------------------------------------------------------------------
# 11/19/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.151743   2.537839        -0.0264  11/19/17       train
# 0  5.676878  47.851803        -2.5114  11/19/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974571  2579           113     421      17887  0.828461  0.859667
# 0  0.866937    72            77     251       2065  0.180000  0.222910
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.041976  11/19/17       train                  3000
# 0          0.516779  11/19/17        test                   323
#
#    less_than_30_knots
# 0               18000
# 0                2142
# --------------------------------------------------------------------------------
# 12/9/17
#         MAE       MSE  Residual Mean test_date data_tested
# 0  1.160522  2.546377        -0.0324   12/9/17       train
# 0  2.391919  8.554695        -1.3047   12/9/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.973333  2560           120     440      17880  0.820513  0.853333
# 0  1.000000     0             0       0       2531  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.044776   12/9/17       train                 3000
# 0          0.000000   12/9/17        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2531
# --------------------------------------------------------------------------------
# 1/4/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.170249   2.622783        -0.0304    1/4/18       train
# 0  4.007853  27.875091         1.5334    1/4/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.973619  2552           106     448      17894  0.821636  0.850667
# 0  0.920872    48             1     195       2233  0.196721  0.197531
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.039880    1/4/18       train                  3000
# 0          0.020408    1/4/18        test                   243
#
#    less_than_30_knots
# 0               18000
# 0                2234
# --------------------------------------------------------------------------------
# 3/2/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.147914   2.516554        -0.0385    3/2/18       train
# 0  4.919529  38.880027        -1.9771    3/2/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974095  2579           123     421      17877  0.825809  0.859667
# 0  0.925103    44            49     133       2204  0.194690  0.248588
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.045522    3/2/18       train                  3000
# 0          0.526882    3/2/18        test                   177
#
#    less_than_30_knots
# 0               18000
# 0                2253
# --------------------------------------------------------------------------------
# 3/7/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.168897   2.603960        -0.0323    3/7/18       train
# 0  3.578160  19.469174        -1.3735    3/7/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.973619  2570           124     430      17876  0.822663  0.856667
# 0  0.998021     2             3       2       2519  0.285714  0.500000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.046028    3/7/18       train                  3000
# 0          0.600000    3/7/18        test                     4
#
#    less_than_30_knots
# 0               18000
# 0                2522
# --------------------------------------------------------------------------------
# 3/21/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.170204   2.576622        -0.0300   3/21/18       train
# 0  4.985000  37.260740        -3.8696   3/21/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.972333  2545           126     455      17874  0.814139  0.848333
# 0  0.975129     0            58       0       2274  0.000000       NaN
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.047173   3/21/18       train                 3000
# 0          1.000000   3/21/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2332
# --------------------------------------------------------------------------------
# 5/15/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.144704   2.413017        -0.0299   5/15/18       train
# 0  4.209454  34.131903        -1.6012   5/15/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974286  2573           113     427      17887  0.826534  0.857667
# 0  0.980423     0             3      46       2454  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0           0.04207   5/15/18       train                  3000
# 0           1.00000   5/15/18        test                    46
#
#    less_than_30_knots
# 0               18000
# 0                2457
# --------------------------------------------------------------------------------
# 5/26/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.165594   2.578184        -0.0306   5/26/18       train
# 0  3.851630  24.332039        -2.8462   5/26/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974762  2557            87     443      17913  0.828312  0.852333
# 0  1.000000     0             0       0       2404  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.032905   5/26/18       train                 3000
# 0          0.000000   5/26/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2404
# --------------------------------------------------------------------------------
# 6/13/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.172393   2.620108        -0.0311   6/13/18       train
# 0  3.962435  27.252662        -1.9161   6/13/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.973000  2560           127     440      17873  0.818676  0.853333
# 0  0.999609     0             0       1       2554  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.047265   6/13/18       train                  3000
# 0               NaN   6/13/18        test                     1
#
#    less_than_30_knots
# 0               18000
# 0                2554
# --------------------------------------------------------------------------------
# 7/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.170137   2.567178        -0.0393   7/17/18       train
# 0  3.196344  19.309047        -0.6089   7/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.973714  2565           117     435      17883  0.822907     0.855
# 0  0.995726     0             0      10       2330  0.000000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.043624   7/17/18       train                  3000
# 0               NaN   7/17/18        test                    10
#
#    less_than_30_knots
# 0               18000
# 0                2330
# --------------------------------------------------------------------------------
# 7/21/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.166696   2.585994        -0.0344   7/21/18       train
# 0  4.024337  26.580320         0.6623   7/21/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974238  2566           107     434      17893  0.825877  0.855333
# 0  0.995849     0             1       9       2399  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0           0.04003   7/21/18       train                  3000
# 0           1.00000   7/21/18        test                     9
#
#    less_than_30_knots
# 0               18000
# 0                2400
# --------------------------------------------------------------------------------
# 8/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.165148   2.559734        -0.0382   8/17/18       train
# 0  3.619079  23.505388        -0.3031   8/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.975619  2604           116     396      17884  0.835687     0.868
# 0  0.996780     0             0       7       2167  0.000000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.042647   8/17/18       train                  3000
# 0               NaN   8/17/18        test                     7
#
#    less_than_30_knots
# 0               18000
# 0                2167
# --------------------------------------------------------------------------------
# 9/4/18
#         MAE       MSE  Residual Mean test_date data_tested
# 0  1.161735  2.529966        -0.0366    9/4/18       train
# 0  2.065784  6.206311        -0.6805    9/4/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974238  2569           110     431      17890  0.826045  0.856333
# 0  1.000000     0             0       0       2133  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0           0.04106    9/4/18       train                 3000
# 0           0.00000    9/4/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2133
# --------------------------------------------------------------------------------
# 9/6/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.149886   2.477512        -0.0267    9/6/18       train
# 0  2.782932  15.404184         0.1646    9/6/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events      CSI  Hit Rate  \
# 0  0.973667  2575           128     425      17872  0.82321  0.858333
# 0  0.997315     0             0       6       2229  0.00000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.047355    9/6/18       train                  3000
# 0               NaN    9/6/18        test                     6
#
#    less_than_30_knots
# 0               18000
# 0                2229
# --------------------------------------------------------------------------------
# 9/10/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.165727   2.575820        -0.0314   9/10/18       train
# 0  3.478501  20.243195        -0.4916   9/10/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974190  2569           111     431      17889  0.825779  0.856333
# 0  0.997347     0             1       5       2256  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.041418   9/10/18       train                  3000
# 0          1.000000   9/10/18        test                     5
#
#    less_than_30_knots
# 0               18000
# 0                2257
# --------------------------------------------------------------------------------
# 9/26/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.145646   2.485896        -0.0269   9/26/18       train
# 0  3.565428  20.345871         0.8024   9/26/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974143  2554            97     446      17903  0.824669  0.851333
# 0  1.000000     0             0       0       2145  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0           0.03659   9/26/18       train                 3000
# 0           0.00000   9/26/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2145
# --------------------------------------------------------------------------------
# 10/2/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.167237   2.566655        -0.0304   10/2/18       train
# 0  4.262548  28.679802        -2.0119   10/2/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.973619  2560           114     440      17886  0.822094  0.853333
# 0  0.998554     0             0       3       2072  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.042633   10/2/18       train                  3000
# 0               NaN   10/2/18        test                     3
#
#    less_than_30_knots
# 0               18000
# 0                2072
# --------------------------------------------------------------------------------
# 10/12/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.172988   2.620139        -0.0354  10/12/18       train
# 0  4.298268  28.590427        -1.5329  10/12/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.975286  2590           109     410      17891  0.833065  0.863333
# 0  0.954927    10            67      35       2151  0.089286  0.222222
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.040385  10/12/18       train                  3000
# 0          0.870130  10/12/18        test                    45
#
#    less_than_30_knots
# 0               18000
# 0                2218
# --------------------------------------------------------------------------------
# 10/27/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.166597   2.583572        -0.0309  10/27/18       train
# 0  3.976024  26.029403        -0.3738  10/27/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.975048  2594           118     406      17882  0.831944  0.864667
# 0  0.955450    16             2      92       2000  0.145455  0.148148
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.043510  10/27/18       train                  3000
# 0          0.111111  10/27/18        test                   108
#
#    less_than_30_knots
# 0               18000
# 0                2002
# --------------------------------------------------------------------------------
# 12/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.158165   2.528111        -0.0345  12/17/18       train
# 0  4.468938  31.930214        -0.3578  12/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974524  2571           106     429      17894  0.827753  0.857000
# 0  0.911271    24            30     155       1876  0.114833  0.134078
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.039597  12/17/18       train                  3000
# 0          0.555556  12/17/18        test                   179
#
#    less_than_30_knots
# 0               18000
# 0                1906
# --------------------------------------------------------------------------------
# 12/22/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.158696   2.550424        -0.0353  12/22/18       train
# 0  4.433743  30.688015        -0.2622  12/22/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.973762  2560           111     440      17889  0.822887  0.853333
# 0  0.917260    33            44     142       2029  0.150685  0.188571
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.041557  12/22/18       train                  3000
# 0          0.571429  12/22/18        test                   175
#
#    less_than_30_knots
# 0               18000
# 0                2073
# --------------------------------------------------------------------------------
# 2/24/19
#         MAE        MSE  Residual Mean test_date data_tested
# 0  1.159976   2.560850        -0.0365   2/24/19       train
# 0  5.325573  44.182908        -2.1197   2/24/19        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.974619  2563            96     437      17904  0.827842  0.854333
# 0  0.899829    63            23     211       2039  0.212121  0.229927
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.036104   2/24/19       train                  3000
# 0          0.267442   2/24/19        test                   274
#
#    less_than_30_knots
# 0               18000
# 0                2062
# --------------------------------------------------------------------------------

# %%
#table.to_csv('RF_basic_regression_results.csv')
table[table['data_tested'] == 'test']
# Out:
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.628188  10.909912         0.1850    1/7/17        test
# 0  3.814669  22.877609        -1.9157    2/9/17        test
# 0  5.606519  50.979304         1.9197   2/13/17        test
# 0  4.624652  34.385473        -1.2595   2/25/17        test
# 0  4.715084  35.216118         1.5366    3/2/17        test
# 0  3.624915  22.777126        -0.8829   3/14/17        test
# 0  4.817011  36.179686        -0.8901   3/22/17        test
# 0  3.981140  27.480078        -0.2523   6/19/17        test
# 0  3.514820  18.979531        -1.5210   7/13/17        test
# 0  6.764024  70.114620        -3.5388  10/29/17        test
# 0  5.676878  47.851803        -2.5114  11/19/17        test
# 0  2.391919   8.554695        -1.3047   12/9/17        test
# 0  4.007853  27.875091         1.5334    1/4/18        test
# 0  4.919529  38.880027        -1.9771    3/2/18        test
# 0  3.578160  19.469174        -1.3735    3/7/18        test
# 0  4.985000  37.260740        -3.8696   3/21/18        test
# 0  4.209454  34.131903        -1.6012   5/15/18        test
# 0  3.851630  24.332039        -2.8462   5/26/18        test
# 0  3.962435  27.252662        -1.9161   6/13/18        test
# 0  3.196344  19.309047        -0.6089   7/17/18        test
# 0  4.024337  26.580320         0.6623   7/21/18        test
# 0  3.619079  23.505388        -0.3031   8/17/18        test
# 0  2.065784   6.206311        -0.6805    9/4/18        test
# 0  2.782932  15.404184         0.1646    9/6/18        test
# 0  3.478501  20.243195        -0.4916   9/10/18        test
# 0  3.565428  20.345871         0.8024   9/26/18        test
# 0  4.262548  28.679802        -2.0119   10/2/18        test
# 0  4.298268  28.590427        -1.5329  10/12/18        test
# 0  3.976024  26.029403        -0.3738  10/27/18        test
# 0  4.468938  31.930214        -0.3578  12/17/18        test
# 0  4.433743  30.688015        -0.2622  12/22/18        test
# 0  5.325573  44.182908        -2.1197   2/24/19        test

# %%
#table_class.to_csv('RF_basic_classfication_results.csv')
table_class[table_class['data_tested'] == 'test']
# Out:
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  1.000000     0             0       0       1959  0.000000  0.000000
# 0  0.973799    35            36      18       1972  0.393258  0.660377
# 0  0.784875   152            32     389       1384  0.265271  0.280961
# 0  0.982570     0             4      31       1973  0.000000  0.000000
# 0  0.797229   251            61     378       1475  0.363768  0.399046
# 0  0.930614    82            49      99       1903  0.356522  0.453039
# 0  0.840573   150            74     271       1669  0.303030  0.356295
# 0  0.979835     1             4      45       2380  0.020000  0.021739
# 0  0.999154     0             0       2       2361  0.000000  0.000000
# 0  0.936736    10            49     101       2211  0.062500  0.090090
# 0  0.866937    72            77     251       2065  0.180000  0.222910
# 0  1.000000     0             0       0       2531  0.000000  0.000000
# 0  0.920872    48             1     195       2233  0.196721  0.197531
# 0  0.925103    44            49     133       2204  0.194690  0.248588
# 0  0.998021     2             3       2       2519  0.285714  0.500000
# 0  0.975129     0            58       0       2274  0.000000       NaN
# 0  0.980423     0             3      46       2454  0.000000  0.000000
# 0  1.000000     0             0       0       2404  0.000000  0.000000
# 0  0.999609     0             0       1       2554  0.000000  0.000000
# 0  0.995726     0             0      10       2330  0.000000  0.000000
# 0  0.995849     0             1       9       2399  0.000000  0.000000
# 0  0.996780     0             0       7       2167  0.000000  0.000000
# 0  1.000000     0             0       0       2133  0.000000  0.000000
# 0  0.997315     0             0       6       2229  0.000000  0.000000
# 0  0.997347     0             1       5       2256  0.000000  0.000000
# 0  1.000000     0             0       0       2145  0.000000  0.000000
# 0  0.998554     0             0       3       2072  0.000000  0.000000
# 0  0.954927    10            67      35       2151  0.089286  0.222222
# 0  0.955450    16             2      92       2000  0.145455  0.148148
# 0  0.911271    24            30     155       1876  0.114833  0.134078
# 0  0.917260    33            44     142       2029  0.150685  0.188571
# 0  0.899829    63            23     211       2039  0.212121  0.229927
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.000000    1/7/17        test                    0
# 0          0.507042    2/9/17        test                   53
# 0          0.173913   2/13/17        test                  541
# 0          1.000000   2/25/17        test                   31
# 0          0.195513    3/2/17        test                  629
# 0          0.374046   3/14/17        test                  181
# 0          0.330357   3/22/17        test                  421
# 0          0.800000   6/19/17        test                   46
# 0               NaN   7/13/17        test                    2
# 0          0.830508  10/29/17        test                  111
# 0          0.516779  11/19/17        test                  323
# 0          0.000000   12/9/17        test                    0
# 0          0.020408    1/4/18        test                  243
# 0          0.526882    3/2/18        test                  177
# 0          0.600000    3/7/18        test                    4
# 0          1.000000   3/21/18        test                    0
# 0          1.000000   5/15/18        test                   46
# 0          0.000000   5/26/18        test                    0
# 0               NaN   6/13/18        test                    1
# 0               NaN   7/17/18        test                   10
# 0          1.000000   7/21/18        test                    9
# 0               NaN   8/17/18        test                    7
# 0          0.000000    9/4/18        test                    0
# 0               NaN    9/6/18        test                    6
# 0          1.000000   9/10/18        test                    5
# 0          0.000000   9/26/18        test                    0
# 0               NaN   10/2/18        test                    3
# 0          0.870130  10/12/18        test                   45
# 0          0.111111  10/27/18        test                  108
# 0          0.555556  12/17/18        test                  179
# 0          0.571429  12/22/18        test                  175
# 0          0.267442   2/24/19        test                  274
#
#    less_than_30_knots
# 0                1959
# 0                2008
# 0                1416
# 0                1977
# 0                1536
# 0                1952
# 0                1743
# 0                2384
# 0                2361
# 0                2260
# 0                2142
# 0                2531
# 0                2234
# 0                2253
# 0                2522
# 0                2332
# 0                2457
# 0                2404
# 0                2554
# 0                2330
# 0                2400
# 0                2167
# 0                2133
# 0                2229
# 0                2257
# 0                2145
# 0                2072
# 0                2218
# 0                2002
# 0                1906
# 0                2073
# 0                2062

# %%
#data.to_csv('RF_basic_data_results.csv')
data.head(2)
# Out:
#                   Date  Type        R1        R2  \
# 0  2017-01-07 06:00:00  ANDE  2.630564  2.322274
# 1  2017-01-07 06:15:00  ANDE  2.055383  1.813005
#
#    Pressure_reduced_to_MSL_.Pa..0.MSL  Derived_radar_reflectivity_.dB..1.HYBL  \
# 0                            102879.7                                     0.0
# 1                            102951.0                                     0.0
#
#    u.component_of_wind_.m.s..85000.ISBL  v.component_of_wind_.m.s..85000.ISBL  \
# 0                                 5.447                                -1.457
# 1                                 5.629                                -1.464
#
#    wind_speed_85000  wind_shear_85000  ...  diff_temp  geo_cbl  veg_sfc  \
# 0          5.638498          5.269992  ...      0.739  -5000.0   40.293
# 1          5.816265          5.773324  ...      1.050  -5000.0   40.293
#
#    best_4_layer     ws_700    actual       Class_results      pred     From  \
# 0        23.757  16.787335  2.332608  Less than 30 knots  3.284963  Mesonet
# 1        23.959  16.195689  1.555072  Less than 30 knots  3.524380  Mesonet
#
#    test_date
# 0     1/7/17
# 1     1/7/17
#
# [2 rows x 26 columns]

# %% [markdown]
# ### Random Forest Grid Searched Model

# %%
# df_0 = df2[df2['max_th'] == 0]
# df_1 = df2[df2['max_th'] == 1]
# df_2 = df2[df2['max_th'] == 2]

# df0_sample = df_0.sample(9000 ,random_state=19)
# df1_sample = df_1.sample(9000 ,random_state=19)
# df2_sample = df_2.sample(3000 ,random_state=19)

# df_gs = pd.concat([df0_sample, df1_sample, df2_sample], axis = 0)
# df_gs['max_th'].value_counts()
# Out:
# 1    9000
# 0    9000
# 2    3000
# Name: max_th, dtype: int64

# %%
# X = df_gs.drop(['Date','max_wind_speed', 'Type', 'EXP', 'max_th'], 1)
# Y = df_gs.max_wind_speed.values
# X
# Out:
#        from          R1          R2  Pressure_reduced_to_MSL_.Pa..0.MSL  \
# 10628     1    3.261219    6.132343                          102305.945
# 9344      1    0.152229    0.247941                          100969.600
# 56227     1    0.318725    0.382697                          100941.227
# 70523     1    7.627781    3.370534                          100430.800
# 48479     1  168.072532  118.652089                          101041.789
# ...     ...         ...         ...                                 ...
# 68215     1    1.037844    1.485693                           99718.380
# 48516     1    0.256680    0.386990                           99734.828
# 5065      1    0.662720    0.743379                           98702.180
# 41001     0    0.012512    0.019735                          100375.700
# 69485     1   -0.021828   -0.074405                          100008.836
#
#        Derived_radar_reflectivity_.dB..1.HYBL  \
# 10628                                   0.000
# 9344                                   33.099
# 56227                                   0.000
# 70523                                  27.962
# 48479                                   0.000
# ...                                       ...
# 68215                                  27.139
# 48516                                  17.453
# 5065                                   33.386
# 41001                                   0.000
# 69485                                   0.000
#
#        u.component_of_wind_.m.s..85000.ISBL  \
# 10628                                 7.229
# 9344                                -18.893
# 56227                                15.297
# 70523                                -8.825
# 48479                                 6.342
# ...                                     ...
# 68215                               -13.345
# 48516                                -4.688
# 5065                                -30.792
# 41001                                25.212
# 69485                                14.596
#
#        v.component_of_wind_.m.s..85000.ISBL  wind_speed_85000  \
# 10628                                -2.143          7.539953
# 9344                                 -8.557         20.740485
# 56227                                 4.152         15.850467
# 70523                               -11.532         14.521283
# 48479                                -0.381          6.353434
# ...                                     ...               ...
# 68215                               -17.285         21.837130
# 48516                                10.497         11.496276
# 5065                                -20.424         36.949791
# 41001                                 0.160         25.212508
# 69485                               -11.863         18.808880
#
#        wind_shear_85000  Wind_speed_.gust._.m.s..0.SFC  ...   HYBL_two  \
# 10628         11.683057                         13.157  ...   5.474310
# 9344          12.970719                         35.733  ...  13.847472
# 56227         11.993877                         18.805  ...   7.235121
# 70523         13.937777                         23.745  ...   4.414027
# 48479          3.322680                          6.390  ...   3.346181
# ...                 ...                            ...  ...        ...
# 68215         15.755341                         35.936  ...  17.014168
# 48516         18.281077                         35.772  ...  15.681797
# 5065          31.360209                         47.098  ...  21.252886
# 41001         16.084006                         31.691  ...  19.528904
# 69485         12.835594                         26.831  ...  11.400766
#
#        HYBL_three  HYBL_four  HYBL_five  diff_temp   geo_cbl  veg_sfc  \
# 10628    7.426896   8.629481   7.586525      0.079  9613.756   87.831
# 9344    17.020268  19.371065  21.503364     -1.993  2451.432   36.072
# 56227    8.691705  10.875789  13.237866     -3.119 -5000.000   86.181
# 70523   10.467418  13.408971  14.921248      0.387   496.275   38.977
# 48479    4.309025   6.146063   7.883806      0.485  5767.350   44.053
# ...           ...        ...        ...        ...       ...      ...
# 68215   18.759977  20.652048  22.376745     -3.191   474.611   43.724
# 48516   18.568731  20.858800  22.640065      3.231   266.416   41.801
# 5065    23.848851  26.730762  29.941884     -0.986   559.418   41.206
# 41001   22.060336  23.619324  24.663153     -5.191 -5000.000   32.040
# 69485   13.080156  14.508165  15.961644     -5.882 -5000.000   44.291
#
#        best_4_layer     ws_700  max_th
# 10628        -0.913   2.643295       0
# 9344          9.649  13.108330       0
# 56227        -0.045   2.921928       0
# 70523        17.013  14.884441       0
# 48479        18.313  16.078714       0
# ...             ...        ...     ...
# 68215        18.400  20.115060       2
# 48516        -0.042  11.009412       2
# 5065          8.700   2.228930       2
# 41001        19.561  13.250822       2
# 69485        13.334   4.681805       2
#
# [21000 rows x 21 columns]

# %%
# from sklearn.model_selection import GridSearchCV
# pram = {'max_depth' : [3,5,7], 'min_samples_split': [3, 5, 7],'n_estimators':[100,350 ,500] , 'max_features' : [0.2,0.3,0.4]}
# clf = GridSearchCV(RandomForestRegressor(random_state=19), pram, cv=3, n_jobs=-1, verbose=3, scoring = 'neg_mean_absolute_error')
# clf.fit(X,Y)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 243 out of 243 | elapsed:  5.6min finished
# GridSearchCV(cv=3, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=19,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 7],
#                          'max_features': [0.2, 0.3, 0.4],
#                          'min_samples_split': [3, 5, 7],
#                          'n_estimators': [100, 350, 500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_mean_absolute_error', verbose=3)

# %%
# clf.best_score_, clf.best_params_
# Out:
# (-3.9179784140825844,
#  {'max_depth': 7,
#   'max_features': 0.4,
#   'min_samples_split': 3,
#   'n_estimators': 100})

# %% [markdown]
# ### Model

# %%
def rf_model(x): 
    test_1 = df[df.EXP == x]
    train_1 = df[df.EXP != x]

    train_1 = train_1.drop(['EXP','jul_date','hour_angle','avg_wind_speed'], axis = 1)
    test_1 = test_1.drop(['EXP','jul_date','hour_angle','avg_wind_speed'], axis = 1)

    df_0 = train_1[train_1['max_th'] == 0]
    df_1 = train_1[train_1['max_th'] == 1]
    df_2 = train_1[train_1['max_th'] == 2]

    df0_sample = df_0.sample(9000 ,random_state=19)
    df1_sample = df_1.sample(9000 ,random_state=19)
    df2_sample = df_2.sample(3000 ,random_state=19)

    df_new = pd.concat([df0_sample, df1_sample, df2_sample], axis = 0)

    x_train = df_new.drop('max_wind_speed', 1)
    x_train.drop(['Date','Type','max_th'], axis=1, inplace=True)
    y_train = df_new.max_wind_speed
    x_test = test_1.drop('max_wind_speed', 1)
    x_test_copy = x_test.copy()
    x_test.drop(['Date','Type','max_th'], axis=1, inplace=True)
    y_test = test_1.max_wind_speed

    
    model = RandomForestRegressor(n_estimators=100, min_samples_split = 3, max_features = 0.4, max_depth = 7 ,
                                  random_state = 19)
    model.fit(x_train, y_train)

    pred_train = model.predict(x_train)
    train_info = model_info2(y_train, pred_train, x , "train")

    y_train30 = np.where(y_train > 30, 1, 0 )
    pred_train30 = np.where(pred_train > 30, 1, 0 )
    train_info2 = model_info1(y_train30, pred_train30, x,'train')

    pred_test = model.predict(x_test)
    test_info = model_info2(y_test, pred_test, x , "test")

    y_test30 = np.where(y_test > 30, 1, 0 )
    pred_test30 = np.where(pred_test > 30, 1, 0 )
    test_info2 = model_info1(y_test30, pred_test30, x,'test')

    table = train_info.append(test_info)
    table2 = train_info2.append(test_info2)
    print(x)
    print(table)
    print("==" *10)
    print(table2)
    print('--' * 40)

    df_class = pd.DataFrame(pred_test30, columns=['Class_results'])
    df_class['Class_results'] = np.where(df_class['Class_results'] == 1, 'Greater than 30 knots', 'Less than 30 knots')
    df_class = df_class.reset_index()
    df_class.drop('index', axis=1, inplace=True)
    df4 = pd.DataFrame(y_test)
    df4 = df4.rename(columns={'max_wind_speed': 'actual'})
    df4 = df4.reset_index()
    df4.drop('index', axis=1, inplace=True)
    x_test_copy = x_test_copy.reset_index()
    x_test_copy.drop("index", axis=1, inplace=True)
    df5 = pd.concat([x_test_copy, df4, df_class], axis=1)
    pred_df = pd.DataFrame(pred_test, columns=["pred"])
    df6 = pd.concat([df5, pred_df], axis=1)
    df6['From'] = np.where(df6['from'] == 1, 'Mesonet', 'ASOS')
    df6.drop(['from', 'max_th'], inplace=True, axis=1)
    df6['test_date'] = x
    return(table, table2, df6)

# %%
table2 = pd.DataFrame()
table_class2 = pd.DataFrame()
data2 = pd.DataFrame()
for i in df['EXP'].unique():
    t,tc,d = rf_model(i)
    table2 = table2.append(t)
    table_class2 = table_class2.append(tc)
    data2 = data2.append(d)
# Out:
# 1/7/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.923876  25.878245        -0.0014    1/7/17       train
# 0  2.570526  10.497127        -0.0257    1/7/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.908238  1270           197    1730      17803  0.397247  0.423333
# 0  1.000000     0             0       0       1959  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.134288    1/7/17       train                 3000
# 0          0.000000    1/7/17        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                1959
# --------------------------------------------------------------------------------
# 2/9/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.912492  25.648377          0.004    2/9/17       train
# 0  4.034421  24.838817         -2.177    2/9/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.907333  1289           235    1711      17765  0.398454  0.429667
# 0  0.969918    20            29      33       1979  0.243902  0.377358
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.154199    2/9/17       train                  3000
# 0          0.591837    2/9/17        test                    53
#
#    less_than_30_knots
# 0               18000
# 0                2008
# --------------------------------------------------------------------------------
# 2/13/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.895877  25.472960         0.0049   2/13/17       train
# 0  5.550683  48.004103         1.1328   2/13/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.904190  1156           168    1844      17832  0.364899  0.385333
# 0  0.784364   146            27     395       1389  0.257042  0.269871
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.126888   2/13/17       train                  3000
# 0          0.156069   2/13/17        test                   541
#
#    less_than_30_knots
# 0               18000
# 0                1416
# --------------------------------------------------------------------------------
# 2/25/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.889186  25.144887        -0.0023   2/25/17       train
# 0  4.670351  34.338927        -1.1483   2/25/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.906429  1271           236    1729      17764  0.392769  0.423667
# 0  0.984064     0             1      31       1976  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.156603   2/25/17       train                  3000
# 0          1.000000   2/25/17        test                    31
#
#    less_than_30_knots
# 0               18000
# 0                1977
# --------------------------------------------------------------------------------
# 3/2/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.906616  25.735889         0.0002    3/2/17       train
# 0  4.726951  34.769552         1.0439    3/2/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.906905  1224           179    1776      17821  0.385027  0.408000
# 0  0.788453   213            42     416       1494  0.317437  0.338633
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.127584    3/2/17       train                  3000
# 0          0.164706    3/2/17        test                   629
#
#    less_than_30_knots
# 0               18000
# 0                1536
# --------------------------------------------------------------------------------
# 3/14/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.883678  25.319954         0.0024   3/14/17       train
# 0  3.811096  24.057530        -0.7612   3/14/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.908952  1275           187    1725      17813  0.400063  0.425000
# 0  0.944210    75            13     106       1939  0.386598  0.414365
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.127907   3/14/17       train                  3000
# 0          0.147727   3/14/17        test                   181
#
#    less_than_30_knots
# 0               18000
# 0                1952
# --------------------------------------------------------------------------------
# 3/22/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.885426  25.587904         0.0011   3/22/17       train
# 0  4.981614  37.833952        -1.1908   3/22/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.906667  1199           159    1801      17841  0.379550  0.399667
# 0  0.830869   158           103     263       1640  0.301527  0.375297
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.117084   3/22/17       train                  3000
# 0          0.394636   3/22/17        test                   421
#
#    less_than_30_knots
# 0               18000
# 0                1743
# --------------------------------------------------------------------------------
# 6/19/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.875521  25.018777         0.0017   6/19/17       train
# 0  3.850474  25.267243        -0.4566   6/19/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.906524  1218           181    1782      17819  0.382898     0.406
# 0  0.981070     0             0      46       2384  0.000000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.129378   6/19/17       train                  3000
# 0               NaN   6/19/17        test                    46
#
#    less_than_30_knots
# 0               18000
# 0                2384
# --------------------------------------------------------------------------------
# 7/13/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.922518  25.785187         0.0052   7/13/17       train
# 0  3.862459  22.308292        -2.1456   7/13/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.906333  1224           191    1776      17809  0.383579     0.408
# 0  0.999154     0             0       2       2361  0.000000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.134982   7/13/17       train                  3000
# 0               NaN   7/13/17        test                     2
#
#    less_than_30_knots
# 0               18000
# 0                2361
# --------------------------------------------------------------------------------
# 10/29/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.845046  24.603174         0.0016  10/29/17       train
# 0  7.037079  76.738074        -3.9863  10/29/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.911095  1382           249    1618      17751  0.425362  0.460667
# 0  0.941375     9            37     102       2223  0.060811  0.081081
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.152667  10/29/17       train                  3000
# 0          0.804348  10/29/17        test                   111
#
#    less_than_30_knots
# 0               18000
# 0                2260
# --------------------------------------------------------------------------------
# 11/19/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.877407  25.268095         0.0027  11/19/17       train
# 0  5.663748  47.193459        -2.5409  11/19/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.911714  1354           208    1646      17792  0.422070  0.451333
# 0  0.873428    61            50     262       2092  0.163539  0.188854
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.133163  11/19/17       train                  3000
# 0          0.450450  11/19/17        test                   323
#
#    less_than_30_knots
# 0               18000
# 0                2142
# --------------------------------------------------------------------------------
# 12/9/17
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.892812  25.417662         0.0020   12/9/17       train
# 0  2.428728   8.403593        -1.4089   12/9/17        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.909524  1330           230    1670      17770  0.411765  0.443333
# 0  1.000000     0             0       0       2531  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.147436   12/9/17       train                 3000
# 0          0.000000   12/9/17        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2531
# --------------------------------------------------------------------------------
# 1/4/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.878193  25.378016         0.0022    1/4/18       train
# 0  4.067514  28.147643         1.1112    1/4/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.909857  1328           221    1672      17779  0.412294  0.442667
# 0  0.911990    26             1     217       2233  0.106557  0.106996
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.142673    1/4/18       train                  3000
# 0          0.037037    1/4/18        test                   243
#
#    less_than_30_knots
# 0               18000
# 0                2234
# --------------------------------------------------------------------------------
# 3/2/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.835103  24.674790         0.0010    3/2/18       train
# 0  5.118132  42.430327        -1.9513    3/2/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.910857  1398           270    1602      17730  0.427523  0.466000
# 0  0.925514     5             9     172       2244  0.026882  0.028249
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.161871    3/2/18       train                  3000
# 0          0.642857    3/2/18        test                   177
#
#    less_than_30_knots
# 0               18000
# 0                2253
# --------------------------------------------------------------------------------
# 3/7/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.906474  25.625026         0.0057    3/7/18       train
# 0  3.407181  17.407617        -1.0561    3/7/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.904143  1161           174    1839      17826  0.365784     0.387
# 0  0.997625     0             2       4       2520  0.000000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.130337    3/7/18       train                  3000
# 0          1.000000    3/7/18        test                     4
#
#    less_than_30_knots
# 0               18000
# 0                2522
# --------------------------------------------------------------------------------
# 3/21/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.926368  25.771664         0.0039   3/21/18       train
# 0  5.978610  50.309407        -5.2809   3/21/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events      CSI  Hit Rate  \
# 0  0.904667  1186           188    1814      17812  0.37202  0.395333
# 0  0.975129     0            58       0       2274  0.00000       NaN
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.136827   3/21/18       train                 3000
# 0          1.000000   3/21/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2332
# --------------------------------------------------------------------------------
# 5/15/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.866874  24.665532        -0.0011   5/15/18       train
# 0  4.470388  36.573707        -1.9934   5/15/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.909905  1322           214    1678      17786  0.411325  0.440667
# 0  0.981622     0             0      46       2457  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.139323   5/15/18       train                  3000
# 0               NaN   5/15/18        test                    46
#
#    less_than_30_knots
# 0               18000
# 0                2457
# --------------------------------------------------------------------------------
# 5/26/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.903637  25.586150         0.0047   5/26/18       train
# 0  4.189792  26.871102        -3.1311   5/26/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.908429  1229           152    1771      17848  0.389911  0.409667
# 0  1.000000     0             0       0       2404  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.110065   5/26/18       train                 3000
# 0          0.000000   5/26/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2404
# --------------------------------------------------------------------------------
# 6/13/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.878981  25.412977         0.0019   6/13/18       train
# 0  4.210143  29.232604        -2.7006   6/13/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.905095  1216           209    1784      17791  0.378934  0.405333
# 0  0.999609     0             0       1       2554  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.146667   6/13/18       train                  3000
# 0               NaN   6/13/18        test                     1
#
#    less_than_30_knots
# 0               18000
# 0                2554
# --------------------------------------------------------------------------------
# 7/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.901051  25.504611         0.0023   7/17/18       train
# 0  3.617619  22.588633        -0.8475   7/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events    CSI  Hit Rate  \
# 0  0.907810  1264           200    1736      17800  0.395  0.421333
# 0  0.995726     0             0      10       2330  0.000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.136612   7/17/18       train                  3000
# 0               NaN   7/17/18        test                    10
#
#    less_than_30_knots
# 0               18000
# 0                2330
# --------------------------------------------------------------------------------
# 7/21/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.908523  25.691978         0.0032   7/21/18       train
# 0  3.866549  23.757631         0.2984   7/21/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.909238  1288           194    1712      17806  0.403256  0.429333
# 0  0.996264     0             0       9       2400  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.130904   7/21/18       train                  3000
# 0               NaN   7/21/18        test                     9
#
#    less_than_30_knots
# 0               18000
# 0                2400
# --------------------------------------------------------------------------------
# 8/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.902933  25.540994        -0.0006   8/17/18       train
# 0  3.720136  23.823960        -0.3513   8/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0   0.90519  1204           195    1796      17805  0.376839  0.401333
# 0   0.99678     0             0       7       2167  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.139385   8/17/18       train                  3000
# 0               NaN   8/17/18        test                     7
#
#    less_than_30_knots
# 0               18000
# 0                2167
# --------------------------------------------------------------------------------
# 9/4/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.908053  25.499743         0.0002    9/4/18       train
# 0  2.390097   8.188313        -1.0054    9/4/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.908095  1306           236    1694      17764  0.403585  0.435333
# 0  1.000000     0             0       0       2133  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.153048    9/4/18       train                 3000
# 0          0.000000    9/4/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2133
# --------------------------------------------------------------------------------
# 9/6/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.892020  25.298299         0.0060    9/6/18       train
# 0  3.136706  18.244626        -0.0847    9/6/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.906238  1219           188    1781      17812  0.382371  0.406333
# 0  0.997315     0             0       6       2229  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.133618    9/6/18       train                  3000
# 0               NaN    9/6/18        test                     6
#
#    less_than_30_knots
# 0               18000
# 0                2229
# --------------------------------------------------------------------------------
# 9/10/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.903754  25.554265         0.0038   9/10/18       train
# 0  3.312836  18.029412        -0.3578   9/10/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.906952  1212           166    1788      17834  0.382817     0.404
# 0  0.997790     0             0       5       2257  0.000000     0.000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.120464   9/10/18       train                  3000
# 0               NaN   9/10/18        test                     5
#
#    less_than_30_knots
# 0               18000
# 0                2257
# --------------------------------------------------------------------------------
# 9/26/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.869192  25.212289         0.0043   9/26/18       train
# 0  3.408874  18.667418         0.0447   9/26/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.906905  1234           189    1766      17811  0.386955  0.411333
# 0  1.000000     0             0       0       2145  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.132818   9/26/18       train                 3000
# 0          0.000000   9/26/18        test                    0
#
#    less_than_30_knots
# 0               18000
# 0                2145
# --------------------------------------------------------------------------------
# 10/2/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.877511  25.337224         0.0006   10/2/18       train
# 0  4.226183  28.262824        -1.7093   10/2/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.908810  1282           197    1718      17803  0.401001  0.427333
# 0  0.998554     0             0       3       2072  0.000000  0.000000
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.133198   10/2/18       train                  3000
# 0               NaN   10/2/18        test                     3
#
#    less_than_30_knots
# 0               18000
# 0                2072
# --------------------------------------------------------------------------------
# 10/12/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.877679  25.409194        -0.0039  10/12/18       train
# 0  4.141655  26.633077        -1.3297  10/12/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.910048  1315           204    1685      17796  0.410424  0.438333
# 0  0.977464     8            14      37       2204  0.135593  0.177778
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.134299  10/12/18       train                  3000
# 0          0.636364  10/12/18        test                    45
#
#    less_than_30_knots
# 0               18000
# 0                2218
# --------------------------------------------------------------------------------
# 10/27/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.892556  25.327867         0.0017  10/27/18       train
# 0  4.041413  26.774038        -0.6699  10/27/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.909333  1300           204    1700      17796  0.405743  0.433333
# 0  0.953555    10             0      98       2002  0.092593  0.092593
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.135638  10/27/18       train                  3000
# 0          0.000000  10/27/18        test                   108
#
#    less_than_30_knots
# 0               18000
# 0                2002
# --------------------------------------------------------------------------------
# 12/17/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.895147  25.181034        -0.0013  12/17/18       train
# 0  4.591714  34.157150         0.0406  12/17/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.912048  1350           197    1650      17803  0.422271  0.450000
# 0  0.910312    10            18     169       1888  0.050761  0.055866
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.127343  12/17/18       train                  3000
# 0          0.642857  12/17/18        test                   179
#
#    less_than_30_knots
# 0               18000
# 0                1906
# --------------------------------------------------------------------------------
# 12/22/18
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.894865  25.533474         0.0022  12/22/18       train
# 0  4.331972  29.476554        -0.4847  12/22/18        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.911286  1374           237    1626      17763  0.424467  0.458000
# 0  0.922153    32            32     143       2041  0.154589  0.182857
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.147114  12/22/18       train                  3000
# 0          0.500000  12/22/18        test                   175
#
#    less_than_30_knots
# 0               18000
# 0                2073
# --------------------------------------------------------------------------------
# 2/24/19
#         MAE        MSE  Residual Mean test_date data_tested
# 0  3.874048  25.146512         0.0069   2/24/19       train
# 0  5.132180  42.128321        -1.2929   2/24/19        test
# ====================
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  0.908095  1305           235    1695      17765  0.403400  0.435000
# 0  0.903682    62            13     212       2049  0.216028  0.226277
#
#    False Alarm Rate test_date data_tested  greter_than_30_knots  \
# 0          0.152597   2/24/19       train                  3000
# 0          0.173333   2/24/19        test                   274
#
#    less_than_30_knots
# 0               18000
# 0                2062
# --------------------------------------------------------------------------------

# %%
#table2.to_csv('RF_search_regression_results.csv')
table2[table2['data_tested'] == 'test']
# Out:
#         MAE        MSE  Residual Mean test_date data_tested
# 0  2.570526  10.497127        -0.0257    1/7/17        test
# 0  4.034421  24.838817        -2.1770    2/9/17        test
# 0  5.550683  48.004103         1.1328   2/13/17        test
# 0  4.670351  34.338927        -1.1483   2/25/17        test
# 0  4.726951  34.769552         1.0439    3/2/17        test
# 0  3.811096  24.057530        -0.7612   3/14/17        test
# 0  4.981614  37.833952        -1.1908   3/22/17        test
# 0  3.850474  25.267243        -0.4566   6/19/17        test
# 0  3.862459  22.308292        -2.1456   7/13/17        test
# 0  7.037079  76.738074        -3.9863  10/29/17        test
# 0  5.663748  47.193459        -2.5409  11/19/17        test
# 0  2.428728   8.403593        -1.4089   12/9/17        test
# 0  4.067514  28.147643         1.1112    1/4/18        test
# 0  5.118132  42.430327        -1.9513    3/2/18        test
# 0  3.407181  17.407617        -1.0561    3/7/18        test
# 0  5.978610  50.309407        -5.2809   3/21/18        test
# 0  4.470388  36.573707        -1.9934   5/15/18        test
# 0  4.189792  26.871102        -3.1311   5/26/18        test
# 0  4.210143  29.232604        -2.7006   6/13/18        test
# 0  3.617619  22.588633        -0.8475   7/17/18        test
# 0  3.866549  23.757631         0.2984   7/21/18        test
# 0  3.720136  23.823960        -0.3513   8/17/18        test
# 0  2.390097   8.188313        -1.0054    9/4/18        test
# 0  3.136706  18.244626        -0.0847    9/6/18        test
# 0  3.312836  18.029412        -0.3578   9/10/18        test
# 0  3.408874  18.667418         0.0447   9/26/18        test
# 0  4.226183  28.262824        -1.7093   10/2/18        test
# 0  4.141655  26.633077        -1.3297  10/12/18        test
# 0  4.041413  26.774038        -0.6699  10/27/18        test
# 0  4.591714  34.157150         0.0406  12/17/18        test
# 0  4.331972  29.476554        -0.4847  12/22/18        test
# 0  5.132180  42.128321        -1.2929   2/24/19        test

# %%
#table_class2.to_csv('RF_search_classification_results.csv')
table_class2[table_class2['data_tested'] == 'test']
# Out:
#    Accuracy  Hits  False Alarms  Misses  No Events       CSI  Hit Rate  \
# 0  1.000000     0             0       0       1959  0.000000  0.000000
# 0  0.969918    20            29      33       1979  0.243902  0.377358
# 0  0.784364   146            27     395       1389  0.257042  0.269871
# 0  0.984064     0             1      31       1976  0.000000  0.000000
# 0  0.788453   213            42     416       1494  0.317437  0.338633
# 0  0.944210    75            13     106       1939  0.386598  0.414365
# 0  0.830869   158           103     263       1640  0.301527  0.375297
# 0  0.981070     0             0      46       2384  0.000000  0.000000
# 0  0.999154     0             0       2       2361  0.000000  0.000000
# 0  0.941375     9            37     102       2223  0.060811  0.081081
# 0  0.873428    61            50     262       2092  0.163539  0.188854
# 0  1.000000     0             0       0       2531  0.000000  0.000000
# 0  0.911990    26             1     217       2233  0.106557  0.106996
# 0  0.925514     5             9     172       2244  0.026882  0.028249
# 0  0.997625     0             2       4       2520  0.000000  0.000000
# 0  0.975129     0            58       0       2274  0.000000       NaN
# 0  0.981622     0             0      46       2457  0.000000  0.000000
# 0  1.000000     0             0       0       2404  0.000000  0.000000
# 0  0.999609     0             0       1       2554  0.000000  0.000000
# 0  0.995726     0             0      10       2330  0.000000  0.000000
# 0  0.996264     0             0       9       2400  0.000000  0.000000
# 0  0.996780     0             0       7       2167  0.000000  0.000000
# 0  1.000000     0             0       0       2133  0.000000  0.000000
# 0  0.997315     0             0       6       2229  0.000000  0.000000
# 0  0.997790     0             0       5       2257  0.000000  0.000000
# 0  1.000000     0             0       0       2145  0.000000  0.000000
# 0  0.998554     0             0       3       2072  0.000000  0.000000
# 0  0.977464     8            14      37       2204  0.135593  0.177778
# 0  0.953555    10             0      98       2002  0.092593  0.092593
# 0  0.910312    10            18     169       1888  0.050761  0.055866
# 0  0.922153    32            32     143       2041  0.154589  0.182857
# 0  0.903682    62            13     212       2049  0.216028  0.226277
#
#    False Alarm Rate test_date data_tested greter_than_30_knots  \
# 0          0.000000    1/7/17        test                    0
# 0          0.591837    2/9/17        test                   53
# 0          0.156069   2/13/17        test                  541
# 0          1.000000   2/25/17        test                   31
# 0          0.164706    3/2/17        test                  629
# 0          0.147727   3/14/17        test                  181
# 0          0.394636   3/22/17        test                  421
# 0               NaN   6/19/17        test                   46
# 0               NaN   7/13/17        test                    2
# 0          0.804348  10/29/17        test                  111
# 0          0.450450  11/19/17        test                  323
# 0          0.000000   12/9/17        test                    0
# 0          0.037037    1/4/18        test                  243
# 0          0.642857    3/2/18        test                  177
# 0          1.000000    3/7/18        test                    4
# 0          1.000000   3/21/18        test                    0
# 0               NaN   5/15/18        test                   46
# 0          0.000000   5/26/18        test                    0
# 0               NaN   6/13/18        test                    1
# 0               NaN   7/17/18        test                   10
# 0               NaN   7/21/18        test                    9
# 0               NaN   8/17/18        test                    7
# 0          0.000000    9/4/18        test                    0
# 0               NaN    9/6/18        test                    6
# 0               NaN   9/10/18        test                    5
# 0          0.000000   9/26/18        test                    0
# 0               NaN   10/2/18        test                    3
# 0          0.636364  10/12/18        test                   45
# 0          0.000000  10/27/18        test                  108
# 0          0.642857  12/17/18        test                  179
# 0          0.500000  12/22/18        test                  175
# 0          0.173333   2/24/19        test                  274
#
#    less_than_30_knots
# 0                1959
# 0                2008
# 0                1416
# 0                1977
# 0                1536
# 0                1952
# 0                1743
# 0                2384
# 0                2361
# 0                2260
# 0                2142
# 0                2531
# 0                2234
# 0                2253
# 0                2522
# 0                2332
# 0                2457
# 0                2404
# 0                2554
# 0                2330
# 0                2400
# 0                2167
# 0                2133
# 0                2229
# 0                2257
# 0                2145
# 0                2072
# 0                2218
# 0                2002
# 0                1906
# 0                2073
# 0                2062

# %%
#data2.to_csv('RF_search_data.csv')
data2.head()
# Out:
#                   Date  Type        R1        R2  \
# 0  2017-01-07 06:00:00  ANDE  2.630564  2.322274
# 1  2017-01-07 06:15:00  ANDE  2.055383  1.813005
# 2  2017-01-07 06:30:00  ANDE  1.792587  1.671478
# 3  2017-01-07 06:45:00  ANDE  1.442889  1.352497
# 4  2017-01-07 07:00:00  ANDE  2.283417  1.677404
#
#    Pressure_reduced_to_MSL_.Pa..0.MSL  Derived_radar_reflectivity_.dB..1.HYBL  \
# 0                            102879.7                                     0.0
# 1                            102951.0                                     0.0
# 2                            102890.6                                     0.0
# 3                            102931.0                                     0.0
# 4                            102882.5                                     0.0
#
#    u.component_of_wind_.m.s..85000.ISBL  v.component_of_wind_.m.s..85000.ISBL  \
# 0                                 5.447                                -1.457
# 1                                 5.629                                -1.464
# 2                                 5.653                                -1.560
# 3                                 5.692                                -2.445
# 4                                 5.226                                -3.060
#
#    wind_speed_85000  wind_shear_85000  ...  diff_temp  geo_cbl  veg_sfc  \
# 0          5.638498          5.269992  ...      0.739  -5000.0   40.293
# 1          5.816265          5.773324  ...      1.050  -5000.0   40.293
# 2          5.864300          6.232140  ...      1.211  -5000.0   40.293
# 3          6.194908          6.806583  ...      0.943  -5000.0   40.293
# 4          6.055962          5.554556  ...      0.751  -5000.0   40.293
#
#    best_4_layer     ws_700    actual       Class_results      pred     From  \
# 0        23.757  16.787335  2.332608  Less than 30 knots  4.930173  Mesonet
# 1        23.959  16.195689  1.555072  Less than 30 knots  4.995400  Mesonet
# 2        24.118  15.636587  2.332608  Less than 30 knots  5.244870  Mesonet
# 3        24.220  16.767452  1.555072  Less than 30 knots  5.958163  Mesonet
# 4        24.149  17.249375  2.526992  Less than 30 knots  5.468028  Mesonet
#
#    test_date
# 0     1/7/17
# 1     1/7/17
# 2     1/7/17
# 3     1/7/17
# 4     1/7/17
#
# [5 rows x 26 columns]
